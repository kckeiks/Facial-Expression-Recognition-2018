# %%
'''
Extra Setup for Colaboratory Environment
'''
#!pip install cmake
#!pip install dlib

from google.colab import files
uploaded = files.upload() 

!7za e colaboratory_dependencies.7z
!7za x frontalization_models.7z
!7za x dlib_models.7z
# Out:
#      <input type="file" id="files-9cc2d21c-5654-4c31-949d-22053553e81b" name="files[]" multiple disabled />
#      <output id="result-9cc2d21c-5654-4c31-949d-22053553e81b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving colaboratory_dependencies.7z to colaboratory_dependencies.7z
#
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 206674460 bytes (198 MiB)
#
# Extracting archive: colaboratory_dependencies.7z
# --
# Path = colaboratory_dependencies.7z
# Type = 7z
# Physical Size = 206674460
# Headers Size = 605
# Method = LZMA2:24
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 3
# Files: 14
# Size:       468032582
# Compressed: 206674460
#
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 1936322 bytes (1891 KiB)
#
# Extracting archive: frontalization_models.7z
# --
# Path = frontalization_models.7z
# Type = 7z
# Physical Size = 1936322
# Headers Size = 258
# Method = LZMA2:21
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 1
# Files: 3
# Size:       1956028
# Compressed: 1936322
#
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 63343297 bytes (61 MiB)
#
# Extracting archive: dlib_models.7z
# --
# Path = dlib_models.7z
# Type = 7z
# Physical Size = 63343297
# Headers Size = 244
# Method = LZMA2:24
# Solid = -
# Blocks = 1
#
# Everything is Ok
#
# Folders: 1
# Files: 2
# Size:       99693937
# Compressed: 63343297

# %%
'''
Libraries, etc.
'''
import os
import sys
import cv2
import numpy as np 
import scipy as sp
import pandas as pd 
import seaborn as sns
from math import sqrt
import scipy.io as io
import tensorflow as tf 
from pathlib import Path
import matplotlib.pyplot as plt 
from sklearn.metrics import confusion_matrix

from keras import backend as K
from keras.utils import np_utils
from keras.models import Sequential
from keras.utils import np_utils as npu
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.layers import Convolution2D, Activation, BatchNormalization, GaussianNoise, MaxPooling2D, Dropout, Dense, Flatten

import frontalize
import check_resources as check
import camera_calibration as calib
import facial_feature_detector as feature_detection

from models import get_model1, get_model2, get_model3

#this_path = os.path.dirname(os.path.abspath(__file__)) 
this_path = str(Path().resolve()) # for Colaboratory
# Out:
# Using TensorFlow backend.

# %%
'''
Constants, Hyperparameters, etc.
'''
BATCH_SIZE = 128
NUM_EPOCHS = 128

input_file = 'fer2013.csv'
filepath = 'Model.{epoch:02d}-{val_acc:.4f}.hdf5'

model1_acc_file = "acc_model1_t2.png"
model2_acc_file = "acc_model2_t2.png"
model3_acc_file = "acc_model3_t2.png"
acc_file = model1_acc_file

model1_loss_file = "loss_model1_t2.png"
model2_loss_file = "loss_model2_t2.png"
model3_loss_file = "loss_model3_t2.png"
loss_file = model1_loss_file

model1_cm_file = "cm_model1_t2.png"
model2_cm_file = "cm_model2_t2.png"
model3_cm_file = "cm_model3_t2.png"
cm_file = model1_cm_file

emotion_labels = ["Angry", "Disgust", "Fear", "Happy", "Sad", "Surprise", "Neutral"]
num_classes = len(emotion_labels)

# %%
'''
Load & Parse Data into Training/Test Labels & Images
'''
data = pd.read_csv(input_file)
data.head()

# get data and labels
train_set = data[(data.Usage == 'Training')]
validation_set = data[(data.Usage == 'PublicTest')]
test_set = data[(data.Usage == 'PrivateTest')]

# greyscale so depth 1
depth = 1
height = int(sqrt(len(data.pixels[0].split())))
width = height

# from pandas to np array
X_train = np.array(list(map(str.split, train_set.pixels)), np.uint8)
X_validation = np.array(list(map(str.split, validation_set.pixels)), np.uint8)
X_test = np.array(list(map(str.split, test_set.pixels)), np.uint8)

# reshape data
num_train = X_train.shape[0]
num_validation = X_validation.shape[0]
num_test = X_test.shape[0]

X_train = X_train.reshape(num_train, width, height, depth)
X_validation = X_validation.reshape(num_validation, width, height, depth)
X_test = X_test.reshape(num_test, width, height, depth)

y_train = train_set.emotion
y_validation = validation_set.emotion
y_test = test_set.emotion

y_train = np_utils.to_categorical(y_train, num_classes)
y_validation = np_utils.to_categorical(y_validation, num_classes)
y_test = np_utils.to_categorical(y_test, num_classes)

# print shapes
print('X_training: ', X_train.shape)
print('X_validation: ', X_validation.shape)
print('X_test: ', X_test.shape)
print( )
print('y_training: ', y_train.shape)
print('y_validation: ', y_validation.shape)
print('y_test: ', y_test.shape)
# Out:
# X_training:  (28709, 48, 48, 1)
# X_validation:  (3589, 48, 48, 1)
# X_test:  (3589, 48, 48, 1)
#
# y_training:  (28709, 7)
# y_validation:  (3589, 7)
# y_test:  (3589, 7)

# %%
'''
Frontalization Function
'''
def myfrontalize(X, limit):
  count = 0
  print("Total Images: ", limit)
  for i in range(0, limit):
    print("\r", end='')
    print("Images Completed: {0}".format(i), end='', flush=True)

    img = X[i, :, :, 0]
    img = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)
    img = img.astype(np.uint8)

    # check for dlib saved weights for face landmark detection
    # if it fails, dowload and extract it manually from
    # http://sourceforge.net/projects/dclib/files/dlib/v18.10/shape_predictor_68_face_landmarks.dat.bz2
    check.check_dlib_landmark_weights()
    
    # load detections performed by dlib library on 3D model and Reference Image
    model3D = frontalize.ThreeD_Model(this_path + "/frontalization_models/model3Ddlib.mat", 'model_dlib')
    
    # extract landmarks from the query image
    # list containing a 2D array with points (x, y) for each face detected in the query image
    lmarks = feature_detection.get_landmarks(img)
    if type(lmarks) is np.ndarray:
      
      # perform camera calibration according to the first face detected
      proj_matrix, camera_matrix, rmat, tvec = calib.estimate_camera(model3D, lmarks[0])
      
      # load mask to exclude eyes from symmetry
      eyemask = np.asarray(io.loadmat('frontalization_models/eyemask.mat')['eyemask'])
      
      # perform frontalization
      frontal_raw, frontal_sym = frontalize.frontalize(img, proj_matrix, model3D.ref_U, eyemask)

      # resize and convert image to grayscale
      temp = cv2.resize(frontal_sym, dsize=(48, 48), interpolation=cv2.INTER_CUBIC)
      temp = cv2.cvtColor(temp, cv2.COLOR_BGR2GRAY)   
      temp = np.resize(temp, (48, 48, 1))
      
      X[i, :, :, :] = temp.astype(np.float32)
      
      count += 1
      
  print('{} images out of {} were frontalized.'.format(count, limit))

# %%
'''
Histogram Equalization - Not defined as method, because 
train has a special case to catch and delete harmful inputs
'''
clahe = cv2.createCLAHE(clipLimit=3.235, tileGridSize=(5,5))

# original image set
X_train1 = X_train.copy() 
X_val1 = X_validation.copy()
X_test1 = X_test.copy()

# linear histogram equalization set
X_train2 = X_train.copy() 
X_val2 = X_validation.copy()
X_test2 = X_test.copy()

# clahe set
X_train3 = X_train.copy()
X_val3 = X_validation.copy()
X_test3 = X_test.copy()

# frontalized set
X_train4 = X_train.copy()
X_val4 = X_validation.copy()
X_test4 = X_test.copy()

# histogram equalization (primarily) for sets 2, 3
i = 0
while (i < num_train):
  tMax = X_train1[i].max()
  tMin = X_train1[i].min()  

  if (tMax > tMin):
    tRatio = 255 / (tMax - tMin)
    X_train2[i] = np.multiply((X_train1[i] - tMin), tRatio)
    
  # Delete harmful training examples from X_train
  else:
    X_train1 = np.delete(X_train1, (i), axis=0)
    X_train2 = np.delete(X_train2, (i), axis=0)
    X_train3 = np.delete(X_train3, (i), axis=0)
    X_train4 = np.delete(X_train4, (i), axis=0)
    y_train = np.delete(y_train, (i), axis=0)
    num_train -= 1
    i -= 1
    
  X_train3[i] = clahe.apply(X_train2[i])[:,:,np.newaxis]
  i += 1
  
i = 0
while (i < num_validation):
  tMax = X_val1[i].max()
  tMin = X_val1[i].min()

  if (tMax > tMin):
    tRatio = 255 / (tMax - tMin)
    X_val2[i] = np.multiply((X_val1[i] - tMin), tRatio).round()
    
  # Shouldn't delete validation data... skip so we don't divide by 0
  else:
    X_val2[i] = X_val1[i]

  X_val3[i] = clahe.apply(X_val2[i])[:,:,np.newaxis]
  i += 1

i = 0
while (i < num_test):
  tMax = X_test1[i].max()
  tMin = X_test1[i].min()

  if (tMax > tMin):
    tRatio = 255 / (tMax - tMin)
    X_test2[i] = np.multiply((X_test1[i] - tMin), tRatio).round()
    
  # Shouldn't delete test data... skip so we don't divide by 0
  else:
    X_test2[i] = X_test1[i]
    
  X_test3[i] = clahe.apply(X_test2[i])[:,:,np.newaxis]
  i += 1
  
# apply frontalization
#print("Attempting to frontalize image data...")
#myfrontalize(X_train4, num_train)
#myfrontalize(X_val4, num_validation)
#myfrontalize(X_test4, num_test)


# print examples from each set
print('Original Images')
for x in range(1,6):
    plt.subplot(1, 5, x)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_test1[x,:,:,0], cmap='gray')
    
plt.show()

print('Original w/ Linear Transform to normalize pixel values')
for x in range(1,6):
    plt.subplot(1, 5, x)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_test2[x,:,:,0], cmap='gray')
    
plt.show()

print('Normalized w/ Contrast Limited Adaptive Histogram Equalization')
for x in range(1,6):
    plt.subplot(1, 5, x)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_test3[x,:,:,0], cmap='gray')
    
plt.show() 

#plt.figure()
#plt.title('Frontalized Images')
#for x in range(1,6):
#  plt.subplot(1, 5, x)
#  plt.xticks([])
#  plt.yticks([])
#  plt.imshow(X_test4[x, :, :, 0], cmap='gray') 
#plt.show()
# Out:
# Original Images
# Original w/ Linear Transform to normalize pixel values
# Normalized w/ Contrast Limited Adaptive Histogram Equalization

# %%
np.save('X_train_frontalized', X_train4)
np.save('X_val_frontalized', X_val4)
np.save('X_test_frontalized', X_test4)

# %%
'''
TensorFlow Model(s)
'''

# shallow model
def get_model2():
  model = Sequential()

  model.add(Convolution2D(64, (3, 3), padding='same', input_shape=(48,48,1)))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(128, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(256, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Flatten())

  model.add(Dense(512))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(256))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(7))
  model.add(Activation('softmax'))

  return model

# actual model
def get_model2():
  model = Sequential()

  model.add(Convolution2D(64, (3, 3), padding='same', input_shape=(48,48,1)))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(128, (5, 5), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Flatten())

  model.add(Dense(256))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(512))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(7))
  model.add(Activation('softmax'))

  return model

# deeper model
def get_model3():
  model = Sequential()

  model.add(Convolution2D(64, (3, 3), padding='same', input_shape=(48,48,1)))
  model.add(Convolution2D(64, (3, 3), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  #model.add(GaussianNoise(2))
  model.add(Dropout(0.4))

  model.add(Convolution2D(128, (3, 3), padding='same'))
  model.add(Convolution2D(128, (3, 3), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  #model.add(GaussianNoise(2))
  model.add(Dropout(0.4))

  model.add(Convolution2D(256, (3, 3), padding='same'))
  model.add(Convolution2D(265, (3, 3), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  #model.add(GaussianNoise(2))
  model.add(Dropout(0.4))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(Convolution2D(512, (3, 3), padding='same')) 
  model.add(Convolution2D(512, (1, 1), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  #model.add(GaussianNoise(2))
  model.add(Dropout(0.4))

  model.add(Flatten())

  model.add(Dense(2048))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.4))

  model.add(Dense(512))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.4))

  model.add(Dense(7))
  model.add(Activation('softmax'))

  return model

# %%
'''
Metric(s)
'''

# metric to balance precision and recall
def fbeta(y_true, y_pred, threshold_shift=0):
  beta = 1

  # just in case of hipster activation at the final layer
  y_pred = K.clip(y_pred, 0, 1)

  # shifting the prediction threshold from .5 if needed
  y_pred_bin = K.round(y_pred + threshold_shift)

  tp = K.sum(K.round(y_true * y_pred_bin), axis=1) + K.epsilon()
  fp = K.sum(K.round(K.clip(y_pred_bin - y_true, 0, 1)), axis=1)
  fn = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=1)

  precision = tp / (tp + fp)
  recall = tp / (tp + fn)

  beta_squared = beta ** 2
  return K.mean((beta_squared + 1) * (precision * recall) / (beta_squared * precision + recall + K.epsilon()))

# %%
'''
Prepare Model for Training
'''
# assign the desired model from above
model = get_model2()
model.summary()

# assign X to the desired image set(s) from above
X_train = X_train3.copy()
X_validation = X_val3.copy()
X_test = X_test3.copy()

num_train = len(X_train)

# reshape X to expected shape and cast it back to type float32
X_train = X_train.reshape(num_train,width,height,depth).astype(np.float32)
X_validation = X_validation.reshape(num_validation,width,height,depth).astype(np.float32)
X_test = X_test.reshape(num_test,width,height,depth).astype(np.float32)

# augment and fit data
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    rotation_range=0,
    width_shift_range=0.0,
    height_shift_range=0.0,
    shear_range=0,
    zoom_range=0.0,
    horizontal_flip=True,
    vertical_flip=False)
datagen.fit(X_train)
datagen.fit(X_validation)

# to be applied during training
checkpointer = ModelCheckpoint(
    filepath, monitor='val_loss', verbose=1, 
    save_best_only=False, mode='auto')
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', factor=0.1, 
    patience=10, verbose=0, mode='auto', 
    min_delta=0.0001, cooldown=0, min_lr=0)
early_stop = EarlyStopping(
    monitor='val_loss', min_delta=0, patience=0, 
    verbose=0, mode='auto')

# prepare model to train
model.compile(
    loss='categorical_crossentropy', 
    optimizer='adam', 
    metrics=[fbeta, 'accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 48, 48, 64)        640
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 48, 48, 64)        256
# _________________________________________________________________
# activation_1 (Activation)    (None, 48, 48, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 128)       204928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 24, 24, 128)       512
# _________________________________________________________________
# activation_2 (Activation)    (None, 24, 24, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 12, 12, 512)       590336
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 12, 12, 512)       2048
# _________________________________________________________________
# activation_3 (Activation)    (None, 12, 12, 512)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 6, 6, 512)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 6, 6, 512)         2359808
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 6, 6, 512)         2048
# _________________________________________________________________
# activation_4 (Activation)    (None, 6, 6, 512)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               1179904
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_5 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               131584
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_6 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 3591
# _________________________________________________________________
# activation_7 (Activation)    (None, 7)                 0
# =================================================================
# Total params: 4,478,727
# Trainable params: 4,474,759
# Non-trainable params: 3,968
# _________________________________________________________________

# %%
'''
Training
'''
train_flow = datagen.flow(X_train, y_train, batch_size=BATCH_SIZE)
validation_flow = datagen.flow(X_validation, y_validation)

history = model.fit_generator(
    train_flow,
    steps_per_epoch= num_train / BATCH_SIZE,
    epochs=NUM_EPOCHS,
    verbose=1,
    validation_data=validation_flow,
    validation_steps=num_validation / BATCH_SIZE,
    callbacks=[checkpointer, reduce_lr, checkpointer]
)
# Out:
# Epoch 1/128
# 225/224 [==============================] - 33s 146ms/step - loss: 1.6995 - fbeta: 0.1761 - acc: 0.3559 - val_loss: 1.6805 - val_fbeta: 0.2037 - val_acc: 0.3502
#
# Epoch 00001: saving model to Model.01-0.3502.hdf5
#
# Epoch 00001: saving model to Model.01-0.3502.hdf5
# Epoch 2/128
# 225/224 [==============================] - 27s 118ms/step - loss: 1.3621 - fbeta: 0.2819 - acc: 0.4797 - val_loss: 1.4292 - val_fbeta: 0.3136 - val_acc: 0.4784
#
# Epoch 00002: saving model to Model.02-0.4784.hdf5
#
# Epoch 00002: saving model to Model.02-0.4784.hdf5
# Epoch 3/128
# 225/224 [==============================] - 27s 118ms/step - loss: 1.2422 - fbeta: 0.3310 - acc: 0.5249 - val_loss: 1.2636 - val_fbeta: 0.2974 - val_acc: 0.5248
#
# Epoch 00003: saving model to Model.03-0.5248.hdf5
#
# Epoch 00003: saving model to Model.03-0.5248.hdf5
# Epoch 4/128
# 225/224 [==============================] - 27s 119ms/step - loss: 1.1827 - fbeta: 0.3613 - acc: 0.5491 - val_loss: 1.1940 - val_fbeta: 0.3263 - val_acc: 0.5416
#
# Epoch 00004: saving model to Model.04-0.5416.hdf5
#
# Epoch 00004: saving model to Model.04-0.5416.hdf5
# Epoch 5/128
# 225/224 [==============================] - 27s 118ms/step - loss: 1.1289 - fbeta: 0.3909 - acc: 0.5712 - val_loss: 1.1867 - val_fbeta: 0.3772 - val_acc: 0.5474
#
# Epoch 00005: saving model to Model.05-0.5474.hdf5
#
# Epoch 00005: saving model to Model.05-0.5474.hdf5
# Epoch 6/128
# 225/224 [==============================] - 27s 118ms/step - loss: 1.1008 - fbeta: 0.4141 - acc: 0.5808 - val_loss: 1.2488 - val_fbeta: 0.3793 - val_acc: 0.5345
#
# Epoch 00006: saving model to Model.06-0.5345.hdf5
#
# Epoch 00006: saving model to Model.06-0.5345.hdf5
# Epoch 7/128
# 225/224 [==============================] - 27s 118ms/step - loss: 1.0648 - fbeta: 0.4313 - acc: 0.5983 - val_loss: 1.1814 - val_fbeta: 0.4246 - val_acc: 0.5420
#
# Epoch 00007: saving model to Model.07-0.5420.hdf5
#
# Epoch 00007: saving model to Model.07-0.5420.hdf5
# Epoch 8/128
# 225/224 [==============================] - 27s 118ms/step - loss: 1.0316 - fbeta: 0.4531 - acc: 0.6077 - val_loss: 1.1459 - val_fbeta: 0.3907 - val_acc: 0.5549
#
# Epoch 00008: saving model to Model.08-0.5549.hdf5
#
# Epoch 00008: saving model to Model.08-0.5549.hdf5
# Epoch 9/128
# 225/224 [==============================] - 27s 118ms/step - loss: 1.0107 - fbeta: 0.4681 - acc: 0.6171 - val_loss: 1.2309 - val_fbeta: 0.4353 - val_acc: 0.5582
#
# Epoch 00009: saving model to Model.09-0.5582.hdf5
#
# Epoch 00009: saving model to Model.09-0.5582.hdf5
# Epoch 10/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.9819 - fbeta: 0.4853 - acc: 0.6280 - val_loss: 1.0888 - val_fbeta: 0.4407 - val_acc: 0.5916
#
# Epoch 00010: saving model to Model.10-0.5916.hdf5
#
# Epoch 00010: saving model to Model.10-0.5916.hdf5
# Epoch 11/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.9632 - fbeta: 0.4983 - acc: 0.6368 - val_loss: 1.0896 - val_fbeta: 0.4677 - val_acc: 0.5938
#
# Epoch 00011: saving model to Model.11-0.5938.hdf5
#
# Epoch 00011: saving model to Model.11-0.5938.hdf5
# Epoch 12/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.9385 - fbeta: 0.5148 - acc: 0.6467 - val_loss: 1.2043 - val_fbeta: 0.4395 - val_acc: 0.5549
#
# Epoch 00012: saving model to Model.12-0.5549.hdf5
#
# Epoch 00012: saving model to Model.12-0.5549.hdf5
# Epoch 13/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.9147 - fbeta: 0.5304 - acc: 0.6547 - val_loss: 1.2536 - val_fbeta: 0.4418 - val_acc: 0.5366
#
# Epoch 00013: saving model to Model.13-0.5366.hdf5
#
# Epoch 00013: saving model to Model.13-0.5366.hdf5
# Epoch 14/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.8873 - fbeta: 0.5445 - acc: 0.6636 - val_loss: 1.0616 - val_fbeta: 0.4731 - val_acc: 0.6034
#
# Epoch 00014: saving model to Model.14-0.6034.hdf5
#
# Epoch 00014: saving model to Model.14-0.6034.hdf5
# Epoch 15/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.8687 - fbeta: 0.5610 - acc: 0.6758 - val_loss: 1.0659 - val_fbeta: 0.4731 - val_acc: 0.6131
#
# Epoch 00015: saving model to Model.15-0.6131.hdf5
#
# Epoch 00015: saving model to Model.15-0.6131.hdf5
# Epoch 16/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.8513 - fbeta: 0.5716 - acc: 0.6817 - val_loss: 1.0529 - val_fbeta: 0.5139 - val_acc: 0.5927
#
# Epoch 00016: saving model to Model.16-0.5927.hdf5
#
# Epoch 00016: saving model to Model.16-0.5927.hdf5
# Epoch 17/128
# 225/224 [==============================] - 27s 119ms/step - loss: 0.8272 - fbeta: 0.5862 - acc: 0.6924 - val_loss: 1.0561 - val_fbeta: 0.4828 - val_acc: 0.6002
#
# Epoch 00017: saving model to Model.17-0.6002.hdf5
#
# Epoch 00017: saving model to Model.17-0.6002.hdf5
# Epoch 18/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.8072 - fbeta: 0.5993 - acc: 0.6978 - val_loss: 1.1052 - val_fbeta: 0.4989 - val_acc: 0.6088
#
# Epoch 00018: saving model to Model.18-0.6088.hdf5
#
# Epoch 00018: saving model to Model.18-0.6088.hdf5
# Epoch 19/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.7906 - fbeta: 0.6108 - acc: 0.7043 - val_loss: 1.1225 - val_fbeta: 0.5560 - val_acc: 0.6142
#
# Epoch 00019: saving model to Model.19-0.6142.hdf5
#
# Epoch 00019: saving model to Model.19-0.6142.hdf5
# Epoch 20/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.7664 - fbeta: 0.6224 - acc: 0.7137 - val_loss: 1.0189 - val_fbeta: 0.5494 - val_acc: 0.6371
#
# Epoch 00020: saving model to Model.20-0.6371.hdf5
#
# Epoch 00020: saving model to Model.20-0.6371.hdf5
# Epoch 21/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.7388 - fbeta: 0.6393 - acc: 0.7235 - val_loss: 1.1827 - val_fbeta: 0.5119 - val_acc: 0.5851
#
# Epoch 00021: saving model to Model.21-0.5851.hdf5
#
# Epoch 00021: saving model to Model.21-0.5851.hdf5
# Epoch 22/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.7266 - fbeta: 0.6490 - acc: 0.7277 - val_loss: 1.1361 - val_fbeta: 0.5075 - val_acc: 0.5927
#
# Epoch 00022: saving model to Model.22-0.5927.hdf5
#
# Epoch 00022: saving model to Model.22-0.5927.hdf5
# Epoch 23/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.6950 - fbeta: 0.6654 - acc: 0.7415 - val_loss: 1.0343 - val_fbeta: 0.5409 - val_acc: 0.6401
#
# Epoch 00023: saving model to Model.23-0.6401.hdf5
#
# Epoch 00023: saving model to Model.23-0.6401.hdf5
# Epoch 24/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.6773 - fbeta: 0.6789 - acc: 0.7491 - val_loss: 1.0911 - val_fbeta: 0.5383 - val_acc: 0.6115
#
# Epoch 00024: saving model to Model.24-0.6115.hdf5
#
# Epoch 00024: saving model to Model.24-0.6115.hdf5
# Epoch 25/128
# 225/224 [==============================] - 27s 119ms/step - loss: 0.6487 - fbeta: 0.6951 - acc: 0.7602 - val_loss: 1.1264 - val_fbeta: 0.5657 - val_acc: 0.6250
#
# Epoch 00025: saving model to Model.25-0.6250.hdf5
#
# Epoch 00025: saving model to Model.25-0.6250.hdf5
# Epoch 26/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.6388 - fbeta: 0.7025 - acc: 0.7647 - val_loss: 1.1470 - val_fbeta: 0.5571 - val_acc: 0.6110
#
# Epoch 00026: saving model to Model.26-0.6110.hdf5
#
# Epoch 00026: saving model to Model.26-0.6110.hdf5
# Epoch 27/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.6098 - fbeta: 0.7174 - acc: 0.7737 - val_loss: 1.6480 - val_fbeta: 0.4397 - val_acc: 0.4849
#
# Epoch 00027: saving model to Model.27-0.4849.hdf5
#
# Epoch 00027: saving model to Model.27-0.4849.hdf5
# Epoch 28/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.5963 - fbeta: 0.7223 - acc: 0.7781 - val_loss: 1.1547 - val_fbeta: 0.5827 - val_acc: 0.6193
#
# Epoch 00028: saving model to Model.28-0.6193.hdf5
#
# Epoch 00028: saving model to Model.28-0.6193.hdf5
# Epoch 29/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.5646 - fbeta: 0.7398 - acc: 0.7914 - val_loss: 1.2217 - val_fbeta: 0.5248 - val_acc: 0.6121
#
# Epoch 00029: saving model to Model.29-0.6121.hdf5
#
# Epoch 00029: saving model to Model.29-0.6121.hdf5
# Epoch 30/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.5582 - fbeta: 0.7453 - acc: 0.7939 - val_loss: 1.1662 - val_fbeta: 0.5603 - val_acc: 0.6099
#
# Epoch 00030: saving model to Model.30-0.6099.hdf5
#
# Epoch 00030: saving model to Model.30-0.6099.hdf5
# Epoch 31/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.4767 - fbeta: 0.7820 - acc: 0.8253 - val_loss: 1.0436 - val_fbeta: 0.6164 - val_acc: 0.6638
#
# Epoch 00031: saving model to Model.31-0.6638.hdf5
#
# Epoch 00031: saving model to Model.31-0.6638.hdf5
# Epoch 32/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.4517 - fbeta: 0.7979 - acc: 0.8389 - val_loss: 1.0600 - val_fbeta: 0.6149 - val_acc: 0.6593
#
# Epoch 00032: saving model to Model.32-0.6593.hdf5
#
# Epoch 00032: saving model to Model.32-0.6593.hdf5
# Epoch 33/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.4388 - fbeta: 0.8036 - acc: 0.8403 - val_loss: 1.0370 - val_fbeta: 0.6336 - val_acc: 0.6735
#
# Epoch 00033: saving model to Model.33-0.6735.hdf5
#
# Epoch 00033: saving model to Model.33-0.6735.hdf5
# Epoch 34/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.4262 - fbeta: 0.8105 - acc: 0.8451 - val_loss: 1.0711 - val_fbeta: 0.6218 - val_acc: 0.6573
#
# Epoch 00034: saving model to Model.34-0.6573.hdf5
#
# Epoch 00034: saving model to Model.34-0.6573.hdf5
# Epoch 35/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.4149 - fbeta: 0.8177 - acc: 0.8494 - val_loss: 1.0748 - val_fbeta: 0.6358 - val_acc: 0.6821
#
# Epoch 00035: saving model to Model.35-0.6821.hdf5
#
# Epoch 00035: saving model to Model.35-0.6821.hdf5
# Epoch 36/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.4084 - fbeta: 0.8187 - acc: 0.8493 - val_loss: 1.0910 - val_fbeta: 0.6271 - val_acc: 0.6593
#
# Epoch 00036: saving model to Model.36-0.6593.hdf5
#
# Epoch 00036: saving model to Model.36-0.6593.hdf5
# Epoch 37/128
# 225/224 [==============================] - 27s 119ms/step - loss: 0.3988 - fbeta: 0.8283 - acc: 0.8582 - val_loss: 1.1397 - val_fbeta: 0.6250 - val_acc: 0.6606
#
# Epoch 00037: saving model to Model.37-0.6606.hdf5
#
# Epoch 00037: saving model to Model.37-0.6606.hdf5
# Epoch 38/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3863 - fbeta: 0.8301 - acc: 0.8609 - val_loss: 1.0797 - val_fbeta: 0.6325 - val_acc: 0.6616
#
# Epoch 00038: saving model to Model.38-0.6616.hdf5
#
# Epoch 00038: saving model to Model.38-0.6616.hdf5
# Epoch 39/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3799 - fbeta: 0.8337 - acc: 0.8634 - val_loss: 1.1350 - val_fbeta: 0.6482 - val_acc: 0.6792
#
# Epoch 00039: saving model to Model.39-0.6792.hdf5
#
# Epoch 00039: saving model to Model.39-0.6792.hdf5
# Epoch 40/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3759 - fbeta: 0.8361 - acc: 0.8626 - val_loss: 1.1775 - val_fbeta: 0.6573 - val_acc: 0.6756
#
# Epoch 00040: saving model to Model.40-0.6756.hdf5
#
# Epoch 00040: saving model to Model.40-0.6756.hdf5
# Epoch 41/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3645 - fbeta: 0.8404 - acc: 0.8664 - val_loss: 1.0928 - val_fbeta: 0.6498 - val_acc: 0.6832
#
# Epoch 00041: saving model to Model.41-0.6832.hdf5
#
# Epoch 00041: saving model to Model.41-0.6832.hdf5
# Epoch 42/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3681 - fbeta: 0.8396 - acc: 0.8655 - val_loss: 1.1108 - val_fbeta: 0.6379 - val_acc: 0.6692
#
# Epoch 00042: saving model to Model.42-0.6692.hdf5
#
# Epoch 00042: saving model to Model.42-0.6692.hdf5
# Epoch 43/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3602 - fbeta: 0.8430 - acc: 0.8688 - val_loss: 1.0858 - val_fbeta: 0.6559 - val_acc: 0.6859
#
# Epoch 00043: saving model to Model.43-0.6859.hdf5
#
# Epoch 00043: saving model to Model.43-0.6859.hdf5
# Epoch 44/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3642 - fbeta: 0.8409 - acc: 0.8664 - val_loss: 1.1621 - val_fbeta: 0.6412 - val_acc: 0.6703
#
# Epoch 00044: saving model to Model.44-0.6703.hdf5
#
# Epoch 00044: saving model to Model.44-0.6703.hdf5
# Epoch 45/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3623 - fbeta: 0.8437 - acc: 0.8688 - val_loss: 1.0820 - val_fbeta: 0.6498 - val_acc: 0.6875
#
# Epoch 00045: saving model to Model.45-0.6875.hdf5
#
# Epoch 00045: saving model to Model.45-0.6875.hdf5
# Epoch 46/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3624 - fbeta: 0.8423 - acc: 0.8666 - val_loss: 1.2224 - val_fbeta: 0.6142 - val_acc: 0.6444
#
# Epoch 00046: saving model to Model.46-0.6444.hdf5
#
# Epoch 00046: saving model to Model.46-0.6444.hdf5
# Epoch 47/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3546 - fbeta: 0.8465 - acc: 0.8729 - val_loss: 1.1744 - val_fbeta: 0.6260 - val_acc: 0.6559
#
# Epoch 00047: saving model to Model.47-0.6559.hdf5
#
# Epoch 00047: saving model to Model.47-0.6559.hdf5
# Epoch 48/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3619 - fbeta: 0.8427 - acc: 0.8669 - val_loss: 1.0910 - val_fbeta: 0.6713 - val_acc: 0.6994
#
# Epoch 00048: saving model to Model.48-0.6994.hdf5
#
# Epoch 00048: saving model to Model.48-0.6994.hdf5
# Epoch 49/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3582 - fbeta: 0.8447 - acc: 0.8674 - val_loss: 1.0273 - val_fbeta: 0.6487 - val_acc: 0.6875
#
# Epoch 00049: saving model to Model.49-0.6875.hdf5
#
# Epoch 00049: saving model to Model.49-0.6875.hdf5
# Epoch 50/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3555 - fbeta: 0.8457 - acc: 0.8712 - val_loss: 1.1587 - val_fbeta: 0.6228 - val_acc: 0.6509
#
# Epoch 00050: saving model to Model.50-0.6509.hdf5
#
# Epoch 00050: saving model to Model.50-0.6509.hdf5
# Epoch 51/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3553 - fbeta: 0.8440 - acc: 0.8698 - val_loss: 1.2105 - val_fbeta: 0.6260 - val_acc: 0.6615
#
# Epoch 00051: saving model to Model.51-0.6615.hdf5
#
# Epoch 00051: saving model to Model.51-0.6615.hdf5
# Epoch 52/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3560 - fbeta: 0.8450 - acc: 0.8687 - val_loss: 1.0915 - val_fbeta: 0.6498 - val_acc: 0.6907
#
# Epoch 00052: saving model to Model.52-0.6907.hdf5
#
# Epoch 00052: saving model to Model.52-0.6907.hdf5
# Epoch 53/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3550 - fbeta: 0.8448 - acc: 0.8690 - val_loss: 1.1161 - val_fbeta: 0.6412 - val_acc: 0.6724
#
# Epoch 00053: saving model to Model.53-0.6724.hdf5
#
# Epoch 00053: saving model to Model.53-0.6724.hdf5
# Epoch 54/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3541 - fbeta: 0.8468 - acc: 0.8736 - val_loss: 1.0926 - val_fbeta: 0.6466 - val_acc: 0.6843
#
# Epoch 00054: saving model to Model.54-0.6843.hdf5
#
# Epoch 00054: saving model to Model.54-0.6843.hdf5
# Epoch 55/128
# 225/224 [==============================] - 26s 118ms/step - loss: 0.3509 - fbeta: 0.8481 - acc: 0.8732 - val_loss: 1.1426 - val_fbeta: 0.6504 - val_acc: 0.6826
#
# Epoch 00055: saving model to Model.55-0.6826.hdf5
#
# Epoch 00055: saving model to Model.55-0.6826.hdf5
# Epoch 56/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3518 - fbeta: 0.8462 - acc: 0.8694 - val_loss: 1.1438 - val_fbeta: 0.6293 - val_acc: 0.6638
#
# Epoch 00056: saving model to Model.56-0.6638.hdf5
#
# Epoch 00056: saving model to Model.56-0.6638.hdf5
# Epoch 57/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3488 - fbeta: 0.8468 - acc: 0.8711 - val_loss: 1.0814 - val_fbeta: 0.6379 - val_acc: 0.6681
#
# Epoch 00057: saving model to Model.57-0.6681.hdf5
#
# Epoch 00057: saving model to Model.57-0.6681.hdf5
# Epoch 58/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3505 - fbeta: 0.8464 - acc: 0.8720 - val_loss: 1.1280 - val_fbeta: 0.6509 - val_acc: 0.6832
#
# Epoch 00058: saving model to Model.58-0.6832.hdf5
#
# Epoch 00058: saving model to Model.58-0.6832.hdf5
# Epoch 59/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3525 - fbeta: 0.8478 - acc: 0.8715 - val_loss: 1.1073 - val_fbeta: 0.6337 - val_acc: 0.6670
#
# Epoch 00059: saving model to Model.59-0.6670.hdf5
#
# Epoch 00059: saving model to Model.59-0.6670.hdf5
# Epoch 60/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3497 - fbeta: 0.8476 - acc: 0.8725 - val_loss: 1.2011 - val_fbeta: 0.6444 - val_acc: 0.6659
#
# Epoch 00060: saving model to Model.60-0.6659.hdf5
#
# Epoch 00060: saving model to Model.60-0.6659.hdf5
# Epoch 61/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3537 - fbeta: 0.8464 - acc: 0.8701 - val_loss: 1.1069 - val_fbeta: 0.6261 - val_acc: 0.6638
#
# Epoch 00061: saving model to Model.61-0.6638.hdf5
#
# Epoch 00061: saving model to Model.61-0.6638.hdf5
# Epoch 62/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3513 - fbeta: 0.8489 - acc: 0.8726 - val_loss: 1.0990 - val_fbeta: 0.6573 - val_acc: 0.6940
#
# Epoch 00062: saving model to Model.62-0.6940.hdf5
#
# Epoch 00062: saving model to Model.62-0.6940.hdf5
# Epoch 63/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3482 - fbeta: 0.8489 - acc: 0.8730 - val_loss: 1.1591 - val_fbeta: 0.6160 - val_acc: 0.6504
#
# Epoch 00063: saving model to Model.63-0.6504.hdf5
#
# Epoch 00063: saving model to Model.63-0.6504.hdf5
# Epoch 64/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3518 - fbeta: 0.8465 - acc: 0.8717 - val_loss: 1.0978 - val_fbeta: 0.6369 - val_acc: 0.6681
#
# Epoch 00064: saving model to Model.64-0.6681.hdf5
#
# Epoch 00064: saving model to Model.64-0.6681.hdf5
# Epoch 65/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3506 - fbeta: 0.8496 - acc: 0.8739 - val_loss: 1.1649 - val_fbeta: 0.6390 - val_acc: 0.6746
#
# Epoch 00065: saving model to Model.65-0.6746.hdf5
#
# Epoch 00065: saving model to Model.65-0.6746.hdf5
# Epoch 66/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3534 - fbeta: 0.8482 - acc: 0.8709 - val_loss: 1.1057 - val_fbeta: 0.6595 - val_acc: 0.6810
#
# Epoch 00066: saving model to Model.66-0.6810.hdf5
#
# Epoch 00066: saving model to Model.66-0.6810.hdf5
# Epoch 67/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3520 - fbeta: 0.8473 - acc: 0.8707 - val_loss: 1.1289 - val_fbeta: 0.6415 - val_acc: 0.6804
#
# Epoch 00067: saving model to Model.67-0.6804.hdf5
#
# Epoch 00067: saving model to Model.67-0.6804.hdf5
# Epoch 68/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3591 - fbeta: 0.8450 - acc: 0.8690 - val_loss: 1.1690 - val_fbeta: 0.6304 - val_acc: 0.6670
#
# Epoch 00068: saving model to Model.68-0.6670.hdf5
#
# Epoch 00068: saving model to Model.68-0.6670.hdf5
# Epoch 69/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3514 - fbeta: 0.8478 - acc: 0.8727 - val_loss: 1.1575 - val_fbeta: 0.6444 - val_acc: 0.6756
#
# Epoch 00069: saving model to Model.69-0.6756.hdf5
#
# Epoch 00069: saving model to Model.69-0.6756.hdf5
# Epoch 70/128
# 225/224 [==============================] - 27s 119ms/step - loss: 0.3523 - fbeta: 0.8469 - acc: 0.8695 - val_loss: 1.0983 - val_fbeta: 0.6422 - val_acc: 0.6789
#
# Epoch 00070: saving model to Model.70-0.6789.hdf5
#
# Epoch 00070: saving model to Model.70-0.6789.hdf5
# Epoch 71/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3556 - fbeta: 0.8457 - acc: 0.8692 - val_loss: 1.1419 - val_fbeta: 0.6315 - val_acc: 0.6726
#
# Epoch 00071: saving model to Model.71-0.6726.hdf5
#
# Epoch 00071: saving model to Model.71-0.6726.hdf5
# Epoch 72/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3518 - fbeta: 0.8476 - acc: 0.8721 - val_loss: 1.0275 - val_fbeta: 0.6638 - val_acc: 0.6994
#
# Epoch 00072: saving model to Model.72-0.6994.hdf5
#
# Epoch 00072: saving model to Model.72-0.6994.hdf5
# Epoch 73/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3573 - fbeta: 0.8451 - acc: 0.8699 - val_loss: 1.2203 - val_fbeta: 0.6088 - val_acc: 0.6412
#
# Epoch 00073: saving model to Model.73-0.6412.hdf5
#
# Epoch 00073: saving model to Model.73-0.6412.hdf5
# Epoch 74/128
# 225/224 [==============================] - 27s 119ms/step - loss: 0.3613 - fbeta: 0.8461 - acc: 0.8702 - val_loss: 1.1131 - val_fbeta: 0.6369 - val_acc: 0.6724
#
# Epoch 00074: saving model to Model.74-0.6724.hdf5
#
# Epoch 00074: saving model to Model.74-0.6724.hdf5
# Epoch 75/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3586 - fbeta: 0.8459 - acc: 0.8696 - val_loss: 1.1689 - val_fbeta: 0.6393 - val_acc: 0.6681
#
# Epoch 00075: saving model to Model.75-0.6681.hdf5
#
# Epoch 00075: saving model to Model.75-0.6681.hdf5
# Epoch 76/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3502 - fbeta: 0.8476 - acc: 0.8732 - val_loss: 1.0898 - val_fbeta: 0.6519 - val_acc: 0.6778
#
# Epoch 00076: saving model to Model.76-0.6778.hdf5
#
# Epoch 00076: saving model to Model.76-0.6778.hdf5
# Epoch 77/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3517 - fbeta: 0.8473 - acc: 0.8731 - val_loss: 1.1459 - val_fbeta: 0.6401 - val_acc: 0.6746
#
# Epoch 00077: saving model to Model.77-0.6746.hdf5
#
# Epoch 00077: saving model to Model.77-0.6746.hdf5
# Epoch 78/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3561 - fbeta: 0.8441 - acc: 0.8700 - val_loss: 1.2111 - val_fbeta: 0.6171 - val_acc: 0.6548
#
# Epoch 00078: saving model to Model.78-0.6548.hdf5
#
# Epoch 00078: saving model to Model.78-0.6548.hdf5
# Epoch 79/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3590 - fbeta: 0.8452 - acc: 0.8694 - val_loss: 1.2147 - val_fbeta: 0.6196 - val_acc: 0.6562
#
# Epoch 00079: saving model to Model.79-0.6562.hdf5
#
# Epoch 00079: saving model to Model.79-0.6562.hdf5
# Epoch 80/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3446 - fbeta: 0.8502 - acc: 0.8750 - val_loss: 1.1256 - val_fbeta: 0.6282 - val_acc: 0.6713
#
# Epoch 00080: saving model to Model.80-0.6713.hdf5
#
# Epoch 00080: saving model to Model.80-0.6713.hdf5
# Epoch 81/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3561 - fbeta: 0.8457 - acc: 0.8692 - val_loss: 1.1808 - val_fbeta: 0.6466 - val_acc: 0.6724
#
# Epoch 00081: saving model to Model.81-0.6724.hdf5
#
# Epoch 00081: saving model to Model.81-0.6724.hdf5
# Epoch 82/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3542 - fbeta: 0.8452 - acc: 0.8711 - val_loss: 1.0129 - val_fbeta: 0.6582 - val_acc: 0.6759
#
# Epoch 00082: saving model to Model.82-0.6759.hdf5
#
# Epoch 00082: saving model to Model.82-0.6759.hdf5
# Epoch 83/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3518 - fbeta: 0.8471 - acc: 0.8724 - val_loss: 1.2211 - val_fbeta: 0.6185 - val_acc: 0.6401
#
# Epoch 00083: saving model to Model.83-0.6401.hdf5
#
# Epoch 00083: saving model to Model.83-0.6401.hdf5
# Epoch 84/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3534 - fbeta: 0.8434 - acc: 0.8693 - val_loss: 1.1083 - val_fbeta: 0.6509 - val_acc: 0.6897
#
# Epoch 00084: saving model to Model.84-0.6897.hdf5
#
# Epoch 00084: saving model to Model.84-0.6897.hdf5
# Epoch 85/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3499 - fbeta: 0.8487 - acc: 0.8728 - val_loss: 1.1557 - val_fbeta: 0.6422 - val_acc: 0.6746
#
# Epoch 00085: saving model to Model.85-0.6746.hdf5
#
# Epoch 00085: saving model to Model.85-0.6746.hdf5
# Epoch 86/128
# 225/224 [==============================] - 27s 119ms/step - loss: 0.3532 - fbeta: 0.8456 - acc: 0.8708 - val_loss: 1.0264 - val_fbeta: 0.6604 - val_acc: 0.7003
#
# Epoch 00086: saving model to Model.86-0.7003.hdf5
#
# Epoch 00086: saving model to Model.86-0.7003.hdf5
# Epoch 87/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3517 - fbeta: 0.8469 - acc: 0.8698 - val_loss: 1.0478 - val_fbeta: 0.6595 - val_acc: 0.6897
#
# Epoch 00087: saving model to Model.87-0.6897.hdf5
#
# Epoch 00087: saving model to Model.87-0.6897.hdf5
# Epoch 88/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3515 - fbeta: 0.8490 - acc: 0.8720 - val_loss: 1.1925 - val_fbeta: 0.6218 - val_acc: 0.6670
#
# Epoch 00088: saving model to Model.88-0.6670.hdf5
#
# Epoch 00088: saving model to Model.88-0.6670.hdf5
# Epoch 89/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3574 - fbeta: 0.8449 - acc: 0.8694 - val_loss: 1.2017 - val_fbeta: 0.6153 - val_acc: 0.6519
#
# Epoch 00089: saving model to Model.89-0.6519.hdf5
#
# Epoch 00089: saving model to Model.89-0.6519.hdf5
# Epoch 90/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3554 - fbeta: 0.8445 - acc: 0.8706 - val_loss: 1.0521 - val_fbeta: 0.6570 - val_acc: 0.6937
#
# Epoch 00090: saving model to Model.90-0.6937.hdf5
#
# Epoch 00090: saving model to Model.90-0.6937.hdf5
# Epoch 91/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3598 - fbeta: 0.8445 - acc: 0.8692 - val_loss: 1.0596 - val_fbeta: 0.6616 - val_acc: 0.6907
#
# Epoch 00091: saving model to Model.91-0.6907.hdf5
#
# Epoch 00091: saving model to Model.91-0.6907.hdf5
# Epoch 92/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3587 - fbeta: 0.8445 - acc: 0.8683 - val_loss: 1.1376 - val_fbeta: 0.6142 - val_acc: 0.6509
#
# Epoch 00092: saving model to Model.92-0.6509.hdf5
#
# Epoch 00092: saving model to Model.92-0.6509.hdf5
# Epoch 93/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3557 - fbeta: 0.8461 - acc: 0.8707 - val_loss: 1.1359 - val_fbeta: 0.6444 - val_acc: 0.6746
#
# Epoch 00093: saving model to Model.93-0.6746.hdf5
#
# Epoch 00093: saving model to Model.93-0.6746.hdf5
# Epoch 94/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3534 - fbeta: 0.8465 - acc: 0.8724 - val_loss: 1.2786 - val_fbeta: 0.6049 - val_acc: 0.6482
#
# Epoch 00094: saving model to Model.94-0.6482.hdf5
#
# Epoch 00094: saving model to Model.94-0.6482.hdf5
# Epoch 95/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3563 - fbeta: 0.8433 - acc: 0.8678 - val_loss: 1.1647 - val_fbeta: 0.6336 - val_acc: 0.6681
#
# Epoch 00095: saving model to Model.95-0.6681.hdf5
#
# Epoch 00095: saving model to Model.95-0.6681.hdf5
# Epoch 96/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3532 - fbeta: 0.8456 - acc: 0.8694 - val_loss: 1.1122 - val_fbeta: 0.6573 - val_acc: 0.6994
#
# Epoch 00096: saving model to Model.96-0.6994.hdf5
#
# Epoch 00096: saving model to Model.96-0.6994.hdf5
# Epoch 97/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3513 - fbeta: 0.8482 - acc: 0.8722 - val_loss: 1.0148 - val_fbeta: 0.6552 - val_acc: 0.6821
#
# Epoch 00097: saving model to Model.97-0.6821.hdf5
#
# Epoch 00097: saving model to Model.97-0.6821.hdf5
# Epoch 98/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3562 - fbeta: 0.8446 - acc: 0.8702 - val_loss: 1.1875 - val_fbeta: 0.6404 - val_acc: 0.6704
#
# Epoch 00098: saving model to Model.98-0.6704.hdf5
#
# Epoch 00098: saving model to Model.98-0.6704.hdf5
# Epoch 99/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3576 - fbeta: 0.8483 - acc: 0.8704 - val_loss: 1.1137 - val_fbeta: 0.6498 - val_acc: 0.6886
#
# Epoch 00099: saving model to Model.99-0.6886.hdf5
#
# Epoch 00099: saving model to Model.99-0.6886.hdf5
# Epoch 100/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3480 - fbeta: 0.8490 - acc: 0.8735 - val_loss: 1.0933 - val_fbeta: 0.6627 - val_acc: 0.6864
#
# Epoch 00100: saving model to Model.100-0.6864.hdf5
#
# Epoch 00100: saving model to Model.100-0.6864.hdf5
# Epoch 101/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3446 - fbeta: 0.8484 - acc: 0.8749 - val_loss: 1.2058 - val_fbeta: 0.6131 - val_acc: 0.6519
#
# Epoch 00101: saving model to Model.101-0.6519.hdf5
#
# Epoch 00101: saving model to Model.101-0.6519.hdf5
# Epoch 102/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3508 - fbeta: 0.8474 - acc: 0.8717 - val_loss: 0.9658 - val_fbeta: 0.6626 - val_acc: 0.6992
#
# Epoch 00102: saving model to Model.102-0.6992.hdf5
#
# Epoch 00102: saving model to Model.102-0.6992.hdf5
# Epoch 103/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3536 - fbeta: 0.8469 - acc: 0.8705 - val_loss: 1.1831 - val_fbeta: 0.6272 - val_acc: 0.6552
#
# Epoch 00103: saving model to Model.103-0.6552.hdf5
#
# Epoch 00103: saving model to Model.103-0.6552.hdf5
# Epoch 104/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3570 - fbeta: 0.8443 - acc: 0.8690 - val_loss: 1.1398 - val_fbeta: 0.6412 - val_acc: 0.6638
#
# Epoch 00104: saving model to Model.104-0.6638.hdf5
#
# Epoch 00104: saving model to Model.104-0.6638.hdf5
# Epoch 105/128
# 225/224 [==============================] - 27s 119ms/step - loss: 0.3569 - fbeta: 0.8449 - acc: 0.8694 - val_loss: 1.1537 - val_fbeta: 0.6304 - val_acc: 0.6649
#
# Epoch 00105: saving model to Model.105-0.6649.hdf5
#
# Epoch 00105: saving model to Model.105-0.6649.hdf5
# Epoch 106/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3614 - fbeta: 0.8434 - acc: 0.8680 - val_loss: 1.1714 - val_fbeta: 0.6304 - val_acc: 0.6704
#
# Epoch 00106: saving model to Model.106-0.6704.hdf5
#
# Epoch 00106: saving model to Model.106-0.6704.hdf5
# Epoch 107/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3583 - fbeta: 0.8431 - acc: 0.8684 - val_loss: 1.1582 - val_fbeta: 0.6433 - val_acc: 0.6832
#
# Epoch 00107: saving model to Model.107-0.6832.hdf5
#
# Epoch 00107: saving model to Model.107-0.6832.hdf5
# Epoch 108/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3529 - fbeta: 0.8497 - acc: 0.8740 - val_loss: 1.1569 - val_fbeta: 0.6412 - val_acc: 0.6606
#
# Epoch 00108: saving model to Model.108-0.6606.hdf5
#
# Epoch 00108: saving model to Model.108-0.6606.hdf5
# Epoch 109/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3569 - fbeta: 0.8430 - acc: 0.8699 - val_loss: 1.0831 - val_fbeta: 0.6455 - val_acc: 0.6800
#
# Epoch 00109: saving model to Model.109-0.6800.hdf5
#
# Epoch 00109: saving model to Model.109-0.6800.hdf5
# Epoch 110/128
# 225/224 [==============================] - 27s 119ms/step - loss: 0.3585 - fbeta: 0.8438 - acc: 0.8689 - val_loss: 1.0504 - val_fbeta: 0.6515 - val_acc: 0.6804
#
# Epoch 00110: saving model to Model.110-0.6804.hdf5
#
# Epoch 00110: saving model to Model.110-0.6804.hdf5
# Epoch 111/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3546 - fbeta: 0.8470 - acc: 0.8712 - val_loss: 1.2082 - val_fbeta: 0.6282 - val_acc: 0.6627
#
# Epoch 00111: saving model to Model.111-0.6627.hdf5
#
# Epoch 00111: saving model to Model.111-0.6627.hdf5
# Epoch 112/128
# 225/224 [==============================] - 27s 119ms/step - loss: 0.3544 - fbeta: 0.8485 - acc: 0.8719 - val_loss: 1.2141 - val_fbeta: 0.6250 - val_acc: 0.6562
#
# Epoch 00112: saving model to Model.112-0.6562.hdf5
#
# Epoch 00112: saving model to Model.112-0.6562.hdf5
# Epoch 113/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3544 - fbeta: 0.8455 - acc: 0.8698 - val_loss: 1.0865 - val_fbeta: 0.6382 - val_acc: 0.6737
#
# Epoch 00113: saving model to Model.113-0.6737.hdf5
#
# Epoch 00113: saving model to Model.113-0.6737.hdf5
# Epoch 114/128
# 225/224 [==============================] - 27s 119ms/step - loss: 0.3499 - fbeta: 0.8457 - acc: 0.8703 - val_loss: 1.0809 - val_fbeta: 0.6552 - val_acc: 0.6940
#
# Epoch 00114: saving model to Model.114-0.6940.hdf5
#
# Epoch 00114: saving model to Model.114-0.6940.hdf5
# Epoch 115/128
# 225/224 [==============================] - 27s 119ms/step - loss: 0.3613 - fbeta: 0.8407 - acc: 0.8661 - val_loss: 1.2533 - val_fbeta: 0.6078 - val_acc: 0.6455
#
# Epoch 00115: saving model to Model.115-0.6455.hdf5
#
# Epoch 00115: saving model to Model.115-0.6455.hdf5
# Epoch 116/128
# 225/224 [==============================] - 27s 119ms/step - loss: 0.3517 - fbeta: 0.8462 - acc: 0.8729 - val_loss: 1.0873 - val_fbeta: 0.6412 - val_acc: 0.6670
#
# Epoch 00116: saving model to Model.116-0.6670.hdf5
#
# Epoch 00116: saving model to Model.116-0.6670.hdf5
# Epoch 117/128
# 225/224 [==============================] - 27s 119ms/step - loss: 0.3584 - fbeta: 0.8457 - acc: 0.8696 - val_loss: 1.1073 - val_fbeta: 0.6537 - val_acc: 0.6826
#
# Epoch 00117: saving model to Model.117-0.6826.hdf5
#
# Epoch 00117: saving model to Model.117-0.6826.hdf5
# Epoch 118/128
# 225/224 [==============================] - 27s 119ms/step - loss: 0.3553 - fbeta: 0.8454 - acc: 0.8706 - val_loss: 1.1085 - val_fbeta: 0.6293 - val_acc: 0.6562
#
# Epoch 00118: saving model to Model.118-0.6562.hdf5
#
# Epoch 00118: saving model to Model.118-0.6562.hdf5
# Epoch 119/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3577 - fbeta: 0.8452 - acc: 0.8698 - val_loss: 1.0977 - val_fbeta: 0.6498 - val_acc: 0.6800
#
# Epoch 00119: saving model to Model.119-0.6800.hdf5
#
# Epoch 00119: saving model to Model.119-0.6800.hdf5
# Epoch 120/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3556 - fbeta: 0.8463 - acc: 0.8708 - val_loss: 1.0918 - val_fbeta: 0.6552 - val_acc: 0.6907
#
# Epoch 00120: saving model to Model.120-0.6907.hdf5
#
# Epoch 00120: saving model to Model.120-0.6907.hdf5
# Epoch 121/128
# 225/224 [==============================] - 27s 119ms/step - loss: 0.3534 - fbeta: 0.8470 - acc: 0.8723 - val_loss: 1.1632 - val_fbeta: 0.6337 - val_acc: 0.6626
#
# Epoch 00121: saving model to Model.121-0.6626.hdf5
#
# Epoch 00121: saving model to Model.121-0.6626.hdf5
# Epoch 122/128
# 225/224 [==============================] - 27s 119ms/step - loss: 0.3566 - fbeta: 0.8440 - acc: 0.8690 - val_loss: 1.1344 - val_fbeta: 0.6476 - val_acc: 0.6810
#
# Epoch 00122: saving model to Model.122-0.6810.hdf5
#
# Epoch 00122: saving model to Model.122-0.6810.hdf5
# Epoch 123/128
# 225/224 [==============================] - 27s 119ms/step - loss: 0.3519 - fbeta: 0.8462 - acc: 0.8718 - val_loss: 1.1653 - val_fbeta: 0.6175 - val_acc: 0.6616
#
# Epoch 00123: saving model to Model.123-0.6616.hdf5
#
# Epoch 00123: saving model to Model.123-0.6616.hdf5
# Epoch 124/128
# 225/224 [==============================] - 27s 119ms/step - loss: 0.3514 - fbeta: 0.8469 - acc: 0.8704 - val_loss: 1.0917 - val_fbeta: 0.6412 - val_acc: 0.6724
#
# Epoch 00124: saving model to Model.124-0.6724.hdf5
#
# Epoch 00124: saving model to Model.124-0.6724.hdf5
# Epoch 125/128
# 225/224 [==============================] - 27s 119ms/step - loss: 0.3517 - fbeta: 0.8479 - acc: 0.8716 - val_loss: 1.1032 - val_fbeta: 0.6604 - val_acc: 0.6837
#
# Epoch 00125: saving model to Model.125-0.6837.hdf5
#
# Epoch 00125: saving model to Model.125-0.6837.hdf5
# Epoch 126/128
# 225/224 [==============================] - 27s 119ms/step - loss: 0.3557 - fbeta: 0.8439 - acc: 0.8690 - val_loss: 1.1272 - val_fbeta: 0.6487 - val_acc: 0.6821
#
# Epoch 00126: saving model to Model.126-0.6821.hdf5
#
# Epoch 00126: saving model to Model.126-0.6821.hdf5
# Epoch 127/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3531 - fbeta: 0.8487 - acc: 0.8726 - val_loss: 1.1308 - val_fbeta: 0.6401 - val_acc: 0.6649
#
# Epoch 00127: saving model to Model.127-0.6649.hdf5
#
# Epoch 00127: saving model to Model.127-0.6649.hdf5
# Epoch 128/128
# 225/224 [==============================] - 27s 118ms/step - loss: 0.3520 - fbeta: 0.8481 - acc: 0.8717 - val_loss: 1.1575 - val_fbeta: 0.6379 - val_acc: 0.6703
#
# Epoch 00128: saving model to Model.128-0.6703.hdf5
#
# Epoch 00128: saving model to Model.128-0.6703.hdf5

# %%
'''
Evaluate Test Set & Print Results
'''
score = model.evaluate(X_test, y_test, steps=int(num_test / BATCH_SIZE))
print('Evaluation Loss: ', score[0])
print('Evaluation Accuracy: ', score[1])

# History of Accuracy
fig1 = plt.figure()
plt.plot(history.history['acc'], color='b', label='Training')
plt.plot(history.history['val_acc'], color='g', label='Validation')
plt.title('History for Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.savefig(acc_file)
plt.show() 

# History of Loss
fig2 = plt.figure()
plt.plot(history.history['loss'], color='b', label='Training')
plt.plot(history.history['val_loss'], color='g', label='Validation')
plt.title('History for Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='lower left')
fig2.savefig(loss_file)
plt.show()

# Confusion Matrix
y_pred = model.predict_classes(X_test)
y_true = np.asarray([np.argmax(i) for i in y_test])

cm = confusion_matrix(y_true, y_pred)
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

sns.set(font_scale=1.5)
fig, ax = plt.subplots(figsize=(10,10))
ax = sns.heatmap(
    cm_norm, annot=True, linewidths=0, square=False, cmap='Greens', 
    yticklabels=emotion_labels, xticklabels=emotion_labels, 
    vmin=0, vmax=np.max(cm_norm), fmt='.2f', 
    annot_kws={'size': 20}
)
ax.set(xlabel='Predicted Label', ylabel='Actual Label')
plt.savefig(cm_file)
plt.show()
# Out:
# 28/28 [==============================] - 27s 971ms/step
# Evaluation Loss:  1.0841418504714966
# Evaluation Accuracy:  0.6497631669044495
