# %%
'''
Libraries, etc.
'''
import os
import cv2
import time
import numpy as np # linear algebra
import scipy as sp # more w/ numpy arrays
import pandas as pd # data processing
import tensorflow as tf # machine learning
import matplotlib.pyplot as plt # graph/plot
import seaborn as sns

from keras.layers import Convolution2D, Activation, BatchNormalization, GaussianNoise, MaxPooling2D, Dropout, Dense, Flatten
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras import backend as K
from keras.utils import np_utils as npu
from sklearn.metrics import confusion_matrix

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-510ed3cb-4cae-44f8-bebd-9c4bf09204b3" name="files[]" multiple disabled />
#      <output id="result-510ed3cb-4cae-44f8-bebd-9c4bf09204b3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
'''
Constants, Hyperparameters, etc.
'''
INPUT_FILE = 'fer2013.csv'

EMOTION_LABELS = ['Angry','Disgust','Fear','Happy','Sad','Surprise','Neutral']
NUM_LABELS = 7

BASE_SIZE = 48
BASE_DEPTH = 1

BATCH_SIZE = 128
NUM_EPOCHS = 64

# %%
'''
Load & Parse Data into Training/Test Labels & Images
'''
data = pd.read_csv(INPUT_FILE)
data.head()

train_set = data[(data.Usage == 'Training')]
validation_set = data[(data.Usage == 'PublicTest')]
test_set = data[(data.Usage == 'PrivateTest')]

X_train1 = np.array(list(map(str.split, train_set.pixels)), np.uint8)
X_validation1 = np.array(list(map(str.split, validation_set.pixels)), np.uint8)
X_test1 = np.array(list(map(str.split, test_set.pixels)), np.uint8)

NUM_TRAIN = len(X_train1)
NUM_VALIDATION = len(X_validation1)
NUM_TEST = len(X_test1)

X_train1 = X_train1.reshape(NUM_TRAIN, BASE_SIZE, BASE_SIZE)
X_validation1 = X_validation1.reshape(NUM_VALIDATION, BASE_SIZE, BASE_SIZE)
X_test1 = X_test1.reshape(NUM_TEST, BASE_SIZE, BASE_SIZE)

print('Matrix Shapes for X')
print('Training: ', X_train1.shape)
print('Validation: ', X_validation1.shape)
print('Testing: ', X_test1.shape)

y_train = train_set.emotion
y_train = npu.to_categorical(y_train, NUM_LABELS)

y_validation = validation_set.emotion
y_validation = npu.to_categorical(y_validation, NUM_LABELS)

y_test = test_set.emotion
y_test = npu.to_categorical(y_test, NUM_LABELS)

print('Matrix Shapes for Y')
print('Training: ', y_train.shape)
print('Validation: ', y_validation.shape)
print('Testing: ', y_test.shape)
# Out:
# Matrix Shapes for X
# Training:  (28709, 48, 48)
# Validation:  (3589, 48, 48)
# Testing:  (3589, 48, 48)
# Matrix Shapes for Y
# Training:  (28709, 7)
# Validation:  (3589, 7)
# Testing:  (3589, 7)

# %%
'''
Histogram Equalization, etc.
'''
clahe = cv2.createCLAHE(clipLimit=3.235, tileGridSize=(5,5))

X_train2 = X_train1.copy()
X_train3 = X_train1.copy()

X_validation2 = X_validation1.copy()
X_validation3 = X_validation1.copy()

X_test2 = X_test1.copy()
X_test3 = X_test1.copy()

i = 0
while (i < NUM_TRAIN):
  tMax = X_train1[i].max()
  tMin = X_train1[i].min()  

  if (tMax > tMin):
    tRatio = 255 / (tMax - tMin)
    X_train2[i] = np.multiply((X_train1[i] - tMin), tRatio)
    
  # Delete useless training examples
  else:
    X_train1 = np.delete(X_train1, (i), axis=0)
    X_train2 = np.delete(X_train2, (i), axis=0)
    X_train3 = np.delete(X_train3, (i), axis=0)
    y_train = np.delete(y_train, (i), axis=0)
    NUM_TRAIN -= 1
    i -= 1
    
  X_train3[i] = clahe.apply(X_train2[i])
  i += 1
  
i = 0
while (i < NUM_VALIDATION):
  tMax = X_validation1[i].max()
  tMin = X_validation1[i].min()

  # Shouldn't delete validation data... skip so we don't divide by 0
  if (tMax > tMin):
    tRatio = 255 / (tMax - tMin)
    X_validation2[i] = np.multiply((X_validation1[i] - tMin), tRatio).round()
  else:
    X_validation2[i] = X_validation1[i]

  X_validation3[i] = clahe.apply(X_validation2[i])
  i += 1

i = 0
while (i < NUM_TEST):
  tMax = X_test1[i].max()
  tMin = X_test1[i].min()

  # Shouldn't delete test data... skip so we don't divide by 0
  if (tMax > tMin):
    tRatio = 255 / (tMax - tMin)
    X_test2[i] = np.multiply((X_test1[i] - tMin), tRatio).round()
  else:
    X_test2[i] = X_test1[i]
    
  X_test3[i] = clahe.apply(X_test2[i])
  i += 1

'''
Print Samples from Input Data (to confirm transforms are correct)
'''
print('Original Images...')
for x in range(1,26):
    plt.subplot(5, 5, x)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_test1[x], cmap='gray')
    
plt.show()

print('Original w/ Linear Transform to normalize pixel values...')
for x in range(1,26):
    plt.subplot(5, 5, x)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_test2[x], cmap='gray')
    
plt.show()

print('Normalized w/ Contrast Limited Adaptive Histogram Equalization')
for x in range(1,26):
    plt.subplot(5, 5, x)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_test3[x], cmap='gray')
    
plt.show()
# Out:
# Original Images...
# Original w/ Linear Transform to normalize pixel values...
# Normalized w/ Contrast Limited Adaptive Histogram Equalization

# %%
'''
TensorFlow Model(s)
'''

def get_model1():
  model = Sequential()

  model.add(Convolution2D(64, (3, 3), padding='same', input_shape=(48,48,1)))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(128, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(256, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Flatten())

  model.add(Dense(512))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(256))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(7))
  model.add(Activation('softmax'))

  return model


def get_model2():
  model = Sequential()

  model.add(Convolution2D(64, (3, 3), padding='same', input_shape=(48,48,1)))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(128, (5, 5), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Flatten())

  model.add(Dense(256))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(512))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(7))
  model.add(Activation('softmax'))

  return model


def get_model3():
  model = Sequential()

  model.add(Convolution2D(64, (3, 3), padding='same', input_shape=(48,48,1)))
  model.add(Convolution2D(64, (3, 3), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(GaussianNoise(2))
  model.add(Dropout(0.4))

  model.add(Convolution2D(128, (3, 3), padding='same'))
  model.add(Convolution2D(128, (3, 3), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(GaussianNoise(2))
  model.add(Dropout(0.4))

  model.add(Convolution2D(256, (3, 3), padding='same'))
  model.add(Convolution2D(265, (3, 3), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(GaussianNoise(2))
  model.add(Dropout(0.4))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(Convolution2D(512, (3, 3), padding='same')) 
  model.add(Convolution2D(512, (1, 1), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(GaussianNoise(2))
  model.add(Dropout(0.4))

  model.add(Flatten())

  model.add(Dense(2048))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.4))

  model.add(Dense(512))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.4))

  model.add(Dense(7))
  model.add(Activation('softmax'))

  return model

# %%
'''
Metric(s)
'''
def fbeta(y_true, y_pred, threshold_shift=0):
  beta = 1
  
  y_pred = K.clip(y_pred, 0, 1)
  y_pred_bin = K.round(y_pred + threshold_shift)
  
  tp = K.sum(K.round(y_true * y_pred_bin), axis=1) + K.epsilon()
  fp = K.sum(K.round(K.clip(y_pred_bin - y_true, 0, 1)), axis=1)
  fn = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=1)
  
  precision = tp / (tp + fp)
  recall = tp / (tp + fn)
  
  beta_sq = beta ** 2
  return K.mean((beta_sq + 1) * (precision * recall) / (beta_sq * precision + recall + K.epsilon()))

# %%
'''
Setup Model & Data Generator
'''
# assign X_train/validation/test to the desired image set(s) from above
X_train = X_train1
X_validation = X_validation1
X_test = X_test1
NUM_TRAIN = len(X_train)

# reshape X_train/validation/test to the expected shape, and cast it back to a float32
X_train = X_train.reshape(NUM_TRAIN,BASE_SIZE,BASE_SIZE,1).astype(np.float32)
X_validation = X_validation.reshape(NUM_VALIDATION,BASE_SIZE,BASE_SIZE,1).astype(np.float32)
X_test = X_test.reshape(NUM_TEST,BASE_SIZE,BASE_SIZE,1).astype(np.float32)

# assign the desired model from above
model = get_model1()
model.summary()

# augmentation and fitting of data
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    rotation_range=0,
    width_shift_range=0.0,
    height_shift_range=0.0,
    shear_range=0,
    horizontal_flip=True,
    vertical_flip=False
)
datagen.fit(X_train)
datagen.fit(X_validation)

filepath = 'Model.{epoch:02d}-{val_acc:.4f}.hdf5'

checkpointer = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, mode='auto')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, verbose=0, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)
early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=0, verbose=0, mode='auto')

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=[fbeta, 'accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_120 (Conv2D)          (None, 48, 48, 64)        640
# _________________________________________________________________
# batch_normalization_144 (Bat (None, 48, 48, 64)        256
# _________________________________________________________________
# activation_158 (Activation)  (None, 48, 48, 64)        0
# _________________________________________________________________
# max_pooling2d_91 (MaxPooling (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_136 (Dropout)        (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_121 (Conv2D)          (None, 24, 24, 128)       73856
# _________________________________________________________________
# batch_normalization_145 (Bat (None, 24, 24, 128)       512
# _________________________________________________________________
# activation_159 (Activation)  (None, 24, 24, 128)       0
# _________________________________________________________________
# max_pooling2d_92 (MaxPooling (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_137 (Dropout)        (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_122 (Conv2D)          (None, 12, 12, 256)       295168
# _________________________________________________________________
# batch_normalization_146 (Bat (None, 12, 12, 256)       1024
# _________________________________________________________________
# activation_160 (Activation)  (None, 12, 12, 256)       0
# _________________________________________________________________
# max_pooling2d_93 (MaxPooling (None, 6, 6, 256)         0
# _________________________________________________________________
# dropout_138 (Dropout)        (None, 6, 6, 256)         0
# _________________________________________________________________
# conv2d_123 (Conv2D)          (None, 6, 6, 512)         1180160
# _________________________________________________________________
# batch_normalization_147 (Bat (None, 6, 6, 512)         2048
# _________________________________________________________________
# activation_161 (Activation)  (None, 6, 6, 512)         0
# _________________________________________________________________
# max_pooling2d_94 (MaxPooling (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_139 (Dropout)        (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten_23 (Flatten)         (None, 4608)              0
# _________________________________________________________________
# dense_68 (Dense)             (None, 512)               2359808
# _________________________________________________________________
# batch_normalization_148 (Bat (None, 512)               2048
# _________________________________________________________________
# activation_162 (Activation)  (None, 512)               0
# _________________________________________________________________
# dropout_140 (Dropout)        (None, 512)               0
# _________________________________________________________________
# dense_69 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_149 (Bat (None, 256)               1024
# _________________________________________________________________
# activation_163 (Activation)  (None, 256)               0
# _________________________________________________________________
# dropout_141 (Dropout)        (None, 256)               0
# _________________________________________________________________
# dense_70 (Dense)             (None, 7)                 1799
# _________________________________________________________________
# activation_164 (Activation)  (None, 7)                 0
# =================================================================
# Total params: 4,049,671
# Trainable params: 4,046,215
# Non-trainable params: 3,456
# _________________________________________________________________

# %%
'''
Training
'''
train_flow = datagen.flow(X_train, y_train, batch_size=BATCH_SIZE)
validation_flow = datagen.flow(X_validation, y_validation)

history = model.fit_generator(
    train_flow,
    steps_per_epoch=NUM_TRAIN / BATCH_SIZE,
    epochs=NUM_EPOCHS,
    verbose=1,
    validation_data=validation_flow,
    validation_steps=NUM_VALIDATION / BATCH_SIZE,
    callbacks=[checkpointer, reduce_lr, checkpointer]
)
# Out:
# Epoch 1/64
# 225/224 [==============================] - 35s 157ms/step - loss: 1.7482 - fbeta: 0.1255 - acc: 0.3285 - val_loss: 1.5980 - val_fbeta: 0.2220 - val_acc: 0.3631
#
# Epoch 00001: saving model to Model.01-0.3631.hdf5
#
# Epoch 00001: saving model to Model.01-0.3631.hdf5
# Epoch 2/64
# 225/224 [==============================] - 24s 107ms/step - loss: 1.4209 - fbeta: 0.2424 - acc: 0.4551 - val_loss: 1.3496 - val_fbeta: 0.3287 - val_acc: 0.4828
#
# Epoch 00002: saving model to Model.02-0.4828.hdf5
#
# Epoch 00002: saving model to Model.02-0.4828.hdf5
# Epoch 3/64
# 225/224 [==============================] - 24s 107ms/step - loss: 1.2852 - fbeta: 0.3045 - acc: 0.5096 - val_loss: 1.2871 - val_fbeta: 0.3287 - val_acc: 0.5269
#
# Epoch 00003: saving model to Model.03-0.5269.hdf5
#
# Epoch 00003: saving model to Model.03-0.5269.hdf5
# Epoch 4/64
# 225/224 [==============================] - 24s 108ms/step - loss: 1.2151 - fbeta: 0.3375 - acc: 0.5348 - val_loss: 1.2528 - val_fbeta: 0.3718 - val_acc: 0.5250
#
# Epoch 00004: saving model to Model.04-0.5250.hdf5
#
# Epoch 00004: saving model to Model.04-0.5250.hdf5
# Epoch 5/64
# 225/224 [==============================] - 24s 108ms/step - loss: 1.1706 - fbeta: 0.3650 - acc: 0.5542 - val_loss: 1.2157 - val_fbeta: 0.3265 - val_acc: 0.5172
#
# Epoch 00005: saving model to Model.05-0.5172.hdf5
#
# Epoch 00005: saving model to Model.05-0.5172.hdf5
# Epoch 6/64
# 225/224 [==============================] - 24s 107ms/step - loss: 1.1302 - fbeta: 0.3915 - acc: 0.5734 - val_loss: 1.2988 - val_fbeta: 0.2759 - val_acc: 0.4828
#
# Epoch 00006: saving model to Model.06-0.4828.hdf5
#
# Epoch 00006: saving model to Model.06-0.4828.hdf5
# Epoch 7/64
# 225/224 [==============================] - 24s 106ms/step - loss: 1.0951 - fbeta: 0.4059 - acc: 0.5825 - val_loss: 1.2026 - val_fbeta: 0.3987 - val_acc: 0.5571
#
# Epoch 00007: saving model to Model.07-0.5571.hdf5
#
# Epoch 00007: saving model to Model.07-0.5571.hdf5
# Epoch 8/64
# 225/224 [==============================] - 24s 106ms/step - loss: 1.0689 - fbeta: 0.4267 - acc: 0.5959 - val_loss: 1.1550 - val_fbeta: 0.3907 - val_acc: 0.5716
#
# Epoch 00008: saving model to Model.08-0.5716.hdf5
#
# Epoch 00008: saving model to Model.08-0.5716.hdf5
# Epoch 9/64
# 225/224 [==============================] - 24s 107ms/step - loss: 1.0471 - fbeta: 0.4424 - acc: 0.6048 - val_loss: 1.0931 - val_fbeta: 0.4440 - val_acc: 0.5991
#
# Epoch 00009: saving model to Model.09-0.5991.hdf5
#
# Epoch 00009: saving model to Model.09-0.5991.hdf5
# Epoch 10/64
# 225/224 [==============================] - 24s 108ms/step - loss: 1.0196 - fbeta: 0.4586 - acc: 0.6146 - val_loss: 1.1880 - val_fbeta: 0.3718 - val_acc: 0.5302
#
# Epoch 00010: saving model to Model.10-0.5302.hdf5
#
# Epoch 00010: saving model to Model.10-0.5302.hdf5
# Epoch 11/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.9949 - fbeta: 0.4767 - acc: 0.6231 - val_loss: 1.0732 - val_fbeta: 0.4591 - val_acc: 0.5873
#
# Epoch 00011: saving model to Model.11-0.5873.hdf5
#
# Epoch 00011: saving model to Model.11-0.5873.hdf5
# Epoch 12/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.9769 - fbeta: 0.4884 - acc: 0.6321 - val_loss: 1.0574 - val_fbeta: 0.4906 - val_acc: 0.6127
#
# Epoch 00012: saving model to Model.12-0.6127.hdf5
#
# Epoch 00012: saving model to Model.12-0.6127.hdf5
# Epoch 13/64
# 225/224 [==============================] - 24s 107ms/step - loss: 0.9518 - fbeta: 0.5032 - acc: 0.6395 - val_loss: 1.1770 - val_fbeta: 0.3416 - val_acc: 0.5506
#
# Epoch 00013: saving model to Model.13-0.5506.hdf5
#
# Epoch 00013: saving model to Model.13-0.5506.hdf5
# Epoch 14/64
# 225/224 [==============================] - 24s 106ms/step - loss: 0.9376 - fbeta: 0.5149 - acc: 0.6428 - val_loss: 1.1084 - val_fbeta: 0.4073 - val_acc: 0.5819
#
# Epoch 00014: saving model to Model.14-0.5819.hdf5
#
# Epoch 00014: saving model to Model.14-0.5819.hdf5
# Epoch 15/64
# 225/224 [==============================] - 24s 106ms/step - loss: 0.9202 - fbeta: 0.5243 - acc: 0.6522 - val_loss: 1.0185 - val_fbeta: 0.5162 - val_acc: 0.6218
#
# Epoch 00015: saving model to Model.15-0.6218.hdf5
#
# Epoch 00015: saving model to Model.15-0.6218.hdf5
# Epoch 16/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.8935 - fbeta: 0.5438 - acc: 0.6659 - val_loss: 1.0609 - val_fbeta: 0.4994 - val_acc: 0.6060
#
# Epoch 00016: saving model to Model.16-0.6060.hdf5
#
# Epoch 00016: saving model to Model.16-0.6060.hdf5
# Epoch 17/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.8715 - fbeta: 0.5555 - acc: 0.6712 - val_loss: 1.0408 - val_fbeta: 0.5022 - val_acc: 0.6024
#
# Epoch 00017: saving model to Model.17-0.6024.hdf5
#
# Epoch 00017: saving model to Model.17-0.6024.hdf5
# Epoch 18/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.8570 - fbeta: 0.5647 - acc: 0.6776 - val_loss: 1.0492 - val_fbeta: 0.4989 - val_acc: 0.6175
#
# Epoch 00018: saving model to Model.18-0.6175.hdf5
#
# Epoch 00018: saving model to Model.18-0.6175.hdf5
# Epoch 19/64
# 225/224 [==============================] - 24s 107ms/step - loss: 0.8321 - fbeta: 0.5778 - acc: 0.6874 - val_loss: 1.1004 - val_fbeta: 0.5043 - val_acc: 0.5970
#
# Epoch 00019: saving model to Model.19-0.5970.hdf5
#
# Epoch 00019: saving model to Model.19-0.5970.hdf5
# Epoch 20/64
# 225/224 [==============================] - 24s 107ms/step - loss: 0.8107 - fbeta: 0.5968 - acc: 0.6992 - val_loss: 1.1548 - val_fbeta: 0.4895 - val_acc: 0.5916
#
# Epoch 00020: saving model to Model.20-0.5916.hdf5
#
# Epoch 00020: saving model to Model.20-0.5916.hdf5
# Epoch 21/64
# 225/224 [==============================] - 24s 106ms/step - loss: 0.8030 - fbeta: 0.5999 - acc: 0.6983 - val_loss: 1.0836 - val_fbeta: 0.5183 - val_acc: 0.6056
#
# Epoch 00021: saving model to Model.21-0.6056.hdf5
#
# Epoch 00021: saving model to Model.21-0.6056.hdf5
# Epoch 22/64
# 225/224 [==============================] - 24s 107ms/step - loss: 0.7749 - fbeta: 0.6173 - acc: 0.7102 - val_loss: 1.2251 - val_fbeta: 0.4817 - val_acc: 0.5700
#
# Epoch 00022: saving model to Model.22-0.5700.hdf5
#
# Epoch 00022: saving model to Model.22-0.5700.hdf5
# Epoch 23/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.7575 - fbeta: 0.6267 - acc: 0.7149 - val_loss: 1.1645 - val_fbeta: 0.5075 - val_acc: 0.5905
#
# Epoch 00023: saving model to Model.23-0.5905.hdf5
#
# Epoch 00023: saving model to Model.23-0.5905.hdf5
# Epoch 24/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.7311 - fbeta: 0.6401 - acc: 0.7251 - val_loss: 1.0837 - val_fbeta: 0.5305 - val_acc: 0.6127
#
# Epoch 00024: saving model to Model.24-0.6127.hdf5
#
# Epoch 00024: saving model to Model.24-0.6127.hdf5
# Epoch 25/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.7145 - fbeta: 0.6531 - acc: 0.7348 - val_loss: 1.0123 - val_fbeta: 0.5539 - val_acc: 0.6358
#
# Epoch 00025: saving model to Model.25-0.6358.hdf5
#
# Epoch 00025: saving model to Model.25-0.6358.hdf5
# Epoch 26/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.6983 - fbeta: 0.6629 - acc: 0.7408 - val_loss: 1.1172 - val_fbeta: 0.5194 - val_acc: 0.6110
#
# Epoch 00026: saving model to Model.26-0.6110.hdf5
#
# Epoch 00026: saving model to Model.26-0.6110.hdf5
# Epoch 27/64
# 225/224 [==============================] - 24s 107ms/step - loss: 0.6835 - fbeta: 0.6692 - acc: 0.7410 - val_loss: 1.1296 - val_fbeta: 0.5323 - val_acc: 0.6078
#
# Epoch 00027: saving model to Model.27-0.6078.hdf5
#
# Epoch 00027: saving model to Model.27-0.6078.hdf5
# Epoch 28/64
# 225/224 [==============================] - 24s 106ms/step - loss: 0.6581 - fbeta: 0.6867 - acc: 0.7545 - val_loss: 1.1070 - val_fbeta: 0.5261 - val_acc: 0.6149
#
# Epoch 00028: saving model to Model.28-0.6149.hdf5
#
# Epoch 00028: saving model to Model.28-0.6149.hdf5
# Epoch 29/64
# 225/224 [==============================] - 24s 107ms/step - loss: 0.6411 - fbeta: 0.6936 - acc: 0.7613 - val_loss: 1.2286 - val_fbeta: 0.5022 - val_acc: 0.5679
#
# Epoch 00029: saving model to Model.29-0.5679.hdf5
#
# Epoch 00029: saving model to Model.29-0.5679.hdf5
# Epoch 30/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.6244 - fbeta: 0.7064 - acc: 0.7658 - val_loss: 1.0831 - val_fbeta: 0.6002 - val_acc: 0.6466
#
# Epoch 00030: saving model to Model.30-0.6466.hdf5
#
# Epoch 00030: saving model to Model.30-0.6466.hdf5
# Epoch 31/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.6131 - fbeta: 0.7121 - acc: 0.7707 - val_loss: 1.0768 - val_fbeta: 0.5571 - val_acc: 0.6401
#
# Epoch 00031: saving model to Model.31-0.6401.hdf5
#
# Epoch 00031: saving model to Model.31-0.6401.hdf5
# Epoch 32/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.5907 - fbeta: 0.7248 - acc: 0.7822 - val_loss: 1.2270 - val_fbeta: 0.5239 - val_acc: 0.5993
#
# Epoch 00032: saving model to Model.32-0.5993.hdf5
#
# Epoch 00032: saving model to Model.32-0.5993.hdf5
# Epoch 33/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.5759 - fbeta: 0.7333 - acc: 0.7860 - val_loss: 1.0849 - val_fbeta: 0.5916 - val_acc: 0.6433
#
# Epoch 00033: saving model to Model.33-0.6433.hdf5
#
# Epoch 00033: saving model to Model.33-0.6433.hdf5
# Epoch 34/64
# 225/224 [==============================] - 24s 106ms/step - loss: 0.5497 - fbeta: 0.7458 - acc: 0.7960 - val_loss: 1.2974 - val_fbeta: 0.5313 - val_acc: 0.5851
#
# Epoch 00034: saving model to Model.34-0.5851.hdf5
#
# Epoch 00034: saving model to Model.34-0.5851.hdf5
# Epoch 35/64
# 225/224 [==============================] - 24s 106ms/step - loss: 0.5442 - fbeta: 0.7525 - acc: 0.7979 - val_loss: 1.1536 - val_fbeta: 0.5722 - val_acc: 0.6304
#
# Epoch 00035: saving model to Model.35-0.6304.hdf5
#
# Epoch 00035: saving model to Model.35-0.6304.hdf5
# Epoch 36/64
# 225/224 [==============================] - 24s 107ms/step - loss: 0.4727 - fbeta: 0.7807 - acc: 0.8253 - val_loss: 1.0179 - val_fbeta: 0.6304 - val_acc: 0.6792
#
# Epoch 00036: saving model to Model.36-0.6792.hdf5
#
# Epoch 00036: saving model to Model.36-0.6792.hdf5
# Epoch 37/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.4646 - fbeta: 0.7885 - acc: 0.8299 - val_loss: 1.0805 - val_fbeta: 0.6067 - val_acc: 0.6498
#
# Epoch 00037: saving model to Model.37-0.6498.hdf5
#
# Epoch 00037: saving model to Model.37-0.6498.hdf5
# Epoch 38/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.4512 - fbeta: 0.7958 - acc: 0.8360 - val_loss: 1.0430 - val_fbeta: 0.6239 - val_acc: 0.6713
#
# Epoch 00038: saving model to Model.38-0.6713.hdf5
#
# Epoch 00038: saving model to Model.38-0.6713.hdf5
# Epoch 39/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.4402 - fbeta: 0.8011 - acc: 0.8380 - val_loss: 1.1112 - val_fbeta: 0.6060 - val_acc: 0.6593
#
# Epoch 00039: saving model to Model.39-0.6593.hdf5
#
# Epoch 00039: saving model to Model.39-0.6593.hdf5
# Epoch 40/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.4244 - fbeta: 0.8069 - acc: 0.8453 - val_loss: 1.1250 - val_fbeta: 0.5981 - val_acc: 0.6422
#
# Epoch 00040: saving model to Model.40-0.6422.hdf5
#
# Epoch 00040: saving model to Model.40-0.6422.hdf5
# Epoch 41/64
# 225/224 [==============================] - 24s 106ms/step - loss: 0.4251 - fbeta: 0.8102 - acc: 0.8453 - val_loss: 1.0811 - val_fbeta: 0.6315 - val_acc: 0.6616
#
# Epoch 00041: saving model to Model.41-0.6616.hdf5
#
# Epoch 00041: saving model to Model.41-0.6616.hdf5
# Epoch 42/64
# 225/224 [==============================] - 24s 106ms/step - loss: 0.4140 - fbeta: 0.8125 - acc: 0.8466 - val_loss: 1.0678 - val_fbeta: 0.6196 - val_acc: 0.6735
#
# Epoch 00042: saving model to Model.42-0.6735.hdf5
#
# Epoch 00042: saving model to Model.42-0.6735.hdf5
# Epoch 43/64
# 225/224 [==============================] - 24s 107ms/step - loss: 0.4074 - fbeta: 0.8160 - acc: 0.8495 - val_loss: 1.1365 - val_fbeta: 0.6382 - val_acc: 0.6559
#
# Epoch 00043: saving model to Model.43-0.6559.hdf5
#
# Epoch 00043: saving model to Model.43-0.6559.hdf5
# Epoch 44/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.4072 - fbeta: 0.8159 - acc: 0.8501 - val_loss: 1.1088 - val_fbeta: 0.6455 - val_acc: 0.6832
#
# Epoch 00044: saving model to Model.44-0.6832.hdf5
#
# Epoch 00044: saving model to Model.44-0.6832.hdf5
# Epoch 45/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.3977 - fbeta: 0.8206 - acc: 0.8531 - val_loss: 1.0497 - val_fbeta: 0.6336 - val_acc: 0.6724
#
# Epoch 00045: saving model to Model.45-0.6724.hdf5
#
# Epoch 00045: saving model to Model.45-0.6724.hdf5
# Epoch 46/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.3924 - fbeta: 0.8248 - acc: 0.8548 - val_loss: 1.2252 - val_fbeta: 0.6034 - val_acc: 0.6336
#
# Epoch 00046: saving model to Model.46-0.6336.hdf5
#
# Epoch 00046: saving model to Model.46-0.6336.hdf5
# Epoch 47/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.3858 - fbeta: 0.8266 - acc: 0.8576 - val_loss: 1.1026 - val_fbeta: 0.6437 - val_acc: 0.6770
#
# Epoch 00047: saving model to Model.47-0.6770.hdf5
#
# Epoch 00047: saving model to Model.47-0.6770.hdf5
# Epoch 48/64
# 225/224 [==============================] - 24s 107ms/step - loss: 0.3787 - fbeta: 0.8313 - acc: 0.8617 - val_loss: 1.1545 - val_fbeta: 0.6293 - val_acc: 0.6746
#
# Epoch 00048: saving model to Model.48-0.6746.hdf5
#
# Epoch 00048: saving model to Model.48-0.6746.hdf5
# Epoch 49/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.3814 - fbeta: 0.8292 - acc: 0.8585 - val_loss: 1.1077 - val_fbeta: 0.6304 - val_acc: 0.6616
#
# Epoch 00049: saving model to Model.49-0.6616.hdf5
#
# Epoch 00049: saving model to Model.49-0.6616.hdf5
# Epoch 50/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.3829 - fbeta: 0.8292 - acc: 0.8615 - val_loss: 1.0669 - val_fbeta: 0.6412 - val_acc: 0.6778
#
# Epoch 00050: saving model to Model.50-0.6778.hdf5
#
# Epoch 00050: saving model to Model.50-0.6778.hdf5
# Epoch 51/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.3787 - fbeta: 0.8319 - acc: 0.8613 - val_loss: 1.1597 - val_fbeta: 0.6326 - val_acc: 0.6626
#
# Epoch 00051: saving model to Model.51-0.6626.hdf5
#
# Epoch 00051: saving model to Model.51-0.6626.hdf5
# Epoch 52/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.3785 - fbeta: 0.8321 - acc: 0.8619 - val_loss: 1.1916 - val_fbeta: 0.6142 - val_acc: 0.6412
#
# Epoch 00052: saving model to Model.52-0.6412.hdf5
#
# Epoch 00052: saving model to Model.52-0.6412.hdf5
# Epoch 53/64
# 225/224 [==============================] - 24s 109ms/step - loss: 0.3790 - fbeta: 0.8293 - acc: 0.8598 - val_loss: 1.1166 - val_fbeta: 0.6336 - val_acc: 0.6703
#
# Epoch 00053: saving model to Model.53-0.6703.hdf5
#
# Epoch 00053: saving model to Model.53-0.6703.hdf5
# Epoch 54/64
# 225/224 [==============================] - 24s 109ms/step - loss: 0.3787 - fbeta: 0.8292 - acc: 0.8590 - val_loss: 1.1090 - val_fbeta: 0.6573 - val_acc: 0.6886
#
# Epoch 00054: saving model to Model.54-0.6886.hdf5
#
# Epoch 00054: saving model to Model.54-0.6886.hdf5
# Epoch 55/64
# 225/224 [==============================] - 24s 106ms/step - loss: 0.3755 - fbeta: 0.8341 - acc: 0.8625 - val_loss: 1.0960 - val_fbeta: 0.6304 - val_acc: 0.6770
#
# Epoch 00055: saving model to Model.55-0.6770.hdf5
#
# Epoch 00055: saving model to Model.55-0.6770.hdf5
# Epoch 56/64
# 225/224 [==============================] - 24s 106ms/step - loss: 0.3774 - fbeta: 0.8310 - acc: 0.8613 - val_loss: 1.1087 - val_fbeta: 0.6261 - val_acc: 0.6692
#
# Epoch 00056: saving model to Model.56-0.6692.hdf5
#
# Epoch 00056: saving model to Model.56-0.6692.hdf5
# Epoch 57/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.3785 - fbeta: 0.8317 - acc: 0.8623 - val_loss: 1.1345 - val_fbeta: 0.6595 - val_acc: 0.6853
#
# Epoch 00057: saving model to Model.57-0.6853.hdf5
#
# Epoch 00057: saving model to Model.57-0.6853.hdf5
# Epoch 58/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.3797 - fbeta: 0.8297 - acc: 0.8588 - val_loss: 1.1178 - val_fbeta: 0.6304 - val_acc: 0.6606
#
# Epoch 00058: saving model to Model.58-0.6606.hdf5
#
# Epoch 00058: saving model to Model.58-0.6606.hdf5
# Epoch 59/64
# 225/224 [==============================] - 24s 109ms/step - loss: 0.3806 - fbeta: 0.8329 - acc: 0.8614 - val_loss: 1.1425 - val_fbeta: 0.6337 - val_acc: 0.6715
#
# Epoch 00059: saving model to Model.59-0.6715.hdf5
#
# Epoch 00059: saving model to Model.59-0.6715.hdf5
# Epoch 60/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.3758 - fbeta: 0.8338 - acc: 0.8616 - val_loss: 1.2032 - val_fbeta: 0.6207 - val_acc: 0.6498
#
# Epoch 00060: saving model to Model.60-0.6498.hdf5
#
# Epoch 00060: saving model to Model.60-0.6498.hdf5
# Epoch 61/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.3802 - fbeta: 0.8337 - acc: 0.8619 - val_loss: 1.0993 - val_fbeta: 0.6272 - val_acc: 0.6627
#
# Epoch 00061: saving model to Model.61-0.6627.hdf5
#
# Epoch 00061: saving model to Model.61-0.6627.hdf5
# Epoch 62/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.3764 - fbeta: 0.8322 - acc: 0.8601 - val_loss: 1.0370 - val_fbeta: 0.6659 - val_acc: 0.7037
#
# Epoch 00062: saving model to Model.62-0.7037.hdf5
#
# Epoch 00062: saving model to Model.62-0.7037.hdf5
# Epoch 63/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.3724 - fbeta: 0.8344 - acc: 0.8628 - val_loss: 1.1578 - val_fbeta: 0.6249 - val_acc: 0.6604
#
# Epoch 00063: saving model to Model.63-0.6604.hdf5
#
# Epoch 00063: saving model to Model.63-0.6604.hdf5
# Epoch 64/64
# 225/224 [==============================] - 24s 108ms/step - loss: 0.3803 - fbeta: 0.8313 - acc: 0.8599 - val_loss: 1.0698 - val_fbeta: 0.6584 - val_acc: 0.6864
#
# Epoch 00064: saving model to Model.64-0.6864.hdf5
#
# Epoch 00064: saving model to Model.64-0.6864.hdf5

# %%
'''
Evaluation
'''
score = model.evaluate(X_test, y_test, steps=int(NUM_TEST / BATCH_SIZE))
print('Evaluation Loss: ', score[0])
print('Evaluation Accuracy: ', score[1])

# History of Accuracy
hist_acc = 'accuracy.png'
fig1 = plt.figure()
plt.plot(history.history['acc'], color='b', label='Training')
plt.plot(history.history['val_acc'], color='g', label='Validation')
plt.title('History for Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
fig1.savefig(hist_acc)
plt.show() 

# History of Loss
loss_acc = 'loss.png'
fig2 = plt.figure()
plt.plot(history.history['loss'], color='b', label='Training')
plt.plot(history.history['val_loss'], color='g', label='Validation')
plt.title('History for Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='lower left')
fig1.savefig(loss_acc)
plt.show()

# Confusion Matrix
y_pred = model.predict_classes(X_test)
y_true = np.asarray([np.argmax(i) for i in y_test])

cm = confusion_matrix(y_true, y_pred)
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
sns.set(font_scale=1.5)
fig, ax = plt.subplots(figsize=(10,10))
ax = sns.heatmap(cm_norm, annot=True, linewidths=0, square=False, cmap='Greens', yticklabels=EMOTION_LABELS, xticklabels=EMOTION_LABELS, vmin=0, vmax=np.max(cm_norm), fmt='.2f', annot_kws={'size': 20})
ax.set(xlabel='Predicted Labels', ylabel='Actual Labels')

plt.show()
# Out:
# 28/28 [==============================] - 21s 736ms/step
# Evaluation Loss:  1.0641683340072632
# Evaluation Accuracy:  0.6505990624427795
