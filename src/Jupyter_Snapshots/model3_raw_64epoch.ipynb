# %%
'''
Libraries, etc.
'''
import os
import cv2
import time
import numpy as np # linear algebra
import scipy as sp # more w/ numpy arrays
import pandas as pd # data processing
import tensorflow as tf # machine learning
import matplotlib.pyplot as plt # graph/plot
import seaborn as sns

from keras.layers import Convolution2D, Activation, BatchNormalization, GaussianNoise, MaxPooling2D, Dropout, Dense, Flatten
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras import backend as K
from keras.utils import np_utils as npu
from sklearn.metrics import confusion_matrix

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d309cc28-f586-4bcc-b01f-141d91cb62be" name="files[]" multiple disabled />
#      <output id="result-d309cc28-f586-4bcc-b01f-141d91cb62be">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
'''
Constants, Hyperparameters, etc.
'''
INPUT_DIR = './fer2013/'
INPUT_FILE = 'fer2013.csv'

EMOTION_LABELS = ['Angry','Disgust','Fear','Happy','Sad','Surprise','Neutral']
NUM_LABELS = 7

BASE_SIZE = 48
BASE_DEPTH = 1

BATCH_SIZE = 128
NUM_EPOCHS = 64

# %%
'''
Load & Parse Data into Training/Test Labels & Images
'''
data = pd.read_csv(INPUT_FILE)
data.head()

train_set = data[(data.Usage == 'Training')]
validation_set = data[(data.Usage == 'PublicTest')]
test_set = data[(data.Usage == 'PrivateTest')]

X_train1 = np.array(list(map(str.split, train_set.pixels)), np.uint8)
X_validation1 = np.array(list(map(str.split, validation_set.pixels)), np.uint8)
X_test1 = np.array(list(map(str.split, test_set.pixels)), np.uint8)

NUM_TRAIN = len(X_train1)
NUM_VALIDATION = len(X_validation1)
NUM_TEST = len(X_test1)

X_train1 = X_train1.reshape(NUM_TRAIN, BASE_SIZE, BASE_SIZE)
X_validation1 = X_validation1.reshape(NUM_VALIDATION, BASE_SIZE, BASE_SIZE)
X_test1 = X_test1.reshape(NUM_TEST, BASE_SIZE, BASE_SIZE)

y_train = train_set.emotion
y_train = npu.to_categorical(y_train, NUM_LABELS)

y_validation = validation_set.emotion
y_validation = npu.to_categorical(y_validation, NUM_LABELS)

y_test = test_set.emotion
y_test = npu.to_categorical(y_test, NUM_LABELS)


print('Training Shape: ', X_train1.shape)
print('Validation Shape: ', X_validation1.shape)
print('Testing Shape: ', X_test1.shape)
# Out:
# Training Shape:  (28709, 48, 48)
# Validation Shape:  (3589, 48, 48)
# Testing Shape:  (3589, 48, 48)

# %%
'''
Histogram Equalization
'''
clahe = cv2.createCLAHE(clipLimit=3.235, tileGridSize=(5,5))

X_train2 = X_train1.copy()
X_train3 = X_train1.copy()

X_validation2 = X_validation1.copy()
X_validation3 = X_validation1.copy()

X_test2 = X_test1.copy()
X_test3 = X_test1.copy()

i = 0
while (i < NUM_TRAIN):
  tMax = X_train1[i].max()
  tMin = X_train1[i].min()
  
  # Delete useless training examples
  if (tMax > tMin):
    tRatio = 255 / (tMax - tMin)
    X_train2[i] = np.multiply((X_train1[i] - tMin), tRatio)

  else:
    X_train1 = np.delete(X_train1, (i), axis=0)
    X_train2 = np.delete(X_train2, (i), axis=0)
    X_train3 = np.delete(X_train3, (i), axis=0)
    y_train = np.delete(y_train, (i), axis=0)
    NUM_TRAIN -= 1
    i -= 1
    #X_train2[i] = X_train1[i]
    
  X_train3[i] = clahe.apply(X_train2[i])
  i += 1
  
i = 0
while (i < NUM_VALIDATION):
  tMax = X_validation1[i].max()
  tMin = X_validation1[i].min()

  # Shouldn't delete validation data... skip so we don't divide by 0
  if (tMax > tMin):
    tRatio = 255 / (tMax - tMin)
    X_validation2[i] = np.multiply((X_validation1[i] - tMin), tRatio).round()
  else:
    X_validation2[i] = X_validation1[i]

  X_validation3[i] = clahe.apply(X_validation2[i])
  i += 1

i = 0
while (i < NUM_TEST):
  tMax = X_test1[i].max()
  tMin = X_test1[i].min()

  # Shouldn't delete test data... skip so we don't divide by 0
  if (tMax > tMin):
    tRatio = 255 / (tMax - tMin)
    X_test2[i] = np.multiply((X_test1[i] - tMin), tRatio).round()
  else:
    X_test2[i] = X_test1[i]
    
  X_test3[i] = clahe.apply(X_test2[i])
  i += 1

'''
Print Samples from Input Data (to confirm transforms are correct)
'''
print('Original Images...')
for x in range(1,26):
    plt.subplot(5, 5, x)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_test1[x], cmap='gray')
    
plt.show()

print('Original w/ Linear Transform to normalize pixel values...')
for x in range(1,26):
    plt.subplot(5, 5, x)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_test2[x], cmap='gray')
    
plt.show()

print('Normalized w/ Contrast Limited Adaptive Histogram Equalization')
for x in range(1,26):
    plt.subplot(5, 5, x)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_test3[x], cmap='gray')
    
plt.show()
# Out:
# Original Images...
# Original w/ Linear Transform to normalize pixel values...
# Normalized w/ Contrast Limited Adaptive Histogram Equalization

# %%
'''
TensorFlow Model(s)
'''
def get_model_test():
  model = Sequential()
  
  model.add(Convolution2D(64, (3, 3), padding='same', input_shape=(48,48,1)))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2,2), strides=2, padding='same'))
  model.add(Dropout(0.25))
  
  model.add(Convolution2D(128, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2,2), strides=2, padding='same'))
  model.add(Dropout(0.25))
  
  model.add(Convolution2D(256, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2,2), strides=2, padding='same'))
  model.add(Dropout(0.25))
  
  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2,2), strides=2, padding='same'))
  model.add(Dropout(0.25))
  
  model.add(Flatten())
  
  model.add(Dense(512))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))
  
  model.add(Dense(128))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))
  
  model.add(Dense(32))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))
  
  model.add(Dense(7))
  model.add(Activation('softmax'))
  
  return model


def get_model1():
  model = Sequential()

  model.add(Convolution2D(64, (3, 3), padding='same', input_shape=(48,48,1)))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(128, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(256, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Flatten())

  model.add(Dense(512))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(256))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(7))
  model.add(Activation('softmax'))

  return model


# actual model
def get_model2():
  model = Sequential()

  model.add(Convolution2D(64, (3, 3), padding='same', input_shape=(48,48,1)))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(128, (5, 5), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Flatten())

  model.add(Dense(256))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(512))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(7))
  model.add(Activation('softmax'))

  return model

# actual model
def get_model3():
  model = Sequential()

  model.add(Convolution2D(64, (3, 3), padding='same', input_shape=(48,48,1)))
  model.add(Convolution2D(64, (3, 3), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(GaussianNoise(0.3))
  model.add(Dropout(0.4))

  model.add(Convolution2D(128, (3, 3), padding='same'))
  model.add(Convolution2D(128, (3, 3), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(GaussianNoise(0.3))
  model.add(Dropout(0.4))

  model.add(Convolution2D(256, (3, 3), padding='same'))
  model.add(Convolution2D(265, (3, 3), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(GaussianNoise(0.3))
  model.add(Dropout(0.4))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(Convolution2D(512, (3, 3), padding='same')) 
  model.add(Convolution2D(512, (1, 1), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(GaussianNoise(0.3))
  model.add(Dropout(0.4))

  model.add(Flatten())

  model.add(Dense(2048))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.4))

  model.add(Dense(512))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.4))

  model.add(Dense(7))
  model.add(Activation('softmax'))

  return model

# %%
'''
Metric(s)
'''
def fbeta(y_true, y_pred, threshold_shift=0):
  beta = 1
  
  y_pred = K.clip(y_pred, 0, 1)
  y_pred_bin = K.round(y_pred + threshold_shift)
  
  tp = K.sum(K.round(y_true * y_pred_bin), axis=1) + K.epsilon()
  fp = K.sum(K.round(K.clip(y_pred_bin - y_true, 0, 1)), axis=1)
  fn = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=1)
  
  precision = tp / (tp + fp)
  recall = tp / (tp + fn)
  
  beta_sq = beta ** 2
  return K.mean((beta_sq + 1) * (precision * recall) / (beta_sq * precision + recall + K.epsilon()))

# %%
'''
Setup Model & Data Generator
'''

X_train = X_train1#np.concatenate( (np.concatenate( (X_train1, X_train2), axis=0), X_train3), axis=0)
X_validation = X_validation1
X_test = X_test1
#y_train = np.concatenate( (np.concatenate( (y_train, y_train), axis=0), y_train), axis=0)
NUM_TRAIN = len(X_train)

X_train = X_train.reshape(NUM_TRAIN,BASE_SIZE,BASE_SIZE,1).astype(np.float32)
X_validation = X_validation.reshape(NUM_VALIDATION,BASE_SIZE,BASE_SIZE,1).astype(np.float32)
X_test = X_test.reshape(NUM_TEST,BASE_SIZE,BASE_SIZE,1).astype(np.float32)

model = get_model3()
model.summary()

datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    rotation_range=0,
    width_shift_range=0.0,
    height_shift_range=0.0,
    shear_range=0,
    horizontal_flip=True,
    vertical_flip=False
)
datagen.fit(X_train)
datagen.fit(X_validation)

filepath = 'Model.{epoch:02d}-{val_acc:.4f}.hdf5'
checkpointer = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, mode='auto')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, verbose=0, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)
early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=0, verbose=0, mode='auto')

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=[fbeta, 'accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_94 (Conv2D)           (None, 48, 48, 64)        640
# _________________________________________________________________
# conv2d_95 (Conv2D)           (None, 48, 48, 64)        36928
# _________________________________________________________________
# batch_normalization_120 (Bat (None, 48, 48, 64)        256
# _________________________________________________________________
# activation_130 (Activation)  (None, 48, 48, 64)        0
# _________________________________________________________________
# max_pooling2d_75 (MaxPooling (None, 24, 24, 64)        0
# _________________________________________________________________
# gaussian_noise_15 (GaussianN (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_112 (Dropout)        (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_96 (Conv2D)           (None, 24, 24, 128)       73856
# _________________________________________________________________
# conv2d_97 (Conv2D)           (None, 24, 24, 128)       147584
# _________________________________________________________________
# batch_normalization_121 (Bat (None, 24, 24, 128)       512
# _________________________________________________________________
# activation_131 (Activation)  (None, 24, 24, 128)       0
# _________________________________________________________________
# max_pooling2d_76 (MaxPooling (None, 12, 12, 128)       0
# _________________________________________________________________
# gaussian_noise_16 (GaussianN (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_113 (Dropout)        (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_98 (Conv2D)           (None, 12, 12, 256)       295168
# _________________________________________________________________
# conv2d_99 (Conv2D)           (None, 12, 12, 265)       610825
# _________________________________________________________________
# batch_normalization_122 (Bat (None, 12, 12, 265)       1060
# _________________________________________________________________
# activation_132 (Activation)  (None, 12, 12, 265)       0
# _________________________________________________________________
# max_pooling2d_77 (MaxPooling (None, 6, 6, 265)         0
# _________________________________________________________________
# gaussian_noise_17 (GaussianN (None, 6, 6, 265)         0
# _________________________________________________________________
# dropout_114 (Dropout)        (None, 6, 6, 265)         0
# _________________________________________________________________
# conv2d_100 (Conv2D)          (None, 6, 6, 512)         1221632
# _________________________________________________________________
# conv2d_101 (Conv2D)          (None, 6, 6, 512)         2359808
# _________________________________________________________________
# conv2d_102 (Conv2D)          (None, 6, 6, 512)         262656
# _________________________________________________________________
# batch_normalization_123 (Bat (None, 6, 6, 512)         2048
# _________________________________________________________________
# activation_133 (Activation)  (None, 6, 6, 512)         0
# _________________________________________________________________
# max_pooling2d_78 (MaxPooling (None, 3, 3, 512)         0
# _________________________________________________________________
# gaussian_noise_18 (GaussianN (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_115 (Dropout)        (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten_19 (Flatten)         (None, 4608)              0
# _________________________________________________________________
# dense_56 (Dense)             (None, 2048)              9439232
# _________________________________________________________________
# batch_normalization_124 (Bat (None, 2048)              8192
# _________________________________________________________________
# activation_134 (Activation)  (None, 2048)              0
# _________________________________________________________________
# dropout_116 (Dropout)        (None, 2048)              0
# _________________________________________________________________
# dense_57 (Dense)             (None, 512)               1049088
# _________________________________________________________________
# batch_normalization_125 (Bat (None, 512)               2048
# _________________________________________________________________
# activation_135 (Activation)  (None, 512)               0
# _________________________________________________________________
# dropout_117 (Dropout)        (None, 512)               0
# _________________________________________________________________
# dense_58 (Dense)             (None, 7)                 3591
# _________________________________________________________________
# activation_136 (Activation)  (None, 7)                 0
# =================================================================
# Total params: 15,515,124
# Trainable params: 15,508,066
# Non-trainable params: 7,058
# _________________________________________________________________

# %%
'''
Training
'''
train_flow = datagen.flow(X_train, y_train, batch_size=BATCH_SIZE)
validation_flow = datagen.flow(X_validation, y_validation)

history = model.fit_generator(
    train_flow,
    steps_per_epoch=NUM_TRAIN / BATCH_SIZE,
    epochs=NUM_EPOCHS,
    verbose=1,
    validation_data=validation_flow,
    validation_steps=NUM_VALIDATION / BATCH_SIZE,
    callbacks=[checkpointer, reduce_lr, checkpointer]
)
# Out:
# Epoch 1/64
# 225/224 [==============================] - 59s 260ms/step - loss: 1.9833 - fbeta: 0.0274 - acc: 0.2291 - val_loss: 2.2245 - val_fbeta: 0.0582 - val_acc: 0.1983
#
# Epoch 00001: saving model to Model.01-0.1983.hdf5
#
# Epoch 00001: saving model to Model.01-0.1983.hdf5
# Epoch 2/64
# 225/224 [==============================] - 49s 216ms/step - loss: 1.7117 - fbeta: 0.1114 - acc: 0.3379 - val_loss: 2.0825 - val_fbeta: 0.0399 - val_acc: 0.2856
#
# Epoch 00002: saving model to Model.02-0.2856.hdf5
#
# Epoch 00002: saving model to Model.02-0.2856.hdf5
# Epoch 3/64
# 225/224 [==============================] - 48s 215ms/step - loss: 1.4664 - fbeta: 0.2274 - acc: 0.4396 - val_loss: 1.4095 - val_fbeta: 0.3265 - val_acc: 0.4838
#
# Epoch 00003: saving model to Model.03-0.4838.hdf5
#
# Epoch 00003: saving model to Model.03-0.4838.hdf5
# Epoch 4/64
# 225/224 [==============================] - 48s 215ms/step - loss: 1.3276 - fbeta: 0.2785 - acc: 0.4929 - val_loss: 1.3834 - val_fbeta: 0.3785 - val_acc: 0.4728
#
# Epoch 00004: saving model to Model.04-0.4728.hdf5
#
# Epoch 00004: saving model to Model.04-0.4728.hdf5
# Epoch 5/64
# 225/224 [==============================] - 48s 215ms/step - loss: 1.2653 - fbeta: 0.3058 - acc: 0.5168 - val_loss: 1.3795 - val_fbeta: 0.3588 - val_acc: 0.4838
#
# Epoch 00005: saving model to Model.05-0.4838.hdf5
#
# Epoch 00005: saving model to Model.05-0.4838.hdf5
# Epoch 6/64
# 225/224 [==============================] - 48s 215ms/step - loss: 1.2243 - fbeta: 0.3317 - acc: 0.5336 - val_loss: 1.5249 - val_fbeta: 0.3222 - val_acc: 0.4440
#
# Epoch 00006: saving model to Model.06-0.4440.hdf5
#
# Epoch 00006: saving model to Model.06-0.4440.hdf5
# Epoch 7/64
# 225/224 [==============================] - 48s 215ms/step - loss: 1.1922 - fbeta: 0.3489 - acc: 0.5453 - val_loss: 1.1308 - val_fbeta: 0.3858 - val_acc: 0.5593
#
# Epoch 00007: saving model to Model.07-0.5593.hdf5
#
# Epoch 00007: saving model to Model.07-0.5593.hdf5
# Epoch 8/64
# 225/224 [==============================] - 48s 215ms/step - loss: 1.1735 - fbeta: 0.3634 - acc: 0.5515 - val_loss: 1.2757 - val_fbeta: 0.3396 - val_acc: 0.5194
#
# Epoch 00008: saving model to Model.08-0.5194.hdf5
#
# Epoch 00008: saving model to Model.08-0.5194.hdf5
# Epoch 9/64
# 225/224 [==============================] - 48s 215ms/step - loss: 1.1554 - fbeta: 0.3712 - acc: 0.5591 - val_loss: 1.1312 - val_fbeta: 0.3707 - val_acc: 0.5582
#
# Epoch 00009: saving model to Model.09-0.5582.hdf5
#
# Epoch 00009: saving model to Model.09-0.5582.hdf5
# Epoch 10/64
# 225/224 [==============================] - 48s 215ms/step - loss: 1.1393 - fbeta: 0.3833 - acc: 0.5663 - val_loss: 1.1290 - val_fbeta: 0.4504 - val_acc: 0.5754
#
# Epoch 00010: saving model to Model.10-0.5754.hdf5
#
# Epoch 00010: saving model to Model.10-0.5754.hdf5
# Epoch 11/64
# 225/224 [==============================] - 48s 215ms/step - loss: 1.1234 - fbeta: 0.3907 - acc: 0.5709 - val_loss: 1.1249 - val_fbeta: 0.4267 - val_acc: 0.5808
#
# Epoch 00011: saving model to Model.11-0.5808.hdf5
#
# Epoch 00011: saving model to Model.11-0.5808.hdf5
# Epoch 12/64
# 225/224 [==============================] - 48s 215ms/step - loss: 1.1167 - fbeta: 0.4009 - acc: 0.5783 - val_loss: 1.1314 - val_fbeta: 0.4251 - val_acc: 0.5760
#
# Epoch 00012: saving model to Model.12-0.5760.hdf5
#
# Epoch 00012: saving model to Model.12-0.5760.hdf5
# Epoch 13/64
# 225/224 [==============================] - 48s 215ms/step - loss: 1.0971 - fbeta: 0.4034 - acc: 0.5803 - val_loss: 1.0902 - val_fbeta: 0.4515 - val_acc: 0.5690
#
# Epoch 00013: saving model to Model.13-0.5690.hdf5
#
# Epoch 00013: saving model to Model.13-0.5690.hdf5
# Epoch 14/64
# 225/224 [==============================] - 49s 216ms/step - loss: 1.0921 - fbeta: 0.4117 - acc: 0.5835 - val_loss: 1.0485 - val_fbeta: 0.4483 - val_acc: 0.6099
#
# Epoch 00014: saving model to Model.14-0.6099.hdf5
#
# Epoch 00014: saving model to Model.14-0.6099.hdf5
# Epoch 15/64
# 225/224 [==============================] - 48s 215ms/step - loss: 1.0814 - fbeta: 0.4195 - acc: 0.5897 - val_loss: 1.1489 - val_fbeta: 0.4235 - val_acc: 0.5550
#
# Epoch 00015: saving model to Model.15-0.5550.hdf5
#
# Epoch 00015: saving model to Model.15-0.5550.hdf5
# Epoch 16/64
# 225/224 [==============================] - 48s 215ms/step - loss: 1.0689 - fbeta: 0.4291 - acc: 0.5967 - val_loss: 1.0769 - val_fbeta: 0.4184 - val_acc: 0.5905
#
# Epoch 00016: saving model to Model.16-0.5905.hdf5
#
# Epoch 00016: saving model to Model.16-0.5905.hdf5
# Epoch 17/64
# 225/224 [==============================] - 48s 215ms/step - loss: 1.0682 - fbeta: 0.4290 - acc: 0.5930 - val_loss: 1.1176 - val_fbeta: 0.3847 - val_acc: 0.5927
#
# Epoch 00017: saving model to Model.17-0.5927.hdf5
#
# Epoch 00017: saving model to Model.17-0.5927.hdf5
# Epoch 18/64
# 225/224 [==============================] - 48s 215ms/step - loss: 1.0546 - fbeta: 0.4367 - acc: 0.6005 - val_loss: 1.0828 - val_fbeta: 0.4838 - val_acc: 0.6078
#
# Epoch 00018: saving model to Model.18-0.6078.hdf5
#
# Epoch 00018: saving model to Model.18-0.6078.hdf5
# Epoch 19/64
# 225/224 [==============================] - 49s 216ms/step - loss: 1.0464 - fbeta: 0.4433 - acc: 0.6038 - val_loss: 1.0573 - val_fbeta: 0.4472 - val_acc: 0.5938
#
# Epoch 00019: saving model to Model.19-0.5938.hdf5
#
# Epoch 00019: saving model to Model.19-0.5938.hdf5
# Epoch 20/64
# 225/224 [==============================] - 49s 216ms/step - loss: 1.0361 - fbeta: 0.4509 - acc: 0.6062 - val_loss: 1.0870 - val_fbeta: 0.4595 - val_acc: 0.6038
#
# Epoch 00020: saving model to Model.20-0.6038.hdf5
#
# Epoch 00020: saving model to Model.20-0.6038.hdf5
# Epoch 21/64
# 225/224 [==============================] - 49s 218ms/step - loss: 1.0260 - fbeta: 0.4527 - acc: 0.6081 - val_loss: 1.0400 - val_fbeta: 0.4494 - val_acc: 0.6067
#
# Epoch 00021: saving model to Model.21-0.6067.hdf5
#
# Epoch 00021: saving model to Model.21-0.6067.hdf5
# Epoch 22/64
# 225/224 [==============================] - 48s 215ms/step - loss: 1.0223 - fbeta: 0.4599 - acc: 0.6116 - val_loss: 0.9651 - val_fbeta: 0.5291 - val_acc: 0.6541
#
# Epoch 00022: saving model to Model.22-0.6541.hdf5
#
# Epoch 00022: saving model to Model.22-0.6541.hdf5
# Epoch 23/64
# 225/224 [==============================] - 48s 215ms/step - loss: 1.0176 - fbeta: 0.4628 - acc: 0.6131 - val_loss: 1.1164 - val_fbeta: 0.4149 - val_acc: 0.5776
#
# Epoch 00023: saving model to Model.23-0.5776.hdf5
#
# Epoch 00023: saving model to Model.23-0.5776.hdf5
# Epoch 24/64
# 225/224 [==============================] - 48s 215ms/step - loss: 1.0103 - fbeta: 0.4669 - acc: 0.6178 - val_loss: 1.0431 - val_fbeta: 0.4917 - val_acc: 0.6171
#
# Epoch 00024: saving model to Model.24-0.6171.hdf5
#
# Epoch 00024: saving model to Model.24-0.6171.hdf5
# Epoch 25/64
# 225/224 [==============================] - 48s 215ms/step - loss: 1.0000 - fbeta: 0.4748 - acc: 0.6227 - val_loss: 1.0401 - val_fbeta: 0.4935 - val_acc: 0.5970
#
# Epoch 00025: saving model to Model.25-0.5970.hdf5
#
# Epoch 00025: saving model to Model.25-0.5970.hdf5
# Epoch 26/64
# 225/224 [==============================] - 49s 216ms/step - loss: 0.9922 - fbeta: 0.4765 - acc: 0.6227 - val_loss: 0.9823 - val_fbeta: 0.5022 - val_acc: 0.6272
#
# Epoch 00026: saving model to Model.26-0.6272.hdf5
#
# Epoch 00026: saving model to Model.26-0.6272.hdf5
# Epoch 27/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.9897 - fbeta: 0.4792 - acc: 0.6252 - val_loss: 1.0254 - val_fbeta: 0.4871 - val_acc: 0.6369
#
# Epoch 00027: saving model to Model.27-0.6369.hdf5
#
# Epoch 00027: saving model to Model.27-0.6369.hdf5
# Epoch 28/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.9803 - fbeta: 0.4837 - acc: 0.6289 - val_loss: 1.0935 - val_fbeta: 0.4917 - val_acc: 0.5949
#
# Epoch 00028: saving model to Model.28-0.5949.hdf5
#
# Epoch 00028: saving model to Model.28-0.5949.hdf5
# Epoch 29/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.9746 - fbeta: 0.4899 - acc: 0.6309 - val_loss: 1.0314 - val_fbeta: 0.4914 - val_acc: 0.6153
#
# Epoch 00029: saving model to Model.29-0.6153.hdf5
#
# Epoch 00029: saving model to Model.29-0.6153.hdf5
# Epoch 30/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.9645 - fbeta: 0.4950 - acc: 0.6351 - val_loss: 1.0425 - val_fbeta: 0.5075 - val_acc: 0.6250
#
# Epoch 00030: saving model to Model.30-0.6250.hdf5
#
# Epoch 00030: saving model to Model.30-0.6250.hdf5
# Epoch 31/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.9592 - fbeta: 0.4976 - acc: 0.6339 - val_loss: 1.0519 - val_fbeta: 0.4752 - val_acc: 0.6056
#
# Epoch 00031: saving model to Model.31-0.6056.hdf5
#
# Epoch 00031: saving model to Model.31-0.6056.hdf5
# Epoch 32/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.9514 - fbeta: 0.5026 - acc: 0.6385 - val_loss: 1.0454 - val_fbeta: 0.5305 - val_acc: 0.6149
#
# Epoch 00032: saving model to Model.32-0.6149.hdf5
#
# Epoch 00032: saving model to Model.32-0.6149.hdf5
# Epoch 33/64
# 225/224 [==============================] - 49s 216ms/step - loss: 0.9121 - fbeta: 0.5216 - acc: 0.6557 - val_loss: 1.0040 - val_fbeta: 0.5269 - val_acc: 0.6315
#
# Epoch 00033: saving model to Model.33-0.6315.hdf5
#
# Epoch 00033: saving model to Model.33-0.6315.hdf5
# Epoch 34/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.9016 - fbeta: 0.5265 - acc: 0.6573 - val_loss: 0.9303 - val_fbeta: 0.5259 - val_acc: 0.6552
#
# Epoch 00034: saving model to Model.34-0.6552.hdf5
#
# Epoch 00034: saving model to Model.34-0.6552.hdf5
# Epoch 35/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.8882 - fbeta: 0.5354 - acc: 0.6614 - val_loss: 0.9302 - val_fbeta: 0.5323 - val_acc: 0.6433
#
# Epoch 00035: saving model to Model.35-0.6433.hdf5
#
# Epoch 00035: saving model to Model.35-0.6433.hdf5
# Epoch 36/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.8830 - fbeta: 0.5421 - acc: 0.6688 - val_loss: 0.9685 - val_fbeta: 0.5350 - val_acc: 0.6471
#
# Epoch 00036: saving model to Model.36-0.6471.hdf5
#
# Epoch 00036: saving model to Model.36-0.6471.hdf5
# Epoch 37/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.8799 - fbeta: 0.5413 - acc: 0.6650 - val_loss: 0.9729 - val_fbeta: 0.5388 - val_acc: 0.6562
#
# Epoch 00037: saving model to Model.37-0.6562.hdf5
#
# Epoch 00037: saving model to Model.37-0.6562.hdf5
# Epoch 38/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.8780 - fbeta: 0.5446 - acc: 0.6658 - val_loss: 0.9354 - val_fbeta: 0.5291 - val_acc: 0.6272
#
# Epoch 00038: saving model to Model.38-0.6272.hdf5
#
# Epoch 00038: saving model to Model.38-0.6272.hdf5
# Epoch 39/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.8638 - fbeta: 0.5482 - acc: 0.6705 - val_loss: 0.9192 - val_fbeta: 0.5638 - val_acc: 0.6615
#
# Epoch 00039: saving model to Model.39-0.6615.hdf5
#
# Epoch 00039: saving model to Model.39-0.6615.hdf5
# Epoch 40/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.8664 - fbeta: 0.5497 - acc: 0.6724 - val_loss: 0.8896 - val_fbeta: 0.5647 - val_acc: 0.6735
#
# Epoch 00040: saving model to Model.40-0.6735.hdf5
#
# Epoch 00040: saving model to Model.40-0.6735.hdf5
# Epoch 41/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.8631 - fbeta: 0.5532 - acc: 0.6734 - val_loss: 0.9329 - val_fbeta: 0.5657 - val_acc: 0.6616
#
# Epoch 00041: saving model to Model.41-0.6616.hdf5
#
# Epoch 00041: saving model to Model.41-0.6616.hdf5
# Epoch 42/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.8572 - fbeta: 0.5568 - acc: 0.6747 - val_loss: 1.0151 - val_fbeta: 0.5108 - val_acc: 0.6175
#
# Epoch 00042: saving model to Model.42-0.6175.hdf5
#
# Epoch 00042: saving model to Model.42-0.6175.hdf5
# Epoch 43/64
# 225/224 [==============================] - 48s 214ms/step - loss: 0.8644 - fbeta: 0.5569 - acc: 0.6716 - val_loss: 0.9420 - val_fbeta: 0.5583 - val_acc: 0.6482
#
# Epoch 00043: saving model to Model.43-0.6482.hdf5
#
# Epoch 00043: saving model to Model.43-0.6482.hdf5
# Epoch 44/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.8491 - fbeta: 0.5629 - acc: 0.6775 - val_loss: 0.9428 - val_fbeta: 0.5399 - val_acc: 0.6476
#
# Epoch 00044: saving model to Model.44-0.6476.hdf5
#
# Epoch 00044: saving model to Model.44-0.6476.hdf5
# Epoch 45/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.8507 - fbeta: 0.5606 - acc: 0.6760 - val_loss: 0.9452 - val_fbeta: 0.5560 - val_acc: 0.6573
#
# Epoch 00045: saving model to Model.45-0.6573.hdf5
#
# Epoch 00045: saving model to Model.45-0.6573.hdf5
# Epoch 46/64
# 225/224 [==============================] - 48s 216ms/step - loss: 0.8547 - fbeta: 0.5609 - acc: 0.6751 - val_loss: 0.9709 - val_fbeta: 0.5496 - val_acc: 0.6509
#
# Epoch 00046: saving model to Model.46-0.6509.hdf5
#
# Epoch 00046: saving model to Model.46-0.6509.hdf5
# Epoch 47/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.8432 - fbeta: 0.5614 - acc: 0.6789 - val_loss: 0.9310 - val_fbeta: 0.5527 - val_acc: 0.6648
#
# Epoch 00047: saving model to Model.47-0.6648.hdf5
#
# Epoch 00047: saving model to Model.47-0.6648.hdf5
# Epoch 48/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.8429 - fbeta: 0.5645 - acc: 0.6783 - val_loss: 0.9969 - val_fbeta: 0.5140 - val_acc: 0.6336
#
# Epoch 00048: saving model to Model.48-0.6336.hdf5
#
# Epoch 00048: saving model to Model.48-0.6336.hdf5
# Epoch 49/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.8401 - fbeta: 0.5663 - acc: 0.6815 - val_loss: 0.9284 - val_fbeta: 0.5625 - val_acc: 0.6627
#
# Epoch 00049: saving model to Model.49-0.6627.hdf5
#
# Epoch 00049: saving model to Model.49-0.6627.hdf5
# Epoch 50/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.8352 - fbeta: 0.5684 - acc: 0.6809 - val_loss: 0.9262 - val_fbeta: 0.5679 - val_acc: 0.6659
#
# Epoch 00050: saving model to Model.50-0.6659.hdf5
#
# Epoch 00050: saving model to Model.50-0.6659.hdf5
# Epoch 51/64
# 225/224 [==============================] - 49s 216ms/step - loss: 0.8279 - fbeta: 0.5727 - acc: 0.6864 - val_loss: 0.9529 - val_fbeta: 0.5549 - val_acc: 0.6482
#
# Epoch 00051: saving model to Model.51-0.6482.hdf5
#
# Epoch 00051: saving model to Model.51-0.6482.hdf5
# Epoch 52/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.8292 - fbeta: 0.5740 - acc: 0.6850 - val_loss: 1.0057 - val_fbeta: 0.5334 - val_acc: 0.6466
#
# Epoch 00052: saving model to Model.52-0.6466.hdf5
#
# Epoch 00052: saving model to Model.52-0.6466.hdf5
# Epoch 53/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.8333 - fbeta: 0.5727 - acc: 0.6827 - val_loss: 0.9044 - val_fbeta: 0.5754 - val_acc: 0.6573
#
# Epoch 00053: saving model to Model.53-0.6573.hdf5
#
# Epoch 00053: saving model to Model.53-0.6573.hdf5
# Epoch 54/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.8334 - fbeta: 0.5739 - acc: 0.6849 - val_loss: 0.8633 - val_fbeta: 0.5787 - val_acc: 0.6821
#
# Epoch 00054: saving model to Model.54-0.6821.hdf5
#
# Epoch 00054: saving model to Model.54-0.6821.hdf5
# Epoch 55/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.8315 - fbeta: 0.5728 - acc: 0.6840 - val_loss: 0.9889 - val_fbeta: 0.5350 - val_acc: 0.6537
#
# Epoch 00055: saving model to Model.55-0.6537.hdf5
#
# Epoch 00055: saving model to Model.55-0.6537.hdf5
# Epoch 56/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.8326 - fbeta: 0.5726 - acc: 0.6870 - val_loss: 0.8845 - val_fbeta: 0.5754 - val_acc: 0.6746
#
# Epoch 00056: saving model to Model.56-0.6746.hdf5
#
# Epoch 00056: saving model to Model.56-0.6746.hdf5
# Epoch 57/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.8198 - fbeta: 0.5736 - acc: 0.6872 - val_loss: 0.9492 - val_fbeta: 0.5517 - val_acc: 0.6422
#
# Epoch 00057: saving model to Model.57-0.6422.hdf5
#
# Epoch 00057: saving model to Model.57-0.6422.hdf5
# Epoch 58/64
# 225/224 [==============================] - 48s 216ms/step - loss: 0.8316 - fbeta: 0.5701 - acc: 0.6827 - val_loss: 0.9590 - val_fbeta: 0.5614 - val_acc: 0.6509
#
# Epoch 00058: saving model to Model.58-0.6509.hdf5
#
# Epoch 00058: saving model to Model.58-0.6509.hdf5
# Epoch 59/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.8275 - fbeta: 0.5752 - acc: 0.6879 - val_loss: 0.9466 - val_fbeta: 0.5594 - val_acc: 0.6593
#
# Epoch 00059: saving model to Model.59-0.6593.hdf5
#
# Epoch 00059: saving model to Model.59-0.6593.hdf5
# Epoch 60/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.8273 - fbeta: 0.5737 - acc: 0.6843 - val_loss: 0.9478 - val_fbeta: 0.5420 - val_acc: 0.6466
#
# Epoch 00060: saving model to Model.60-0.6466.hdf5
#
# Epoch 00060: saving model to Model.60-0.6466.hdf5
# Epoch 61/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.8293 - fbeta: 0.5716 - acc: 0.6845 - val_loss: 0.9143 - val_fbeta: 0.5700 - val_acc: 0.6724
#
# Epoch 00061: saving model to Model.61-0.6724.hdf5
#
# Epoch 00061: saving model to Model.61-0.6724.hdf5
# Epoch 62/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.8317 - fbeta: 0.5760 - acc: 0.6872 - val_loss: 0.9613 - val_fbeta: 0.5700 - val_acc: 0.6487
#
# Epoch 00062: saving model to Model.62-0.6487.hdf5
#
# Epoch 00062: saving model to Model.62-0.6487.hdf5
# Epoch 63/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.8277 - fbeta: 0.5726 - acc: 0.6835 - val_loss: 1.0106 - val_fbeta: 0.5494 - val_acc: 0.6382
#
# Epoch 00063: saving model to Model.63-0.6382.hdf5
#
# Epoch 00063: saving model to Model.63-0.6382.hdf5
# Epoch 64/64
# 225/224 [==============================] - 48s 215ms/step - loss: 0.8303 - fbeta: 0.5719 - acc: 0.6839 - val_loss: 0.9274 - val_fbeta: 0.5722 - val_acc: 0.6627
#
# Epoch 00064: saving model to Model.64-0.6627.hdf5
#
# Epoch 00064: saving model to Model.64-0.6627.hdf5

# %%
'''
Evaluation
'''
score = model.evaluate(X_test, y_test, steps=int(NUM_TEST / BATCH_SIZE))
print('Evaluation Loss: ', score[0])
print('Evaluation Accuracy: ', score[1])

# History of Accuracy
hist_acc = 'accuracy.png'
fig1 = plt.figure()
plt.plot(history.history['acc'], color='b', label='Training')
plt.plot(history.history['val_acc'], color='g', label='Validation')
plt.title('History for Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
fig1.savefig(hist_acc)
plt.show() 

# History of Loss
loss_acc = 'loss.png'
fig2 = plt.figure()
plt.plot(history.history['loss'], color='b', label='Training')
plt.plot(history.history['val_loss'], color='g', label='Validation')
plt.title('History for Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='lower left')
fig1.savefig(loss_acc)
plt.show()

y_pred = model.predict_classes(X_test)
y_true = np.asarray([np.argmax(i) for i in y_test])

cm = confusion_matrix(y_true, y_pred)
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
sns.set(font_scale=1.5)
fig, ax = plt.subplots(figsize=(10,10))
ax = sns.heatmap(cm_norm, annot=True, linewidths=0, square=False, cmap='Greens', yticklabels=EMOTION_LABELS, xticklabels=EMOTION_LABELS, vmin=0, vmax=np.max(cm_norm), fmt='.2f', annot_kws={'size': 20})
ax.set(xlabel='Predicted Labels', ylabel='Actual Labels')

plt.show()
# Out:
# 28/28 [==============================] - 49s 2s/step
# Evaluation Loss:  0.9010893702507019
# Evaluation Accuracy:  0.5736973881721497
