# %%
# Extra Setup for Colaboratory Environment

#!pip install cmake
#!pip install dlib

#from google.colab import files
#uploaded = files.upload() 

#!7za e colaboratory_dependencies.7z
#!7za x frontalization_models.7z
#!7za x dlib_models.7z

# %%
'''
Libraries, etc.
'''
import os
import sys
import cv2
import numpy as np 
import scipy as sp
import pandas as pd 
import seaborn as sns
from math import sqrt
import scipy.io as io
import tensorflow as tf 
from pathlib import Path
import matplotlib.pyplot as plt 
from sklearn.metrics import confusion_matrix

from keras import backend as K
from keras.utils import np_utils
from keras.models import Sequential
from keras.utils import np_utils as npu
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.layers import Convolution2D, Activation, BatchNormalization, GaussianNoise, MaxPooling2D, Dropout, Dense, Flatten

import frontalize
import check_resources as check
import camera_calibration as calib
import facial_feature_detector as feature_detection

from models import get_model1, get_model2, get_model3

#this_path = os.path.dirname(os.path.abspath(__file__)) 
this_path = str(Path().resolve()) # for Colaboratory

# %%
'''
Constants, Hyperparameters, etc.
'''
BATCH_SIZE = 128
NUM_EPOCHS = 85
input_file = 'fer2013.csv'
filepath = 'Model.{epoch:02d}-{val_acc:.4f}.hdf5'

model1_acc_file = "acc_model1_t2.png"
model2_acc_file = "acc_model2_t2.png"
model3_acc_file = "acc_model3_t2.png"
model4_acc_file = "acc_model4_t2.png"
acc_file = model1_acc_file

model1_loss_file = "loss_model1_t2.png"
model2_loss_file = "loss_model2_t2.png"
model3_loss_file = "loss_model3_t2.png"
model4_loss_file = "loss_model4_t2.png"
loss_file = model1_loss_file

model1_cm_file = "cm_model1_t2.png"
model2_cm_file = "cm_model2_t2.png"
model3_cm_file = "cm_model3_t2.png"
model4_cm_file = "cm_model4_t2.png"
cm_file = model1_cm_file

emotion_labels = ["Angry", "Disgust", "Fear", "Happy", "Sad", "Surprise", "Neutral"]
num_classes = len(emotion_labels)

# %%
'''
Load & Parse Data into Training/Test Labels & Images
'''
data = pd.read_csv(input_file)
data.head()

# get data and labels
train_set = data[(data.Usage == 'Training')]
validation_set = data[(data.Usage == 'PublicTest')]
test_set = data[(data.Usage == 'PrivateTest')]

# greyscale so depth 1
depth = 1
height = int(sqrt(len(data.pixels[0].split())))
width = height

# from pandas to np array
X_train = np.array(list(map(str.split, train_set.pixels)), np.uint8)
X_validation = np.array(list(map(str.split, validation_set.pixels)), np.uint8)
X_test = np.array(list(map(str.split, test_set.pixels)), np.uint8)

# reshape data
num_train = X_train.shape[0]
num_validation = X_validation.shape[0]
num_test = X_test.shape[0]

X_train = X_train.reshape(num_train, width, height, depth)
X_validation = X_validation.reshape(num_validation, width, height, depth)
X_test = X_test.reshape(num_test, width, height, depth)

y_train = train_set.emotion
y_validation = validation_set.emotion
y_test = test_set.emotion

y_train = np_utils.to_categorical(y_train, num_classes)
y_validation = np_utils.to_categorical(y_validation, num_classes)
y_test = np_utils.to_categorical(y_test, num_classes)

# print shapes
print('X_training: ', X_train.shape)
print('X_validation: ', X_validation.shape)
print('X_test: ', X_test.shape)
print( )
print('y_training: ', y_train.shape)
print('y_validation: ', y_validation.shape)
print('y_test: ', y_test.shape)
# Out:
# X_training:  (28709, 48, 48, 1)
# X_validation:  (3589, 48, 48, 1)
# X_test:  (3589, 48, 48, 1)
#
# y_training:  (28709, 7)
# y_validation:  (3589, 7)
# y_test:  (3589, 7)

# %%
'''
Frontalization Function
'''
def myfrontalize(X, limit=0):
  count = 0

  if (limit == 0):
    limit = X.shape[0]
    
  print("Total Images: ", limit)
    
  # check for dlib saved weights for face landmark detection
  # if it fails, dowload and extract it manually from
  # http://sourceforge.net/projects/dclib/files/dlib/v18.10/shape_predictor_68_face_landmarks.dat.bz2
  check.check_dlib_landmark_weights()
    
  # load detections performed by dlib library on 3D model and Reference Image
  model3D = frontalize.ThreeD_Model(this_path + "/frontalization_models/model3Ddlib.mat", 'model_dlib')
  
  # load mask to exclude eyes from symmetry
  eyemask = np.asarray(io.loadmat('frontalization_models/eyemask.mat')['eyemask'])
        
  for i in range(0, limit):
    print("\r", end='')
    print("Images Completed: {0}".format(i), end='', flush=True)

    # cast img to type int for cv2
    img = X[i, :, :, 0].astype(np.uint8)
    
    # create a color version for frontalizer stuffs
    c_img = np.copy(img)
    c_img = cv2.cvtColor(c_img, cv2.COLOR_GRAY2BGR)    
    
    # extract landmarks from the query image
    # list containing a 2D array with points (x, y) for each face detected in the query image
    lmarks = feature_detection.get_landmarks(c_img)
    if type(lmarks) is np.ndarray:
      
      # perform camera calibration according to the first face detected
      proj_matrix, camera_matrix, rmat, tvec = calib.estimate_camera(model3D, lmarks[0])
      
      # perform frontalization and convert result to grayscale
      frontal_raw, frontal_sym = frontalize.frontalize(c_img, proj_matrix, model3D.ref_U, eyemask)
      temp = cv2.cvtColor(frontal_raw, cv2.COLOR_BGR2GRAY)
    
      # find nonzero bbox and crop image to remove uncessesary black space from edges           
      temp_mask = cv2.findNonZero(temp)     
      t_x, t_y, t_w, t_h = cv2.boundingRect(temp_mask)
      t_bbox = temp[t_y:t_y+t_h, t_x:t_x+t_w]

      # resize the cropped image to the appropriate dimensions for network
      t_bbox = cv2.resize(t_bbox, dsize=(48, 48))  
      t_bbox = np.resize(t_bbox, (48, 48, 1))   
      X[i] = t_bbox.astype(np.float32)
    
      plt.show()
      count += 1
      
  print( )
  print('{} images out of {} were frontalized.'.format(count, limit))

# %%
'''
Histogram Equalization - Not defined as method, because 
train has a special case to catch and delete harmful inputs
'''
clahe = cv2.createCLAHE(clipLimit=3.235, tileGridSize=(5,5))

# original image set
X_train1 = X_train.copy().astype(np.uint8)
X_val1 = X_validation.copy().astype(np.uint8)
X_test1 = X_test.copy().astype(np.uint8)

# linear histogram equalization set
X_train2 = X_train1.copy() 
X_val2 = X_val1.copy()
X_test2 = X_test1.copy()

# clahe set
X_train3 = X_train1.copy()
X_val3 = X_val1.copy()
X_test3 = X_test1.copy()

# frontalized set
X_train4 = X_train1.copy()
X_val4 = X_val1.copy()
X_test4 = X_test1.copy()

# histogram equalization
i = 0
while (i < num_train):
  tMax = X_train1[i].max()
  tMin = X_train1[i].min()  

  if (tMax > tMin):
    tRatio = 255 / (tMax - tMin)
    X_train2[i] = np.multiply((X_train1[i] - tMin), tRatio)
    X_train3[i] = clahe.apply(X_train2[i])[:,:,np.newaxis]
    i += 1
    
  # Delete harmful training examples from X_train
  else:
    X_train1 = np.delete(X_train1, (i), axis=0)
    X_train2 = np.delete(X_train2, (i), axis=0)
    X_train3 = np.delete(X_train3, (i), axis=0)
    X_train4 = np.delete(X_train4, (i), axis=0)
    y_train = np.delete(y_train, (i), axis=0)
    num_train -= 1
  
i = 0
while (i < num_validation):
  tMax = X_val1[i].max()
  tMin = X_val1[i].min()

  if (tMax > tMin):
    tRatio = 255 / (tMax - tMin)
    X_val2[i] = np.multiply((X_val1[i] - tMin), tRatio).round()
    
  # Shouldn't delete validation data... skip so we don't divide by 0
  else:
    X_val2[i] = X_val1[i]

  X_val3[i] = clahe.apply(X_val2[i])[:,:,np.newaxis]
  i += 1

i = 0
while (i < num_test):
  tMax = X_test1[i].max()
  tMin = X_test1[i].min()

  if (tMax > tMin):
    tRatio = 255 / (tMax - tMin)
    X_test2[i] = np.multiply((X_test1[i] - tMin), tRatio).round()
    
  # Shouldn't delete test data... skip so we don't divide by 0
  else:
    X_test2[i] = X_test1[i]
    
  X_test3[i] = clahe.apply(X_test2[i])[:,:,np.newaxis]
  i += 1
  
# apply frontalization
#print("Attempting to frontalize image data...")
#myfrontalize(X_train4, num_train)
#np.save('X_train_frontalized', X_train4)

#myfrontalize(X_val4, num_validation)
#np.save('X_val_frontalized', X_val4)

#myfrontalize(X_test4, num_test)
#np.save('X_test_frontalized', X_test4)

X_train4 = np.load('X_train_frontalized.npy')
X_val4 = np.load('X_val_frontalized.npy')
X_test4 = np.load('X_test_frontalized.npy')


# print examples from each set
print('Original Images')
for x in range(1,6):
    plt.subplot(1, 5, x)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_train1[x,:,:,0], cmap='gray') 
plt.show()

print('Original w/ Linear Transform to normalize pixel values')
for x in range(1,6):
    plt.subplot(1, 5, x)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_train2[x,:,:,0], cmap='gray')   
plt.show()

print('Normalized w/ Contrast Limited Adaptive Histogram Equalization')
for x in range(1,6):
    plt.subplot(1, 5, x)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_train3[x,:,:,0], cmap='gray')    
plt.show() 

print('Frontalized, Cropped, and Resized')
for x in range(1,6):
  plt.subplot(1, 5, x)
  plt.xticks([])
  plt.yticks([])
  plt.imshow(X_train4[x, :, :, 0], cmap='gray') 
    
plt.show()
# Out:
# Original Images
# Original w/ Linear Transform to normalize pixel values
# Normalized w/ Contrast Limited Adaptive Histogram Equalization
# Frontalized, Cropped, and Resized

# %%
'''
TensorFlow Model(s)
'''

# shallow model
def get_model1():
  model = Sequential()

  model.add(Convolution2D(64, (3, 3), padding='same', input_shape=(48,48,1)))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(128, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(256, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Flatten())

  model.add(Dense(512))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(256))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(7))
  model.add(Activation('softmax'))

  return model

# actual model
def get_model2():
  model = Sequential()

  model.add(Convolution2D(64, (3, 3), padding='same', input_shape=(48,48,1)))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(128, (5, 5), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Flatten())

  model.add(Dense(256))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(512))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(7))
  model.add(Activation('softmax'))

  return model

# deeper model
def get_model3():
  model = Sequential()

  model.add(Convolution2D(64, (3, 3), padding='same', input_shape=(48,48,1)))
  model.add(Convolution2D(64, (3, 3), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.4))

  model.add(Convolution2D(128, (3, 3), padding='same'))
  model.add(Convolution2D(128, (3, 3), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.4))

  model.add(Convolution2D(256, (3, 3), padding='same'))
  model.add(Convolution2D(265, (3, 3), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.4))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(Convolution2D(512, (3, 3), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.4))

  model.add(Flatten())

  model.add(Dense(2048))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.4))

  model.add(Dense(512))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.4))

  model.add(Dense(7))
  model.add(Activation('softmax'))

  return model

# shallow model
def get_model4():
  model = Sequential()

  model.add(Convolution2D(64, (3, 3), padding='same', input_shape=(48,48,1)))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(128, (5, 5), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Flatten())

  model.add(Dense(256))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(7))
  model.add(Activation('softmax'))

  return model

# %%
'''
Metric(s)
'''

# metric to balance precision and recall
def fbeta(y_true, y_pred, threshold_shift=0):
  beta = 1

  # just in case of hipster activation at the final layer
  y_pred = K.clip(y_pred, 0, 1)

  # shifting the prediction threshold from .5 if needed
  y_pred_bin = K.round(y_pred + threshold_shift)

  tp = K.sum(K.round(y_true * y_pred_bin), axis=1) + K.epsilon()
  fp = K.sum(K.round(K.clip(y_pred_bin - y_true, 0, 1)), axis=1)
  fn = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=1)

  precision = tp / (tp + fp)
  recall = tp / (tp + fn)

  beta_squared = beta ** 2
  return K.mean((beta_squared + 1) * (precision * recall) / (beta_squared * precision + recall + K.epsilon()))

# %%
'''
Prepare Model for Training
'''
# assign the desired model from above
model1 = get_model1()
model2 = get_model2()
model3 = get_model3()
model4 = get_model4()

#model.summary()

num_train = len(X_train)

# assign X to the desired image set(s) from above
X_train = X_train3.copy()
X_validation = X_val3.copy()
X_test = X_test3.copy()

# reshape X to expected shape and cast it back to type float32
X_train = X_train.reshape(num_train,width,height,1).astype(np.float32)
X_validation = X_validation.reshape(num_validation,width,height,1).astype(np.float32)
X_test = X_test.reshape(num_test,width,height,1).astype(np.float32)

# augment and fit data
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    rotation_range=0,
    width_shift_range=0.0,
    height_shift_range=0.0,
    shear_range=0,
    zoom_range=0.0,
    horizontal_flip=True,
    vertical_flip=False)
datagen.fit(X_train)
datagen.fit(X_validation)

# to be applied during training
checkpointer = ModelCheckpoint(
    filepath, monitor='val_loss', verbose=1, 
    save_best_only=False, mode='auto')
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', factor=0.1, 
    patience=10, verbose=0, mode='auto', 
    min_delta=0.0001, cooldown=0, min_lr=0)
early_stop = EarlyStopping(
    monitor='val_loss', min_delta=0, patience=0, 
    verbose=0, mode='auto')

# prepare model to train
model1.compile(
    loss='categorical_crossentropy', 
    optimizer='adam', 
    metrics=[fbeta, 'accuracy'])

model2.compile(
    loss='categorical_crossentropy', 
    optimizer='adam', 
    metrics=[fbeta, 'accuracy'])

model3.compile(
    loss='categorical_crossentropy', 
    optimizer='adam', 
    metrics=[fbeta, 'accuracy'])

model4.compile(
    loss='categorical_crossentropy', 
    optimizer='adam', 
    metrics=[fbeta, 'accuracy'])

# %%
'''
Training
'''
train_flow = datagen.flow(X_train, y_train, batch_size=BATCH_SIZE)
validation_flow = datagen.flow(X_validation, y_validation)

history1 = model1.fit_generator(
    train_flow,
    steps_per_epoch= num_train / BATCH_SIZE,
    epochs=NUM_EPOCHS,
    verbose=1,
    validation_data=validation_flow,
    validation_steps=num_validation / BATCH_SIZE,
    callbacks=[checkpointer, reduce_lr, checkpointer]
)

history2 = model2.fit_generator(
    train_flow,
    steps_per_epoch= num_train / BATCH_SIZE,
    epochs=NUM_EPOCHS,
    verbose=1,
    validation_data=validation_flow,
    validation_steps=num_validation / BATCH_SIZE,
    callbacks=[checkpointer, reduce_lr, checkpointer]
)

history3 = model3.fit_generator(
    train_flow,
    steps_per_epoch= num_train / BATCH_SIZE,
    epochs=NUM_EPOCHS,
    verbose=1,
    validation_data=validation_flow,
    validation_steps=num_validation / BATCH_SIZE,
    callbacks=[checkpointer, reduce_lr, checkpointer]
)

history4 = model4.fit_generator(
    train_flow,
    steps_per_epoch= num_train / BATCH_SIZE,
    epochs=NUM_EPOCHS,
    verbose=1,
    validation_data=validation_flow,
    validation_steps=num_validation / BATCH_SIZE,
    callbacks=[checkpointer, reduce_lr, checkpointer]
)
# Out:
# Epoch 1/85
# 225/224 [==============================] - 14s 61ms/step - loss: 1.7058 - fbeta: 0.1638 - acc: 0.3548 - val_loss: 2.2625 - val_fbeta: 0.2780 - val_acc: 0.3147
#
# Epoch 00001: saving model to Model.01-0.3147.hdf5
#
# Epoch 00001: saving model to Model.01-0.3147.hdf5
# Epoch 2/85
# 225/224 [==============================] - 8s 34ms/step - loss: 1.3843 - fbeta: 0.2671 - acc: 0.4679 - val_loss: 1.3305 - val_fbeta: 0.3384 - val_acc: 0.5065
#
# Epoch 00002: saving model to Model.02-0.5065.hdf5
#
# Epoch 00002: saving model to Model.02-0.5065.hdf5
# Epoch 3/85
# 225/224 [==============================] - 8s 35ms/step - loss: 1.2593 - fbeta: 0.3175 - acc: 0.5164 - val_loss: 1.2679 - val_fbeta: 0.3147 - val_acc: 0.5054
#
# Epoch 00003: saving model to Model.03-0.5054.hdf5
#
# Epoch 00003: saving model to Model.03-0.5054.hdf5
# Epoch 4/85
# 225/224 [==============================] - 8s 36ms/step - loss: 1.1913 - fbeta: 0.3517 - acc: 0.5482 - val_loss: 1.1832 - val_fbeta: 0.3896 - val_acc: 0.5616
#
# Epoch 00004: saving model to Model.04-0.5616.hdf5
#
# Epoch 00004: saving model to Model.04-0.5616.hdf5
# Epoch 5/85
# 225/224 [==============================] - 8s 35ms/step - loss: 1.1449 - fbeta: 0.3808 - acc: 0.5674 - val_loss: 1.1410 - val_fbeta: 0.3966 - val_acc: 0.5517
#
# Epoch 00005: saving model to Model.05-0.5517.hdf5
#
# Epoch 00005: saving model to Model.05-0.5517.hdf5
# Epoch 6/85
# 225/224 [==============================] - 8s 35ms/step - loss: 1.1115 - fbeta: 0.4008 - acc: 0.5798 - val_loss: 1.2021 - val_fbeta: 0.3890 - val_acc: 0.5485
#
# Epoch 00006: saving model to Model.06-0.5485.hdf5
#
# Epoch 00006: saving model to Model.06-0.5485.hdf5
# Epoch 7/85
# 225/224 [==============================] - 8s 35ms/step - loss: 1.0778 - fbeta: 0.4189 - acc: 0.5923 - val_loss: 1.1563 - val_fbeta: 0.4106 - val_acc: 0.5722
#
# Epoch 00007: saving model to Model.07-0.5722.hdf5
#
# Epoch 00007: saving model to Model.07-0.5722.hdf5
# Epoch 8/85
# 225/224 [==============================] - 8s 35ms/step - loss: 1.0486 - fbeta: 0.4373 - acc: 0.6035 - val_loss: 1.2752 - val_fbeta: 0.3319 - val_acc: 0.4950
#
# Epoch 00008: saving model to Model.08-0.4950.hdf5
#
# Epoch 00008: saving model to Model.08-0.4950.hdf5
# Epoch 9/85
# 225/224 [==============================] - 8s 35ms/step - loss: 1.0232 - fbeta: 0.4574 - acc: 0.6135 - val_loss: 1.1504 - val_fbeta: 0.4300 - val_acc: 0.5744
#
# Epoch 00009: saving model to Model.09-0.5744.hdf5
#
# Epoch 00009: saving model to Model.09-0.5744.hdf5
# Epoch 10/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.9972 - fbeta: 0.4720 - acc: 0.6236 - val_loss: 1.0519 - val_fbeta: 0.4407 - val_acc: 0.6175
#
# Epoch 00010: saving model to Model.10-0.6175.hdf5
#
# Epoch 00010: saving model to Model.10-0.6175.hdf5
# Epoch 11/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.9768 - fbeta: 0.4866 - acc: 0.6318 - val_loss: 1.1987 - val_fbeta: 0.4386 - val_acc: 0.5636
#
# Epoch 00011: saving model to Model.11-0.5636.hdf5
#
# Epoch 00011: saving model to Model.11-0.5636.hdf5
# Epoch 12/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.9587 - fbeta: 0.4997 - acc: 0.6373 - val_loss: 1.1391 - val_fbeta: 0.4073 - val_acc: 0.5627
#
# Epoch 00012: saving model to Model.12-0.5627.hdf5
#
# Epoch 00012: saving model to Model.12-0.5627.hdf5
# Epoch 13/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.9329 - fbeta: 0.5144 - acc: 0.6466 - val_loss: 1.0938 - val_fbeta: 0.4591 - val_acc: 0.5991ss:
#
# Epoch 00013: saving model to Model.13-0.5991.hdf5
#
# Epoch 00013: saving model to Model.13-0.5991.hdf5
# Epoch 14/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.9160 - fbeta: 0.5277 - acc: 0.6543 - val_loss: 1.1635 - val_fbeta: 0.4353 - val_acc: 0.5733
#
# Epoch 00014: saving model to Model.14-0.5733.hdf5
#
# Epoch 00014: saving model to Model.14-0.5733.hdf5
# Epoch 15/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.8963 - fbeta: 0.5361 - acc: 0.6607 - val_loss: 1.0388 - val_fbeta: 0.5022 - val_acc: 0.6207 - fbeta:
#
# Epoch 00015: saving model to Model.15-0.6207.hdf5
#
# Epoch 00015: saving model to Model.15-0.6207.hdf5
# Epoch 16/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.8723 - fbeta: 0.5535 - acc: 0.6713 - val_loss: 0.9939 - val_fbeta: 0.5205 - val_acc: 0.6337
#
# Epoch 00016: saving model to Model.16-0.6337.hdf5
#
# Epoch 00016: saving model to Model.16-0.6337.hdf5
# Epoch 17/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.8523 - fbeta: 0.5655 - acc: 0.6816 - val_loss: 1.3595 - val_fbeta: 0.4095 - val_acc: 0.5323
#
# Epoch 00017: saving model to Model.17-0.5323.hdf5
#
# Epoch 00017: saving model to Model.17-0.5323.hdf5
# Epoch 18/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.8333 - fbeta: 0.5732 - acc: 0.6839 - val_loss: 1.1480 - val_fbeta: 0.5097 - val_acc: 0.5841
#
# Epoch 00018: saving model to Model.18-0.5841.hdf5
#
# Epoch 00018: saving model to Model.18-0.5841.hdf5
# Epoch 19/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.8174 - fbeta: 0.5909 - acc: 0.6929 - val_loss: 1.1712 - val_fbeta: 0.4763 - val_acc: 0.5657
#
# Epoch 00019: saving model to Model.19-0.5657.hdf5
#
# Epoch 00019: saving model to Model.19-0.5657.hdf5
# Epoch 20/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.7938 - fbeta: 0.6032 - acc: 0.7025 - val_loss: 0.9985 - val_fbeta: 0.5261 - val_acc: 0.6382
#
# Epoch 00020: saving model to Model.20-0.6382.hdf5
#
# Epoch 00020: saving model to Model.20-0.6382.hdf5
# Epoch 21/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.7741 - fbeta: 0.6201 - acc: 0.7114 - val_loss: 1.0196 - val_fbeta: 0.5129 - val_acc: 0.6196
#
# Epoch 00021: saving model to Model.21-0.6196.hdf5
#
# Epoch 00021: saving model to Model.21-0.6196.hdf5
# Epoch 22/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.7510 - fbeta: 0.6268 - acc: 0.7173 - val_loss: 1.3311 - val_fbeta: 0.4968 - val_acc: 0.5539: 2s - loss: 0.7404 - fbeta: 0.6320 - acc: 0.720 - ETA: 2s - loss
#
# Epoch 00022: saving model to Model.22-0.5539.hdf5
#
# Epoch 00022: saving model to Model.22-0.5539.hdf5
# Epoch 23/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.7345 - fbeta: 0.6389 - acc: 0.7280 - val_loss: 1.0441 - val_fbeta: 0.5463 - val_acc: 0.6282
#
# Epoch 00023: saving model to Model.23-0.6282.hdf5
#
# Epoch 00023: saving model to Model.23-0.6282.hdf5
# Epoch 24/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.7188 - fbeta: 0.6490 - acc: 0.7324 - val_loss: 1.1170 - val_fbeta: 0.5250 - val_acc: 0.6149
#
# Epoch 00024: saving model to Model.24-0.6149.hdf5
#
# Epoch 00024: saving model to Model.24-0.6149.hdf5
# Epoch 25/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.6948 - fbeta: 0.6634 - acc: 0.7392 - val_loss: 1.1025 - val_fbeta: 0.5043 - val_acc: 0.6142
#
# Epoch 00025: saving model to Model.25-0.6142.hdf5
#
# Epoch 00025: saving model to Model.25-0.6142.hdf5
# Epoch 26/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.6823 - fbeta: 0.6724 - acc: 0.7421 - val_loss: 1.2954 - val_fbeta: 0.5226 - val_acc: 0.5754
#
# Epoch 00026: saving model to Model.26-0.5754.hdf5
#
# Epoch 00026: saving model to Model.26-0.5754.hdf5
# Epoch 27/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.6111 - fbeta: 0.7019 - acc: 0.7739 - val_loss: 0.9932 - val_fbeta: 0.5927 - val_acc: 0.6670
#
# Epoch 00027: saving model to Model.27-0.6670.hdf5
#
# Epoch 00027: saving model to Model.27-0.6670.hdf5
# Epoch 28/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.5893 - fbeta: 0.7136 - acc: 0.7796 - val_loss: 0.9519 - val_fbeta: 0.6049 - val_acc: 0.6670
#
# Epoch 00028: saving model to Model.28-0.6670.hdf5
#
# Epoch 00028: saving model to Model.28-0.6670.hdf5
# Epoch 29/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.5719 - fbeta: 0.7243 - acc: 0.7869 - val_loss: 1.0165 - val_fbeta: 0.5991 - val_acc: 0.6573
#
# Epoch 00029: saving model to Model.29-0.6573.hdf5
#
# Epoch 00029: saving model to Model.29-0.6573.hdf5
# Epoch 30/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.5597 - fbeta: 0.7329 - acc: 0.7945 - val_loss: 1.0306 - val_fbeta: 0.5970 - val_acc: 0.6433
#
# Epoch 00030: saving model to Model.30-0.6433.hdf5
#
# Epoch 00030: saving model to Model.30-0.6433.hdf5
# Epoch 31/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.5415 - fbeta: 0.7430 - acc: 0.7990 - val_loss: 0.9700 - val_fbeta: 0.6153 - val_acc: 0.6746
#
# Epoch 00031: saving model to Model.31-0.6746.hdf5
#
# Epoch 00031: saving model to Model.31-0.6746.hdf5
# Epoch 32/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.5385 - fbeta: 0.7469 - acc: 0.7989 - val_loss: 1.0325 - val_fbeta: 0.6104 - val_acc: 0.6659
#
# Epoch 00032: saving model to Model.32-0.6659.hdf5
#
# Epoch 00032: saving model to Model.32-0.6659.hdf5
# Epoch 33/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.5336 - fbeta: 0.7484 - acc: 0.8019 - val_loss: 0.9886 - val_fbeta: 0.6239 - val_acc: 0.6875
#
# Epoch 00033: saving model to Model.33-0.6875.hdf5
#
# Epoch 00033: saving model to Model.33-0.6875.hdf5
# Epoch 34/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.5244 - fbeta: 0.7561 - acc: 0.8064 - val_loss: 0.9880 - val_fbeta: 0.6218 - val_acc: 0.6713
#
# Epoch 00034: saving model to Model.34-0.6713.hdf5
#
# Epoch 00034: saving model to Model.34-0.6713.hdf5
# Epoch 35/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.5208 - fbeta: 0.7569 - acc: 0.8076 - val_loss: 1.0500 - val_fbeta: 0.6175 - val_acc: 0.6670
#
# Epoch 00035: saving model to Model.35-0.6670.hdf5
#
# Epoch 00035: saving model to Model.35-0.6670.hdf5
# Epoch 36/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.5090 - fbeta: 0.7637 - acc: 0.8092 - val_loss: 1.0458 - val_fbeta: 0.6027 - val_acc: 0.6681 fbeta:
#
# Epoch 00036: saving model to Model.36-0.6681.hdf5
#
# Epoch 00036: saving model to Model.36-0.6681.hdf5
# Epoch 37/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.5050 - fbeta: 0.7678 - acc: 0.8154 - val_loss: 1.0239 - val_fbeta: 0.6315 - val_acc: 0.6821
#
# Epoch 00037: saving model to Model.37-0.6821.hdf5
#
# Epoch 00037: saving model to Model.37-0.6821.hdf5
# Epoch 38/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.5005 - fbeta: 0.7697 - acc: 0.8155 - val_loss: 1.0342 - val_fbeta: 0.6261 - val_acc: 0.6692
#
# Epoch 00038: saving model to Model.38-0.6692.hdf5
#
# Epoch 00038: saving model to Model.38-0.6692.hdf5
# Epoch 39/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4815 - fbeta: 0.7778 - acc: 0.8226 - val_loss: 1.0219 - val_fbeta: 0.6049 - val_acc: 0.6570
#
# Epoch 00039: saving model to Model.39-0.6570.hdf5
#
# Epoch 00039: saving model to Model.39-0.6570.hdf5
# Epoch 40/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4822 - fbeta: 0.7757 - acc: 0.8221 - val_loss: 1.0453 - val_fbeta: 0.6110 - val_acc: 0.6584
#
# Epoch 00040: saving model to Model.40-0.6584.hdf5
#
# Epoch 00040: saving model to Model.40-0.6584.hdf5
# Epoch 41/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4772 - fbeta: 0.7791 - acc: 0.8233 - val_loss: 0.9458 - val_fbeta: 0.6390 - val_acc: 0.7026
#
# Epoch 00041: saving model to Model.41-0.7026.hdf5
#
# Epoch 00041: saving model to Model.41-0.7026.hdf5
# Epoch 42/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4825 - fbeta: 0.7781 - acc: 0.8212 - val_loss: 1.1542 - val_fbeta: 0.6078 - val_acc: 0.6476
#
# Epoch 00042: saving model to Model.42-0.6476.hdf5
#
# Epoch 00042: saving model to Model.42-0.6476.hdf5
# Epoch 43/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4831 - fbeta: 0.7760 - acc: 0.8207 - val_loss: 0.9775 - val_fbeta: 0.6437 - val_acc: 0.6792
#
# Epoch 00043: saving model to Model.43-0.6792.hdf5
#
# Epoch 00043: saving model to Model.43-0.6792.hdf5
# Epoch 44/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4839 - fbeta: 0.7748 - acc: 0.8196 - val_loss: 1.0302 - val_fbeta: 0.6304 - val_acc: 0.6703
#
# Epoch 00044: saving model to Model.44-0.6703.hdf5
#
# Epoch 00044: saving model to Model.44-0.6703.hdf5
# Epoch 45/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.4804 - fbeta: 0.7774 - acc: 0.8215 - val_loss: 1.0382 - val_fbeta: 0.6336 - val_acc: 0.6810
#
# Epoch 00045: saving model to Model.45-0.6810.hdf5
#
# Epoch 00045: saving model to Model.45-0.6810.hdf5
# Epoch 46/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.4782 - fbeta: 0.7805 - acc: 0.8235 - val_loss: 1.0730 - val_fbeta: 0.6228 - val_acc: 0.6659
#
# Epoch 00046: saving model to Model.46-0.6659.hdf5
#
# Epoch 00046: saving model to Model.46-0.6659.hdf5
# Epoch 47/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4811 - fbeta: 0.7767 - acc: 0.8204 - val_loss: 1.0176 - val_fbeta: 0.6315 - val_acc: 0.6759
#
# Epoch 00047: saving model to Model.47-0.6759.hdf5
#
# Epoch 00047: saving model to Model.47-0.6759.hdf5
# Epoch 48/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4814 - fbeta: 0.7789 - acc: 0.8199 - val_loss: 1.0055 - val_fbeta: 0.6164 - val_acc: 0.6606
#
# Epoch 00048: saving model to Model.48-0.6606.hdf5
#
# Epoch 00048: saving model to Model.48-0.6606.hdf5
# Epoch 49/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.4749 - fbeta: 0.7796 - acc: 0.8231 - val_loss: 1.0129 - val_fbeta: 0.6455 - val_acc: 0.6789
#
# Epoch 00049: saving model to Model.49-0.6789.hdf5
#
# Epoch 00049: saving model to Model.49-0.6789.hdf5
# Epoch 50/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.4812 - fbeta: 0.7776 - acc: 0.8217 - val_loss: 1.1061 - val_fbeta: 0.6196 - val_acc: 0.6519
#
# Epoch 00050: saving model to Model.50-0.6519.hdf5
#
# Epoch 00050: saving model to Model.50-0.6519.hdf5
# Epoch 51/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4759 - fbeta: 0.7817 - acc: 0.8235 - val_loss: 1.0158 - val_fbeta: 0.6304 - val_acc: 0.6804
#
# Epoch 00051: saving model to Model.51-0.6804.hdf5
#
# Epoch 00051: saving model to Model.51-0.6804.hdf5
# Epoch 52/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.4707 - fbeta: 0.7818 - acc: 0.8254 - val_loss: 1.0502 - val_fbeta: 0.6336 - val_acc: 0.6627
#
# Epoch 00052: saving model to Model.52-0.6627.hdf5
#
# Epoch 00052: saving model to Model.52-0.6627.hdf5
# Epoch 53/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4788 - fbeta: 0.7822 - acc: 0.8247 - val_loss: 1.0210 - val_fbeta: 0.6261 - val_acc: 0.6767
#
# Epoch 00053: saving model to Model.53-0.6767.hdf5
#
# Epoch 00053: saving model to Model.53-0.6767.hdf5
# Epoch 54/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4763 - fbeta: 0.7806 - acc: 0.8218 - val_loss: 1.0735 - val_fbeta: 0.6175 - val_acc: 0.6541
#
# Epoch 00054: saving model to Model.54-0.6541.hdf5
#
# Epoch 00054: saving model to Model.54-0.6541.hdf5
# Epoch 55/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4708 - fbeta: 0.7838 - acc: 0.8252 - val_loss: 0.9886 - val_fbeta: 0.6238 - val_acc: 0.6715s: 0.4717 -
#
# Epoch 00055: saving model to Model.55-0.6715.hdf5
#
# Epoch 00055: saving model to Model.55-0.6715.hdf5
# Epoch 56/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4786 - fbeta: 0.7807 - acc: 0.8227 - val_loss: 1.1071 - val_fbeta: 0.6002 - val_acc: 0.6487
#
# Epoch 00056: saving model to Model.56-0.6487.hdf5
#
# Epoch 00056: saving model to Model.56-0.6487.hdf5
# Epoch 57/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4785 - fbeta: 0.7800 - acc: 0.8219 - val_loss: 0.9998 - val_fbeta: 0.6272 - val_acc: 0.6606
#
# Epoch 00057: saving model to Model.57-0.6606.hdf5
#
# Epoch 00057: saving model to Model.57-0.6606.hdf5
# Epoch 58/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4714 - fbeta: 0.7820 - acc: 0.8248 - val_loss: 1.0343 - val_fbeta: 0.6239 - val_acc: 0.6649
#
# Epoch 00058: saving model to Model.58-0.6649.hdf5
#
# Epoch 00058: saving model to Model.58-0.6649.hdf5
# Epoch 59/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4718 - fbeta: 0.7826 - acc: 0.8244 - val_loss: 1.0496 - val_fbeta: 0.6360 - val_acc: 0.6715
#
# Epoch 00059: saving model to Model.59-0.6715.hdf5
#
# Epoch 00059: saving model to Model.59-0.6715.hdf5
# Epoch 60/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4733 - fbeta: 0.7834 - acc: 0.8247 - val_loss: 1.0299 - val_fbeta: 0.6207 - val_acc: 0.6649
#
# Epoch 00060: saving model to Model.60-0.6649.hdf5
#
# Epoch 00060: saving model to Model.60-0.6649.hdf5
# Epoch 61/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4748 - fbeta: 0.7831 - acc: 0.8248 - val_loss: 1.0267 - val_fbeta: 0.6358 - val_acc: 0.6800
#
# Epoch 00061: saving model to Model.61-0.6800.hdf5
#
# Epoch 00061: saving model to Model.61-0.6800.hdf5
# Epoch 62/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4773 - fbeta: 0.7823 - acc: 0.8243 - val_loss: 1.0350 - val_fbeta: 0.6272 - val_acc: 0.6724
#
# Epoch 00062: saving model to Model.62-0.6724.hdf5
#
# Epoch 00062: saving model to Model.62-0.6724.hdf5
# Epoch 63/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4705 - fbeta: 0.7824 - acc: 0.8244 - val_loss: 1.0738 - val_fbeta: 0.6226 - val_acc: 0.6770
#
# Epoch 00063: saving model to Model.63-0.6770.hdf5
#
# Epoch 00063: saving model to Model.63-0.6770.hdf5
# Epoch 64/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4736 - fbeta: 0.7815 - acc: 0.8245 - val_loss: 1.0013 - val_fbeta: 0.6218 - val_acc: 0.6638
#
# Epoch 00064: saving model to Model.64-0.6638.hdf5
#
# Epoch 00064: saving model to Model.64-0.6638.hdf5
# Epoch 65/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4788 - fbeta: 0.7803 - acc: 0.8221 - val_loss: 1.0206 - val_fbeta: 0.6153 - val_acc: 0.6670
#
# Epoch 00065: saving model to Model.65-0.6670.hdf5
#
# Epoch 00065: saving model to Model.65-0.6670.hdf5
# Epoch 66/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4761 - fbeta: 0.7820 - acc: 0.8234 - val_loss: 1.0308 - val_fbeta: 0.6433 - val_acc: 0.6800
#
# Epoch 00066: saving model to Model.66-0.6800.hdf5
#
# Epoch 00066: saving model to Model.66-0.6800.hdf5
# Epoch 67/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4732 - fbeta: 0.7807 - acc: 0.8268 - val_loss: 1.1254 - val_fbeta: 0.6204 - val_acc: 0.6670
#
# Epoch 00067: saving model to Model.67-0.6670.hdf5
#
# Epoch 00067: saving model to Model.67-0.6670.hdf5
# Epoch 68/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.4725 - fbeta: 0.7837 - acc: 0.8260 - val_loss: 0.9576 - val_fbeta: 0.6336 - val_acc: 0.6875
#
# Epoch 00068: saving model to Model.68-0.6875.hdf5
#
# Epoch 00068: saving model to Model.68-0.6875.hdf5
# Epoch 69/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4678 - fbeta: 0.7818 - acc: 0.8245 - val_loss: 0.9956 - val_fbeta: 0.6444 - val_acc: 0.6810
#
# Epoch 00069: saving model to Model.69-0.6810.hdf5
#
# Epoch 00069: saving model to Model.69-0.6810.hdf5
# Epoch 70/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.4681 - fbeta: 0.7827 - acc: 0.8280 - val_loss: 1.1542 - val_fbeta: 0.5970 - val_acc: 0.6422
#
# Epoch 00070: saving model to Model.70-0.6422.hdf5
#
# Epoch 00070: saving model to Model.70-0.6422.hdf5
# Epoch 71/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4706 - fbeta: 0.7838 - acc: 0.8256 - val_loss: 1.0054 - val_fbeta: 0.6349 - val_acc: 0.6693
#
# Epoch 00071: saving model to Model.71-0.6693.hdf5
#
# Epoch 00071: saving model to Model.71-0.6693.hdf5
# Epoch 72/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4753 - fbeta: 0.7786 - acc: 0.8228 - val_loss: 0.9700 - val_fbeta: 0.6573 - val_acc: 0.7080
#
# Epoch 00072: saving model to Model.72-0.7080.hdf5
#
# Epoch 00072: saving model to Model.72-0.7080.hdf5
# Epoch 73/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4740 - fbeta: 0.7837 - acc: 0.8249 - val_loss: 1.0876 - val_fbeta: 0.6228 - val_acc: 0.6724
#
# Epoch 00073: saving model to Model.73-0.6724.hdf5
#
# Epoch 00073: saving model to Model.73-0.6724.hdf5
# Epoch 74/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.4756 - fbeta: 0.7797 - acc: 0.8215 - val_loss: 1.0776 - val_fbeta: 0.6056 - val_acc: 0.6519
#
# Epoch 00074: saving model to Model.74-0.6519.hdf5
#
# Epoch 00074: saving model to Model.74-0.6519.hdf5
# Epoch 75/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4714 - fbeta: 0.7813 - acc: 0.8223 - val_loss: 1.1135 - val_fbeta: 0.6060 - val_acc: 0.6537
#
# Epoch 00075: saving model to Model.75-0.6537.hdf5
#
# Epoch 00075: saving model to Model.75-0.6537.hdf5
# Epoch 76/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4663 - fbeta: 0.7821 - acc: 0.8264 - val_loss: 0.9969 - val_fbeta: 0.6261 - val_acc: 0.6638
#
# Epoch 00076: saving model to Model.76-0.6638.hdf5
#
# Epoch 00076: saving model to Model.76-0.6638.hdf5
# Epoch 77/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.4747 - fbeta: 0.7827 - acc: 0.8265 - val_loss: 0.9781 - val_fbeta: 0.6519 - val_acc: 0.6950
#
# Epoch 00077: saving model to Model.77-0.6950.hdf5
#
# Epoch 00077: saving model to Model.77-0.6950.hdf5
# Epoch 78/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4736 - fbeta: 0.7808 - acc: 0.8238 - val_loss: 1.0435 - val_fbeta: 0.6249 - val_acc: 0.6815
#
# Epoch 00078: saving model to Model.78-0.6815.hdf5
#
# Epoch 00078: saving model to Model.78-0.6815.hdf5
# Epoch 79/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4691 - fbeta: 0.7850 - acc: 0.8272 - val_loss: 1.1245 - val_fbeta: 0.6078 - val_acc: 0.6573
#
# Epoch 00079: saving model to Model.79-0.6573.hdf5
#
# Epoch 00079: saving model to Model.79-0.6573.hdf5
# Epoch 80/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4735 - fbeta: 0.7814 - acc: 0.8241 - val_loss: 1.0365 - val_fbeta: 0.6282 - val_acc: 0.6649
#
# Epoch 00080: saving model to Model.80-0.6649.hdf5
#
# Epoch 00080: saving model to Model.80-0.6649.hdf5
# Epoch 81/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.4759 - fbeta: 0.7807 - acc: 0.8229 - val_loss: 0.9144 - val_fbeta: 0.6509 - val_acc: 0.6864
#
# Epoch 00081: saving model to Model.81-0.6864.hdf5
#
# Epoch 00081: saving model to Model.81-0.6864.hdf5
# Epoch 82/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4707 - fbeta: 0.7821 - acc: 0.8271 - val_loss: 1.0851 - val_fbeta: 0.5949 - val_acc: 0.64719 - fbe
#
# Epoch 00082: saving model to Model.82-0.6471.hdf5
#
# Epoch 00082: saving model to Model.82-0.6471.hdf5
# Epoch 83/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.4779 - fbeta: 0.7823 - acc: 0.8239 - val_loss: 1.0806 - val_fbeta: 0.6121 - val_acc: 0.6552
#
# Epoch 00083: saving model to Model.83-0.6552.hdf5
#
# Epoch 00083: saving model to Model.83-0.6552.hdf5
# Epoch 84/85
# 225/224 [==============================] - 8s 35ms/step - loss: 0.4765 - fbeta: 0.7808 - acc: 0.8234 - val_loss: 1.0062 - val_fbeta: 0.6390 - val_acc: 0.6832
#
# Epoch 00084: saving model to Model.84-0.6832.hdf5
#
# Epoch 00084: saving model to Model.84-0.6832.hdf5
# Epoch 85/85
# 225/224 [==============================] - 8s 34ms/step - loss: 0.4781 - fbeta: 0.7810 - acc: 0.8223 - val_loss: 1.0537 - val_fbeta: 0.6261 - val_acc: 0.6767
#
# Epoch 00085: saving model to Model.85-0.6767.hdf5
#
# Epoch 00085: saving model to Model.85-0.6767.hdf5
# Epoch 1/85
# 225/224 [==============================] - 13s 60ms/step - loss: 1.7147 - fbeta: 0.1716 - acc: 0.3525 - val_loss: 1.8704 - val_fbeta: 0.2306 - val_acc: 0.2920
#
# Epoch 00001: saving model to Model.01-0.2920.hdf5
#
# Epoch 00001: saving model to Model.01-0.2920.hdf5
# Epoch 2/85
# 225/224 [==============================] - 9s 42ms/step - loss: 1.3699 - fbeta: 0.2792 - acc: 0.4756 - val_loss: 1.3768 - val_fbeta: 0.3621 - val_acc: 0.4881
#
# Epoch 00002: saving model to Model.02-0.4881.hdf5
#
# Epoch 00002: saving model to Model.02-0.4881.hdf5
# Epoch 3/85
# 225/224 [==============================] - 9s 42ms/step - loss: 1.2506 - fbeta: 0.3284 - acc: 0.5210 - val_loss: 1.2312 - val_fbeta: 0.3869 - val_acc: 0.5237
#
# Epoch 00003: saving model to Model.03-0.5237.hdf5
#
# Epoch 00003: saving model to Model.03-0.5237.hdf5
# Epoch 4/85
# 225/224 [==============================] - 10s 42ms/step - loss: 1.1799 - fbeta: 0.3657 - acc: 0.5501 - val_loss: 1.2724 - val_fbeta: 0.3929 - val_acc: 0.5350
#
# Epoch 00004: saving model to Model.04-0.5350.hdf5
#
# Epoch 00004: saving model to Model.04-0.5350.hdf5
# Epoch 5/85
# 225/224 [==============================] - 9s 42ms/step - loss: 1.1276 - fbeta: 0.3896 - acc: 0.5703 - val_loss: 1.1896 - val_fbeta: 0.3836 - val_acc: 0.5366
#
# Epoch 00005: saving model to Model.05-0.5366.hdf5
#
# Epoch 00005: saving model to Model.05-0.5366.hdf5
# Epoch 6/85
# 225/224 [==============================] - 9s 42ms/step - loss: 1.0947 - fbeta: 0.4163 - acc: 0.5851 - val_loss: 1.3110 - val_fbeta: 0.3341 - val_acc: 0.5043
#
# Epoch 00006: saving model to Model.06-0.5043.hdf5
#
# Epoch 00006: saving model to Model.06-0.5043.hdf5
# Epoch 7/85
# 225/224 [==============================] - 9s 42ms/step - loss: 1.0606 - fbeta: 0.4313 - acc: 0.5955 - val_loss: 1.1043 - val_fbeta: 0.4300 - val_acc: 0.5851
#
# Epoch 00007: saving model to Model.07-0.5851.hdf5
#
# Epoch 00007: saving model to Model.07-0.5851.hdf5
# Epoch 8/85
# 225/224 [==============================] - 10s 43ms/step - loss: 1.0335 - fbeta: 0.4536 - acc: 0.6061 - val_loss: 1.0607 - val_fbeta: 0.4795 - val_acc: 0.5993
#
# Epoch 00008: saving model to Model.08-0.5993.hdf5
#
# Epoch 00008: saving model to Model.08-0.5993.hdf5
# Epoch 9/85
# 225/224 [==============================] - 9s 42ms/step - loss: 1.0074 - fbeta: 0.4706 - acc: 0.6166 - val_loss: 1.1518 - val_fbeta: 0.4095 - val_acc: 0.5668
#
# Epoch 00009: saving model to Model.09-0.5668.hdf5
#
# Epoch 00009: saving model to Model.09-0.5668.hdf5
# Epoch 10/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.9880 - fbeta: 0.4843 - acc: 0.6252 - val_loss: 1.1350 - val_fbeta: 0.3966 - val_acc: 0.5657
#
# Epoch 00010: saving model to Model.10-0.5657.hdf5
#
# Epoch 00010: saving model to Model.10-0.5657.hdf5
# Epoch 11/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.9566 - fbeta: 0.5031 - acc: 0.6356 - val_loss: 1.2636 - val_fbeta: 0.4224 - val_acc: 0.5453
#
# Epoch 00011: saving model to Model.11-0.5453.hdf5
#
# Epoch 00011: saving model to Model.11-0.5453.hdf5
# Epoch 12/85
# 225/224 [==============================] - 10s 43ms/step - loss: 0.9371 - fbeta: 0.5154 - acc: 0.6457 - val_loss: 1.4010 - val_fbeta: 0.3951 - val_acc: 0.5028
#
# Epoch 00012: saving model to Model.12-0.5028.hdf5
#
# Epoch 00012: saving model to Model.12-0.5028.hdf5
# Epoch 13/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.9209 - fbeta: 0.5282 - acc: 0.6552 - val_loss: 1.0093 - val_fbeta: 0.5032 - val_acc: 0.6207
#
# Epoch 00013: saving model to Model.13-0.6207.hdf5
#
# Epoch 00013: saving model to Model.13-0.6207.hdf5
# Epoch 14/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.8975 - fbeta: 0.5359 - acc: 0.6560 - val_loss: 1.1612 - val_fbeta: 0.4634 - val_acc: 0.5550
#
# Epoch 00014: saving model to Model.14-0.5550.hdf5
#
# Epoch 00014: saving model to Model.14-0.5550.hdf5
# Epoch 15/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.8741 - fbeta: 0.5572 - acc: 0.6717 - val_loss: 1.0657 - val_fbeta: 0.4644 - val_acc: 0.6110
#
# Epoch 00015: saving model to Model.15-0.6110.hdf5
#
# Epoch 00015: saving model to Model.15-0.6110.hdf5
# Epoch 16/85
# 225/224 [==============================] - 10s 42ms/step - loss: 0.8517 - fbeta: 0.5686 - acc: 0.6815 - val_loss: 1.1261 - val_fbeta: 0.5250 - val_acc: 0.5971
#
# Epoch 00016: saving model to Model.16-0.5971.hdf5
#
# Epoch 00016: saving model to Model.16-0.5971.hdf5
# Epoch 17/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.8338 - fbeta: 0.5812 - acc: 0.6873 - val_loss: 1.0295 - val_fbeta: 0.5162 - val_acc: 0.6239
#
# Epoch 00017: saving model to Model.17-0.6239.hdf5
#
# Epoch 00017: saving model to Model.17-0.6239.hdf5
# Epoch 18/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.8085 - fbeta: 0.5993 - acc: 0.6961 - val_loss: 1.0416 - val_fbeta: 0.5453 - val_acc: 0.6379
#
# Epoch 00018: saving model to Model.18-0.6379.hdf5
#
# Epoch 00018: saving model to Model.18-0.6379.hdf5
# Epoch 19/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.7930 - fbeta: 0.6093 - acc: 0.7055 - val_loss: 1.0657 - val_fbeta: 0.5280 - val_acc: 0.6110
#
# Epoch 00019: saving model to Model.19-0.6110.hdf5
#
# Epoch 00019: saving model to Model.19-0.6110.hdf5
# Epoch 20/85
# 225/224 [==============================] - 10s 42ms/step - loss: 0.7633 - fbeta: 0.6276 - acc: 0.7181 - val_loss: 1.2753 - val_fbeta: 0.4684 - val_acc: 0.5860
#
# Epoch 00020: saving model to Model.20-0.5860.hdf5
#
# Epoch 00020: saving model to Model.20-0.5860.hdf5
# Epoch 21/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.7463 - fbeta: 0.6370 - acc: 0.7223 - val_loss: 1.0296 - val_fbeta: 0.5636 - val_acc: 0.6325
#
# Epoch 00021: saving model to Model.21-0.6325.hdf5
#
# Epoch 00021: saving model to Model.21-0.6325.hdf5
# Epoch 22/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.7199 - fbeta: 0.6530 - acc: 0.7316 - val_loss: 1.1170 - val_fbeta: 0.5506 - val_acc: 0.6175
#
# Epoch 00022: saving model to Model.22-0.6175.hdf5
#
# Epoch 00022: saving model to Model.22-0.6175.hdf5
# Epoch 23/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.7003 - fbeta: 0.6648 - acc: 0.7393 - val_loss: 1.1399 - val_fbeta: 0.5054 - val_acc: 0.5970
#
# Epoch 00023: saving model to Model.23-0.5970.hdf5
#
# Epoch 00023: saving model to Model.23-0.5970.hdf5
# Epoch 24/85
# 225/224 [==============================] - 10s 42ms/step - loss: 0.6273 - fbeta: 0.6945 - acc: 0.7689 - val_loss: 0.9807 - val_fbeta: 0.5971 - val_acc: 0.6637
#
# Epoch 00024: saving model to Model.24-0.6637.hdf5
#
# Epoch 00024: saving model to Model.24-0.6637.hdf5
# Epoch 25/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.5917 - fbeta: 0.7187 - acc: 0.7839 - val_loss: 0.9622 - val_fbeta: 0.5981 - val_acc: 0.6703
#
# Epoch 00025: saving model to Model.25-0.6703.hdf5
#
# Epoch 00025: saving model to Model.25-0.6703.hdf5
# Epoch 26/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.5779 - fbeta: 0.7274 - acc: 0.7844 - val_loss: 1.0773 - val_fbeta: 0.5916 - val_acc: 0.6519
#
# Epoch 00026: saving model to Model.26-0.6519.hdf5
#
# Epoch 00026: saving model to Model.26-0.6519.hdf5
# Epoch 27/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.5725 - fbeta: 0.7318 - acc: 0.7875 - val_loss: 0.9464 - val_fbeta: 0.6142 - val_acc: 0.6832
#
# Epoch 00027: saving model to Model.27-0.6832.hdf5
#
# Epoch 00027: saving model to Model.27-0.6832.hdf5
# Epoch 28/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.5475 - fbeta: 0.7426 - acc: 0.8007 - val_loss: 0.9670 - val_fbeta: 0.6160 - val_acc: 0.6693
#
# Epoch 00028: saving model to Model.28-0.6693.hdf5
#
# Epoch 00028: saving model to Model.28-0.6693.hdf5
# Epoch 29/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.5429 - fbeta: 0.7491 - acc: 0.8010 - val_loss: 1.0024 - val_fbeta: 0.6142 - val_acc: 0.6541
#
# Epoch 00029: saving model to Model.29-0.6541.hdf5
#
# Epoch 00029: saving model to Model.29-0.6541.hdf5
# Epoch 30/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.5295 - fbeta: 0.7545 - acc: 0.8067 - val_loss: 1.0448 - val_fbeta: 0.6067 - val_acc: 0.6692
#
# Epoch 00030: saving model to Model.30-0.6692.hdf5
#
# Epoch 00030: saving model to Model.30-0.6692.hdf5
# Epoch 31/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.5250 - fbeta: 0.7589 - acc: 0.8068 - val_loss: 1.0328 - val_fbeta: 0.6228 - val_acc: 0.6681
#
# Epoch 00031: saving model to Model.31-0.6681.hdf5
#
# Epoch 00031: saving model to Model.31-0.6681.hdf5
# Epoch 32/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.5102 - fbeta: 0.7672 - acc: 0.8119 - val_loss: 1.0156 - val_fbeta: 0.6360 - val_acc: 0.6926
#
# Epoch 00032: saving model to Model.32-0.6926.hdf5
#
# Epoch 00032: saving model to Model.32-0.6926.hdf5
# Epoch 33/85
# 225/224 [==============================] - 9s 41ms/step - loss: 0.5044 - fbeta: 0.7689 - acc: 0.8154 - val_loss: 1.0319 - val_fbeta: 0.6282 - val_acc: 0.6756
#
# Epoch 00033: saving model to Model.33-0.6756.hdf5
#
# Epoch 00033: saving model to Model.33-0.6756.hdf5
# Epoch 34/85
# 225/224 [==============================] - 9s 41ms/step - loss: 0.4950 - fbeta: 0.7743 - acc: 0.8184 - val_loss: 1.0293 - val_fbeta: 0.5991 - val_acc: 0.6541
#
# Epoch 00034: saving model to Model.34-0.6541.hdf5
#
# Epoch 00034: saving model to Model.34-0.6541.hdf5
# Epoch 35/85
# 225/224 [==============================] - 9s 41ms/step - loss: 0.4897 - fbeta: 0.7745 - acc: 0.8185 - val_loss: 1.0471 - val_fbeta: 0.6272 - val_acc: 0.6735
#
# Epoch 00035: saving model to Model.35-0.6735.hdf5
#
# Epoch 00035: saving model to Model.35-0.6735.hdf5
# Epoch 36/85
# 225/224 [==============================] - 10s 43ms/step - loss: 0.4816 - fbeta: 0.7784 - acc: 0.8198 - val_loss: 1.0815 - val_fbeta: 0.6360 - val_acc: 0.6693
#
# Epoch 00036: saving model to Model.36-0.6693.hdf5
#
# Epoch 00036: saving model to Model.36-0.6693.hdf5
# Epoch 37/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4727 - fbeta: 0.7851 - acc: 0.8262 - val_loss: 1.0522 - val_fbeta: 0.6272 - val_acc: 0.6756
#
# Epoch 00037: saving model to Model.37-0.6756.hdf5
#
# Epoch 00037: saving model to Model.37-0.6756.hdf5
# Epoch 38/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4620 - fbeta: 0.7871 - acc: 0.8284 - val_loss: 1.0036 - val_fbeta: 0.6336 - val_acc: 0.6703
#
# Epoch 00038: saving model to Model.38-0.6703.hdf5
#
# Epoch 00038: saving model to Model.38-0.6703.hdf5
# Epoch 39/85
# 225/224 [==============================] - 10s 43ms/step - loss: 0.4673 - fbeta: 0.7882 - acc: 0.8267 - val_loss: 1.0655 - val_fbeta: 0.6104 - val_acc: 0.6570
#
# Epoch 00039: saving model to Model.39-0.6570.hdf5
#
# Epoch 00039: saving model to Model.39-0.6570.hdf5
# Epoch 40/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4631 - fbeta: 0.7907 - acc: 0.8298 - val_loss: 1.1220 - val_fbeta: 0.6315 - val_acc: 0.6713
#
# Epoch 00040: saving model to Model.40-0.6713.hdf5
#
# Epoch 00040: saving model to Model.40-0.6713.hdf5
# Epoch 41/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4638 - fbeta: 0.7909 - acc: 0.8292 - val_loss: 1.0455 - val_fbeta: 0.6401 - val_acc: 0.6800
#
# Epoch 00041: saving model to Model.41-0.6800.hdf5
#
# Epoch 00041: saving model to Model.41-0.6800.hdf5
# Epoch 42/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4577 - fbeta: 0.7912 - acc: 0.8311 - val_loss: 1.0563 - val_fbeta: 0.6121 - val_acc: 0.6606
#
# Epoch 00042: saving model to Model.42-0.6606.hdf5
#
# Epoch 00042: saving model to Model.42-0.6606.hdf5
# Epoch 43/85
# 225/224 [==============================] - 10s 42ms/step - loss: 0.4589 - fbeta: 0.7936 - acc: 0.8334 - val_loss: 0.9759 - val_fbeta: 0.6459 - val_acc: 0.6826
#
# Epoch 00043: saving model to Model.43-0.6826.hdf5
#
# Epoch 00043: saving model to Model.43-0.6826.hdf5
# Epoch 44/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4577 - fbeta: 0.7946 - acc: 0.8325 - val_loss: 1.1272 - val_fbeta: 0.6250 - val_acc: 0.6713
#
# Epoch 00044: saving model to Model.44-0.6713.hdf5
#
# Epoch 00044: saving model to Model.44-0.6713.hdf5
# Epoch 45/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4577 - fbeta: 0.7923 - acc: 0.8319 - val_loss: 1.0842 - val_fbeta: 0.6422 - val_acc: 0.6843
#
# Epoch 00045: saving model to Model.45-0.6843.hdf5
#
# Epoch 00045: saving model to Model.45-0.6843.hdf5
# Epoch 46/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4569 - fbeta: 0.7926 - acc: 0.8326 - val_loss: 0.9915 - val_fbeta: 0.6207 - val_acc: 0.6627
#
# Epoch 00046: saving model to Model.46-0.6627.hdf5
#
# Epoch 00046: saving model to Model.46-0.6627.hdf5
# Epoch 47/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4501 - fbeta: 0.7940 - acc: 0.8319 - val_loss: 0.9995 - val_fbeta: 0.6459 - val_acc: 0.6770
#
# Epoch 00047: saving model to Model.47-0.6770.hdf5
#
# Epoch 00047: saving model to Model.47-0.6770.hdf5
# Epoch 48/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4544 - fbeta: 0.7937 - acc: 0.8303 - val_loss: 1.0392 - val_fbeta: 0.6272 - val_acc: 0.6789
#
# Epoch 00048: saving model to Model.48-0.6789.hdf5
#
# Epoch 00048: saving model to Model.48-0.6789.hdf5
# Epoch 49/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4542 - fbeta: 0.7948 - acc: 0.8331 - val_loss: 1.0235 - val_fbeta: 0.6379 - val_acc: 0.6789
#
# Epoch 00049: saving model to Model.49-0.6789.hdf5
#
# Epoch 00049: saving model to Model.49-0.6789.hdf5
# Epoch 50/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4533 - fbeta: 0.7959 - acc: 0.8323 - val_loss: 1.1185 - val_fbeta: 0.6099 - val_acc: 0.6476
#
# Epoch 00050: saving model to Model.50-0.6476.hdf5
#
# Epoch 00050: saving model to Model.50-0.6476.hdf5
# Epoch 51/85
# 225/224 [==============================] - 10s 43ms/step - loss: 0.4492 - fbeta: 0.7988 - acc: 0.8367 - val_loss: 1.0583 - val_fbeta: 0.6315 - val_acc: 0.6826
#
# Epoch 00051: saving model to Model.51-0.6826.hdf5
#
# Epoch 00051: saving model to Model.51-0.6826.hdf5
# Epoch 52/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4546 - fbeta: 0.7963 - acc: 0.8333 - val_loss: 1.0779 - val_fbeta: 0.6261 - val_acc: 0.6724
#
# Epoch 00052: saving model to Model.52-0.6724.hdf5
#
# Epoch 00052: saving model to Model.52-0.6724.hdf5
# Epoch 53/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4528 - fbeta: 0.7939 - acc: 0.8329 - val_loss: 1.0835 - val_fbeta: 0.6272 - val_acc: 0.6659
#
# Epoch 00053: saving model to Model.53-0.6659.hdf5
#
# Epoch 00053: saving model to Model.53-0.6659.hdf5
# Epoch 54/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4528 - fbeta: 0.7962 - acc: 0.8326 - val_loss: 1.0453 - val_fbeta: 0.6422 - val_acc: 0.6778
#
# Epoch 00054: saving model to Model.54-0.6778.hdf5
#
# Epoch 00054: saving model to Model.54-0.6778.hdf5
# Epoch 55/85
# 225/224 [==============================] - 10s 42ms/step - loss: 0.4486 - fbeta: 0.7972 - acc: 0.8352 - val_loss: 1.0821 - val_fbeta: 0.6104 - val_acc: 0.6548
#
# Epoch 00055: saving model to Model.55-0.6548.hdf5
#
# Epoch 00055: saving model to Model.55-0.6548.hdf5
# Epoch 56/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4571 - fbeta: 0.7925 - acc: 0.8304 - val_loss: 1.0400 - val_fbeta: 0.6379 - val_acc: 0.6692
#
# Epoch 00056: saving model to Model.56-0.6692.hdf5
#
# Epoch 00056: saving model to Model.56-0.6692.hdf5
# Epoch 57/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4528 - fbeta: 0.7968 - acc: 0.8355 - val_loss: 1.1090 - val_fbeta: 0.6250 - val_acc: 0.6670
#
# Epoch 00057: saving model to Model.57-0.6670.hdf5
#
# Epoch 00057: saving model to Model.57-0.6670.hdf5
# Epoch 58/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4502 - fbeta: 0.7970 - acc: 0.8330 - val_loss: 0.9967 - val_fbeta: 0.6444 - val_acc: 0.6843
#
# Epoch 00058: saving model to Model.58-0.6843.hdf5
#
# Epoch 00058: saving model to Model.58-0.6843.hdf5
# Epoch 59/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4584 - fbeta: 0.7924 - acc: 0.8316 - val_loss: 1.0216 - val_fbeta: 0.6382 - val_acc: 0.6759
#
# Epoch 00059: saving model to Model.59-0.6759.hdf5
#
# Epoch 00059: saving model to Model.59-0.6759.hdf5
# Epoch 60/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4589 - fbeta: 0.7942 - acc: 0.8325 - val_loss: 1.0779 - val_fbeta: 0.6293 - val_acc: 0.6681
#
# Epoch 00060: saving model to Model.60-0.6681.hdf5
#
# Epoch 00060: saving model to Model.60-0.6681.hdf5
# Epoch 61/85
# 225/224 [==============================] - 9s 41ms/step - loss: 0.4489 - fbeta: 0.7984 - acc: 0.8373 - val_loss: 1.0117 - val_fbeta: 0.6455 - val_acc: 0.6875
#
# Epoch 00061: saving model to Model.61-0.6875.hdf5
#
# Epoch 00061: saving model to Model.61-0.6875.hdf5
# Epoch 62/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4487 - fbeta: 0.7948 - acc: 0.8319 - val_loss: 1.1521 - val_fbeta: 0.6067 - val_acc: 0.6552
#
# Epoch 00062: saving model to Model.62-0.6552.hdf5
#
# Epoch 00062: saving model to Model.62-0.6552.hdf5
# Epoch 63/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4574 - fbeta: 0.7938 - acc: 0.8325 - val_loss: 1.0744 - val_fbeta: 0.6138 - val_acc: 0.6559
#
# Epoch 00063: saving model to Model.63-0.6559.hdf5
#
# Epoch 00063: saving model to Model.63-0.6559.hdf5
# Epoch 64/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4480 - fbeta: 0.7961 - acc: 0.8336 - val_loss: 1.0628 - val_fbeta: 0.6433 - val_acc: 0.6853
#
# Epoch 00064: saving model to Model.64-0.6853.hdf5
#
# Epoch 00064: saving model to Model.64-0.6853.hdf5
# Epoch 65/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4559 - fbeta: 0.7916 - acc: 0.8287 - val_loss: 1.0571 - val_fbeta: 0.6466 - val_acc: 0.6853
#
# Epoch 00065: saving model to Model.65-0.6853.hdf5
#
# Epoch 00065: saving model to Model.65-0.6853.hdf5
# Epoch 66/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4585 - fbeta: 0.7921 - acc: 0.8306 - val_loss: 1.0296 - val_fbeta: 0.6228 - val_acc: 0.6703
#
# Epoch 00066: saving model to Model.66-0.6703.hdf5
#
# Epoch 00066: saving model to Model.66-0.6703.hdf5
# Epoch 67/85
# 225/224 [==============================] - 10s 43ms/step - loss: 0.4583 - fbeta: 0.7975 - acc: 0.8334 - val_loss: 0.9768 - val_fbeta: 0.6493 - val_acc: 0.6881
#
# Epoch 00067: saving model to Model.67-0.6881.hdf5
#
# Epoch 00067: saving model to Model.67-0.6881.hdf5
# Epoch 68/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4507 - fbeta: 0.7973 - acc: 0.8350 - val_loss: 1.0251 - val_fbeta: 0.6422 - val_acc: 0.6853
#
# Epoch 00068: saving model to Model.68-0.6853.hdf5
#
# Epoch 00068: saving model to Model.68-0.6853.hdf5
# Epoch 69/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4552 - fbeta: 0.7956 - acc: 0.8356 - val_loss: 1.1486 - val_fbeta: 0.6088 - val_acc: 0.6466
#
# Epoch 00069: saving model to Model.69-0.6466.hdf5
#
# Epoch 00069: saving model to Model.69-0.6466.hdf5
# Epoch 70/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4575 - fbeta: 0.7941 - acc: 0.8324 - val_loss: 1.0406 - val_fbeta: 0.6228 - val_acc: 0.6703
#
# Epoch 00070: saving model to Model.70-0.6703.hdf5
#
# Epoch 00070: saving model to Model.70-0.6703.hdf5
# Epoch 71/85
# 225/224 [==============================] - 10s 43ms/step - loss: 0.4526 - fbeta: 0.7950 - acc: 0.8333 - val_loss: 1.0804 - val_fbeta: 0.6182 - val_acc: 0.6637
#
# Epoch 00071: saving model to Model.71-0.6637.hdf5
#
# Epoch 00071: saving model to Model.71-0.6637.hdf5
# Epoch 72/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4553 - fbeta: 0.7954 - acc: 0.8309 - val_loss: 1.1312 - val_fbeta: 0.6099 - val_acc: 0.6466
#
# Epoch 00072: saving model to Model.72-0.6466.hdf5
#
# Epoch 00072: saving model to Model.72-0.6466.hdf5
# Epoch 73/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4524 - fbeta: 0.7978 - acc: 0.8348 - val_loss: 1.0719 - val_fbeta: 0.6304 - val_acc: 0.6789
#
# Epoch 00073: saving model to Model.73-0.6789.hdf5
#
# Epoch 00073: saving model to Model.73-0.6789.hdf5
# Epoch 74/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4536 - fbeta: 0.7960 - acc: 0.8331 - val_loss: 0.9258 - val_fbeta: 0.6498 - val_acc: 0.6972
#
# Epoch 00074: saving model to Model.74-0.6972.hdf5
#
# Epoch 00074: saving model to Model.74-0.6972.hdf5
# Epoch 75/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4531 - fbeta: 0.7971 - acc: 0.8341 - val_loss: 1.1028 - val_fbeta: 0.6160 - val_acc: 0.6582
#
# Epoch 00075: saving model to Model.75-0.6582.hdf5
#
# Epoch 00075: saving model to Model.75-0.6582.hdf5
# Epoch 76/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4550 - fbeta: 0.7915 - acc: 0.8310 - val_loss: 1.0502 - val_fbeta: 0.6142 - val_acc: 0.6649
#
# Epoch 00076: saving model to Model.76-0.6649.hdf5
#
# Epoch 00076: saving model to Model.76-0.6649.hdf5
# Epoch 77/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4466 - fbeta: 0.7968 - acc: 0.8346 - val_loss: 1.0275 - val_fbeta: 0.6466 - val_acc: 0.6875
#
# Epoch 00077: saving model to Model.77-0.6875.hdf5
#
# Epoch 00077: saving model to Model.77-0.6875.hdf5
# Epoch 78/85
# 225/224 [==============================] - 10s 42ms/step - loss: 0.4522 - fbeta: 0.7939 - acc: 0.8314 - val_loss: 1.0220 - val_fbeta: 0.6337 - val_acc: 0.6737
#
# Epoch 00078: saving model to Model.78-0.6737.hdf5
#
# Epoch 00078: saving model to Model.78-0.6737.hdf5
# Epoch 79/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4559 - fbeta: 0.7951 - acc: 0.8344 - val_loss: 1.0483 - val_fbeta: 0.6401 - val_acc: 0.6821
#
# Epoch 00079: saving model to Model.79-0.6821.hdf5
#
# Epoch 00079: saving model to Model.79-0.6821.hdf5
# Epoch 80/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4489 - fbeta: 0.7964 - acc: 0.8345 - val_loss: 1.0973 - val_fbeta: 0.6121 - val_acc: 0.6466
#
# Epoch 00080: saving model to Model.80-0.6466.hdf5
#
# Epoch 00080: saving model to Model.80-0.6466.hdf5
# Epoch 81/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4583 - fbeta: 0.7928 - acc: 0.8306 - val_loss: 1.0597 - val_fbeta: 0.6250 - val_acc: 0.6649
#
# Epoch 00081: saving model to Model.81-0.6649.hdf5
#
# Epoch 00081: saving model to Model.81-0.6649.hdf5
# Epoch 82/85
# 225/224 [==============================] - 10s 42ms/step - loss: 0.4443 - fbeta: 0.7970 - acc: 0.8351 - val_loss: 1.0254 - val_fbeta: 0.6437 - val_acc: 0.6915
#
# Epoch 00082: saving model to Model.82-0.6915.hdf5
#
# Epoch 00082: saving model to Model.82-0.6915.hdf5
# Epoch 83/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4615 - fbeta: 0.7926 - acc: 0.8300 - val_loss: 1.1044 - val_fbeta: 0.6131 - val_acc: 0.6498
#
# Epoch 00083: saving model to Model.83-0.6498.hdf5
#
# Epoch 00083: saving model to Model.83-0.6498.hdf5
# Epoch 84/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4582 - fbeta: 0.7924 - acc: 0.8315 - val_loss: 1.0255 - val_fbeta: 0.6476 - val_acc: 0.6864
#
# Epoch 00084: saving model to Model.84-0.6864.hdf5
#
# Epoch 00084: saving model to Model.84-0.6864.hdf5
# Epoch 85/85
# 225/224 [==============================] - 9s 42ms/step - loss: 0.4519 - fbeta: 0.7938 - acc: 0.8350 - val_loss: 1.0152 - val_fbeta: 0.6369 - val_acc: 0.6864
#
# Epoch 00085: saving model to Model.85-0.6864.hdf5
#
# Epoch 00085: saving model to Model.85-0.6864.hdf5
# Epoch 1/85
# 225/224 [==============================] - 19s 84ms/step - loss: 1.8976 - fbeta: 0.1128 - acc: 0.2985 - val_loss: 1.8327 - val_fbeta: 0.1886 - val_acc: 0.3341
#
# Epoch 00001: saving model to Model.01-0.3341.hdf5
#
# Epoch 00001: saving model to Model.01-0.3341.hdf5
# Epoch 2/85
# 225/224 [==============================] - 14s 63ms/step - loss: 1.4844 - fbeta: 0.2323 - acc: 0.4344 - val_loss: 1.3813 - val_fbeta: 0.2705 - val_acc: 0.4774
#
# Epoch 00002: saving model to Model.02-0.4774.hdf5
#
# Epoch 00002: saving model to Model.02-0.4774.hdf5
# Epoch 3/85
# 225/224 [==============================] - 14s 63ms/step - loss: 1.3243 - fbeta: 0.2895 - acc: 0.4927 - val_loss: 1.5804 - val_fbeta: 0.3481 - val_acc: 0.4558
#
# Epoch 00003: saving model to Model.03-0.4558.hdf5
#
# Epoch 00003: saving model to Model.03-0.4558.hdf5
# Epoch 4/85
# 225/224 [==============================] - 14s 63ms/step - loss: 1.2392 - fbeta: 0.3246 - acc: 0.5287 - val_loss: 1.3209 - val_fbeta: 0.3851 - val_acc: 0.5139
#
# Epoch 00004: saving model to Model.04-0.5139.hdf5
#
# Epoch 00004: saving model to Model.04-0.5139.hdf5
# Epoch 5/85
# 225/224 [==============================] - 14s 63ms/step - loss: 1.1977 - fbeta: 0.3480 - acc: 0.5473 - val_loss: 1.2255 - val_fbeta: 0.3955 - val_acc: 0.5334
#
# Epoch 00005: saving model to Model.05-0.5334.hdf5
#
# Epoch 00005: saving model to Model.05-0.5334.hdf5
# Epoch 6/85
# 225/224 [==============================] - 14s 62ms/step - loss: 1.1619 - fbeta: 0.3709 - acc: 0.5581 - val_loss: 1.2189 - val_fbeta: 0.3168 - val_acc: 0.5237
#
# Epoch 00006: saving model to Model.06-0.5237.hdf5
#
# Epoch 00006: saving model to Model.06-0.5237.hdf5
# Epoch 7/85
# ...
#
# Epoch 00027: saving model to Model.27-0.6552.hdf5
#
# Epoch 00027: saving model to Model.27-0.6552.hdf5
# Epoch 28/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.3372 - fbeta: 0.8512 - acc: 0.8893 - val_loss: 1.1863 - val_fbeta: 0.5705 - val_acc: 0.6182
#
# Epoch 00028: saving model to Model.28-0.6182.hdf5
#
# Epoch 00028: saving model to Model.28-0.6182.hdf5
# Epoch 29/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.3271 - fbeta: 0.8567 - acc: 0.8921 - val_loss: 1.2100 - val_fbeta: 0.5485 - val_acc: 0.6131
#
# Epoch 00029: saving model to Model.29-0.6131.hdf5
#
# Epoch 00029: saving model to Model.29-0.6131.hdf5
# Epoch 30/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.3187 - fbeta: 0.8597 - acc: 0.8950 - val_loss: 1.2039 - val_fbeta: 0.5668 - val_acc: 0.6196
#
# Epoch 00030: saving model to Model.30-0.6196.hdf5
#
# Epoch 00030: saving model to Model.30-0.6196.hdf5
# Epoch 31/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.3124 - fbeta: 0.8626 - acc: 0.8960 - val_loss: 1.2460 - val_fbeta: 0.5442 - val_acc: 0.5916
#
# Epoch 00031: saving model to Model.31-0.5916.hdf5
#
# Epoch 00031: saving model to Model.31-0.5916.hdf5
# Epoch 32/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.3009 - fbeta: 0.8701 - acc: 0.9029 - val_loss: 1.2353 - val_fbeta: 0.5605 - val_acc: 0.6004
#
# Epoch 00032: saving model to Model.32-0.6004.hdf5
#
# Epoch 00032: saving model to Model.32-0.6004.hdf5
# Epoch 33/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.3024 - fbeta: 0.8683 - acc: 0.9004 - val_loss: 1.1852 - val_fbeta: 0.5808 - val_acc: 0.6261
#
# Epoch 00033: saving model to Model.33-0.6261.hdf5
#
# Epoch 00033: saving model to Model.33-0.6261.hdf5
# Epoch 34/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.2858 - fbeta: 0.8764 - acc: 0.9064 - val_loss: 1.2444 - val_fbeta: 0.5668 - val_acc: 0.6175
#
# Epoch 00034: saving model to Model.34-0.6175.hdf5
#
# Epoch 00034: saving model to Model.34-0.6175.hdf5
# Epoch 35/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.2834 - fbeta: 0.8777 - acc: 0.9073 - val_loss: 1.2481 - val_fbeta: 0.5571 - val_acc: 0.6131
#
# Epoch 00035: saving model to Model.35-0.6131.hdf5
#
# Epoch 00035: saving model to Model.35-0.6131.hdf5
# Epoch 36/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.2754 - fbeta: 0.8807 - acc: 0.9098 - val_loss: 1.2907 - val_fbeta: 0.5649 - val_acc: 0.6182
#
# Epoch 00036: saving model to Model.36-0.6182.hdf5
#
# Epoch 00036: saving model to Model.36-0.6182.hdf5
# Epoch 37/85
# 225/224 [==============================] - 6s 26ms/step - loss: 0.2702 - fbeta: 0.8836 - acc: 0.9116 - val_loss: 1.2168 - val_fbeta: 0.5765 - val_acc: 0.6325
#
# Epoch 00037: saving model to Model.37-0.6325.hdf5
#
# Epoch 00037: saving model to Model.37-0.6325.hdf5
# Epoch 38/85
# 225/224 [==============================] - 6s 26ms/step - loss: 0.2557 - fbeta: 0.8948 - acc: 0.9198 - val_loss: 1.2450 - val_fbeta: 0.5787 - val_acc: 0.6250
#
# Epoch 00038: saving model to Model.38-0.6250.hdf5
#
# Epoch 00038: saving model to Model.38-0.6250.hdf5
# Epoch 39/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.2626 - fbeta: 0.8874 - acc: 0.9133 - val_loss: 1.2208 - val_fbeta: 0.5716 - val_acc: 0.6204
#
# Epoch 00039: saving model to Model.39-0.6204.hdf5
#
# Epoch 00039: saving model to Model.39-0.6204.hdf5
# Epoch 40/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.2548 - fbeta: 0.8946 - acc: 0.9197 - val_loss: 1.2554 - val_fbeta: 0.5582 - val_acc: 0.6099
#
# Epoch 00040: saving model to Model.40-0.6099.hdf5
#
# Epoch 00040: saving model to Model.40-0.6099.hdf5
# Epoch 41/85
# 225/224 [==============================] - 6s 26ms/step - loss: 0.2545 - fbeta: 0.8923 - acc: 0.9196 - val_loss: 1.2538 - val_fbeta: 0.5916 - val_acc: 0.6272: 0.2526 - fbet - ETA: 1s - loss: 0.2518 - fbe
#
# Epoch 00041: saving model to Model.41-0.6272.hdf5
#
# Epoch 00041: saving model to Model.41-0.6272.hdf5
# Epoch 42/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.2546 - fbeta: 0.8925 - acc: 0.9183 - val_loss: 1.2382 - val_fbeta: 0.5894 - val_acc: 0.6282
#
# Epoch 00042: saving model to Model.42-0.6282.hdf5
#
# Epoch 00042: saving model to Model.42-0.6282.hdf5
# Epoch 43/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.2516 - fbeta: 0.8951 - acc: 0.9202 - val_loss: 1.2399 - val_fbeta: 0.5694 - val_acc: 0.6171
#
# Epoch 00043: saving model to Model.43-0.6171.hdf5
#
# Epoch 00043: saving model to Model.43-0.6171.hdf5
# Epoch 44/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.2536 - fbeta: 0.8933 - acc: 0.9191 - val_loss: 1.2171 - val_fbeta: 0.5927 - val_acc: 0.6325
#
# Epoch 00044: saving model to Model.44-0.6325.hdf5
#
# Epoch 00044: saving model to Model.44-0.6325.hdf5
# Epoch 45/85
# 225/224 [==============================] - 6s 26ms/step - loss: 0.2514 - fbeta: 0.8957 - acc: 0.9215 - val_loss: 1.3541 - val_fbeta: 0.5366 - val_acc: 0.5797
#
# Epoch 00045: saving model to Model.45-0.5797.hdf5
#
# Epoch 00045: saving model to Model.45-0.5797.hdf5
# Epoch 46/85
# 225/224 [==============================] - 6s 26ms/step - loss: 0.2497 - fbeta: 0.8958 - acc: 0.9207 - val_loss: 1.1601 - val_fbeta: 0.5851 - val_acc: 0.6336
#
# Epoch 00046: saving model to Model.46-0.6336.hdf5
#
# Epoch 00046: saving model to Model.46-0.6336.hdf5
# Epoch 47/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.2526 - fbeta: 0.8941 - acc: 0.9192 - val_loss: 1.3863 - val_fbeta: 0.5572 - val_acc: 0.5938
#
# Epoch 00047: saving model to Model.47-0.5938.hdf5
#
# Epoch 00047: saving model to Model.47-0.5938.hdf5
# Epoch 48/85
# 225/224 [==============================] - 6s 26ms/step - loss: 0.2524 - fbeta: 0.8952 - acc: 0.9196 - val_loss: 1.2798 - val_fbeta: 0.5711 - val_acc: 0.6099
#
# Epoch 00048: saving model to Model.48-0.6099.hdf5
#
# Epoch 00048: saving model to Model.48-0.6099.hdf5
# Epoch 49/85
# 225/224 [==============================] - 6s 26ms/step - loss: 0.2499 - fbeta: 0.8952 - acc: 0.9206 - val_loss: 1.2040 - val_fbeta: 0.5808 - val_acc: 0.6207
#
# Epoch 00049: saving model to Model.49-0.6207.hdf5
#
# Epoch 00049: saving model to Model.49-0.6207.hdf5
# Epoch 50/85
# 225/224 [==============================] - 6s 26ms/step - loss: 0.2443 - fbeta: 0.8973 - acc: 0.9224 - val_loss: 1.2054 - val_fbeta: 0.5797 - val_acc: 0.6315
#
# Epoch 00050: saving model to Model.50-0.6315.hdf5
#
# Epoch 00050: saving model to Model.50-0.6315.hdf5
# Epoch 51/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.2519 - fbeta: 0.8940 - acc: 0.9180 - val_loss: 1.2933 - val_fbeta: 0.5416 - val_acc: 0.5927
#
# Epoch 00051: saving model to Model.51-0.5927.hdf5
#
# Epoch 00051: saving model to Model.51-0.5927.hdf5
# Epoch 52/85
# 225/224 [==============================] - 6s 26ms/step - loss: 0.2474 - fbeta: 0.8977 - acc: 0.9217 - val_loss: 1.2102 - val_fbeta: 0.5851 - val_acc: 0.6228
#
# Epoch 00052: saving model to Model.52-0.6228.hdf5
#
# Epoch 00052: saving model to Model.52-0.6228.hdf5
# Epoch 53/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.2483 - fbeta: 0.8962 - acc: 0.9212 - val_loss: 1.2980 - val_fbeta: 0.5744 - val_acc: 0.6110
#
# Epoch 00053: saving model to Model.53-0.6110.hdf5
#
# Epoch 00053: saving model to Model.53-0.6110.hdf5
# Epoch 54/85
# 225/224 [==============================] - 6s 26ms/step - loss: 0.2491 - fbeta: 0.8961 - acc: 0.9212 - val_loss: 1.1902 - val_fbeta: 0.5808 - val_acc: 0.6358
#
# Epoch 00054: saving model to Model.54-0.6358.hdf5
#
# Epoch 00054: saving model to Model.54-0.6358.hdf5
# Epoch 55/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.2457 - fbeta: 0.8973 - acc: 0.9218 - val_loss: 1.2395 - val_fbeta: 0.5671 - val_acc: 0.6193
#
# Epoch 00055: saving model to Model.55-0.6193.hdf5
#
# Epoch 00055: saving model to Model.55-0.6193.hdf5
# Epoch 56/85
# 225/224 [==============================] - 6s 26ms/step - loss: 0.2491 - fbeta: 0.8950 - acc: 0.9194 - val_loss: 1.2185 - val_fbeta: 0.5754 - val_acc: 0.6239
#
# Epoch 00056: saving model to Model.56-0.6239.hdf5
#
# Epoch 00056: saving model to Model.56-0.6239.hdf5
# Epoch 57/85
# 225/224 [==============================] - 6s 26ms/step - loss: 0.2510 - fbeta: 0.8956 - acc: 0.9204 - val_loss: 1.3658 - val_fbeta: 0.5474 - val_acc: 0.5959
#
# Epoch 00057: saving model to Model.57-0.5959.hdf5
#
# Epoch 00057: saving model to Model.57-0.5959.hdf5
# Epoch 58/85
# 225/224 [==============================] - 6s 26ms/step - loss: 0.2444 - fbeta: 0.8988 - acc: 0.9244 - val_loss: 1.1897 - val_fbeta: 0.5894 - val_acc: 0.6207
#
# Epoch 00058: saving model to Model.58-0.6207.hdf5
#
# Epoch 00058: saving model to Model.58-0.6207.hdf5
# Epoch 59/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.2505 - fbeta: 0.8948 - acc: 0.9186 - val_loss: 1.1498 - val_fbeta: 0.5860 - val_acc: 0.6393
#
# Epoch 00059: saving model to Model.59-0.6393.hdf5
#
# Epoch 00059: saving model to Model.59-0.6393.hdf5
# Epoch 60/85
# 225/224 [==============================] - 6s 26ms/step - loss: 0.2432 - fbeta: 0.9004 - acc: 0.9246 - val_loss: 1.1929 - val_fbeta: 0.5905 - val_acc: 0.6272
#
# Epoch 00060: saving model to Model.60-0.6272.hdf5
#
# Epoch 00060: saving model to Model.60-0.6272.hdf5
# Epoch 61/85
# 225/224 [==============================] - 6s 26ms/step - loss: 0.2456 - fbeta: 0.8980 - acc: 0.9237 - val_loss: 1.2758 - val_fbeta: 0.5722 - val_acc: 0.6088
#
# Epoch 00061: saving model to Model.61-0.6088.hdf5
#
# Epoch 00061: saving model to Model.61-0.6088.hdf5
# Epoch 62/85
# 225/224 [==============================] - 6s 26ms/step - loss: 0.2495 - fbeta: 0.8950 - acc: 0.9207 - val_loss: 1.3452 - val_fbeta: 0.5550 - val_acc: 0.5981
#
# Epoch 00062: saving model to Model.62-0.5981.hdf5
#
# Epoch 00062: saving model to Model.62-0.5981.hdf5
# Epoch 63/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.2531 - fbeta: 0.8926 - acc: 0.9180 - val_loss: 1.2648 - val_fbeta: 0.5849 - val_acc: 0.6315
#
# Epoch 00063: saving model to Model.63-0.6315.hdf5
#
# Epoch 00063: saving model to Model.63-0.6315.hdf5
# Epoch 64/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.2478 - fbeta: 0.8949 - acc: 0.9203 - val_loss: 1.2546 - val_fbeta: 0.5614 - val_acc: 0.6110
#
# Epoch 00064: saving model to Model.64-0.6110.hdf5
#
# Epoch 00064: saving model to Model.64-0.6110.hdf5
# Epoch 65/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.2494 - fbeta: 0.8960 - acc: 0.9207 - val_loss: 1.2315 - val_fbeta: 0.5959 - val_acc: 0.6304
#
# Epoch 00065: saving model to Model.65-0.6304.hdf5
#
# Epoch 00065: saving model to Model.65-0.6304.hdf5
# Epoch 66/85
# 225/224 [==============================] - 6s 26ms/step - loss: 0.2496 - fbeta: 0.8955 - acc: 0.9215 - val_loss: 1.2287 - val_fbeta: 0.5593 - val_acc: 0.6088
#
# Epoch 00066: saving model to Model.66-0.6088.hdf5
#
# Epoch 00066: saving model to Model.66-0.6088.hdf5
# Epoch 67/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.2455 - fbeta: 0.8980 - acc: 0.9217 - val_loss: 1.1634 - val_fbeta: 0.6027 - val_acc: 0.6393
#
# Epoch 00067: saving model to Model.67-0.6393.hdf5
#
# Epoch 00067: saving model to Model.67-0.6393.hdf5
# Epoch 68/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.2445 - fbeta: 0.8980 - acc: 0.9233 - val_loss: 1.2820 - val_fbeta: 0.5560 - val_acc: 0.6056
#
# Epoch 00068: saving model to Model.68-0.6056.hdf5
#
# Epoch 00068: saving model to Model.68-0.6056.hdf5
# Epoch 69/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.2449 - fbeta: 0.8936 - acc: 0.9199 - val_loss: 1.2144 - val_fbeta: 0.5679 - val_acc: 0.6164
#
# Epoch 00069: saving model to Model.69-0.6164.hdf5
#
# Epoch 00069: saving model to Model.69-0.6164.hdf5
# Epoch 70/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.2502 - fbeta: 0.8948 - acc: 0.9214 - val_loss: 1.2307 - val_fbeta: 0.5787 - val_acc: 0.6358
#
# Epoch 00070: saving model to Model.70-0.6358.hdf5
#
# Epoch 00070: saving model to Model.70-0.6358.hdf5
# Epoch 71/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.2513 - fbeta: 0.8948 - acc: 0.9203 - val_loss: 1.2170 - val_fbeta: 0.5782 - val_acc: 0.6215
#
# Epoch 00071: saving model to Model.71-0.6215.hdf5
#
# Epoch 00071: saving model to Model.71-0.6215.hdf5
# Epoch 72/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.2457 - fbeta: 0.8988 - acc: 0.9231 - val_loss: 1.3159 - val_fbeta: 0.5636 - val_acc: 0.6078
#
# Epoch 00072: saving model to Model.72-0.6078.hdf5
#
# Epoch 00072: saving model to Model.72-0.6078.hdf5
# Epoch 73/85
# 225/224 [==============================] - 6s 26ms/step - loss: 0.2515 - fbeta: 0.8937 - acc: 0.9180 - val_loss: 1.2845 - val_fbeta: 0.5614 - val_acc: 0.6110
#
# Epoch 00073: saving model to Model.73-0.6110.hdf5
#
# Epoch 00073: saving model to Model.73-0.6110.hdf5
# Epoch 74/85
# 225/224 [==============================] - 6s 26ms/step - loss: 0.2485 - fbeta: 0.8950 - acc: 0.9216 - val_loss: 1.2374 - val_fbeta: 0.5776 - val_acc: 0.6250
#
# Epoch 00074: saving model to Model.74-0.6250.hdf5
#
# Epoch 00074: saving model to Model.74-0.6250.hdf5
# Epoch 75/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.2466 - fbeta: 0.8951 - acc: 0.9203 - val_loss: 1.3159 - val_fbeta: 0.5560 - val_acc: 0.5949
#
# Epoch 00075: saving model to Model.75-0.5949.hdf5
#
# Epoch 00075: saving model to Model.75-0.5949.hdf5
# Epoch 76/85
# 225/224 [==============================] - 6s 26ms/step - loss: 0.2484 - fbeta: 0.8978 - acc: 0.9211 - val_loss: 1.2560 - val_fbeta: 0.5722 - val_acc: 0.6207
#
# Epoch 00076: saving model to Model.76-0.6207.hdf5
#
# Epoch 00076: saving model to Model.76-0.6207.hdf5
# Epoch 77/85
# 225/224 [==============================] - 6s 26ms/step - loss: 0.2481 - fbeta: 0.8962 - acc: 0.9211 - val_loss: 1.1790 - val_fbeta: 0.5851 - val_acc: 0.6336
#
# Epoch 00077: saving model to Model.77-0.6336.hdf5
#
# Epoch 00077: saving model to Model.77-0.6336.hdf5
# Epoch 78/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.2541 - fbeta: 0.8935 - acc: 0.9184 - val_loss: 1.2904 - val_fbeta: 0.5560 - val_acc: 0.6027
#
# Epoch 00078: saving model to Model.78-0.6027.hdf5
#
# Epoch 00078: saving model to Model.78-0.6027.hdf5
# Epoch 79/85
# 225/224 [==============================] - 6s 26ms/step - loss: 0.2452 - fbeta: 0.8981 - acc: 0.9226 - val_loss: 1.2669 - val_fbeta: 0.5636 - val_acc: 0.6121
#
# Epoch 00079: saving model to Model.79-0.6121.hdf5
#
# Epoch 00079: saving model to Model.79-0.6121.hdf5
# Epoch 80/85
# 225/224 [==============================] - 6s 26ms/step - loss: 0.2482 - fbeta: 0.8949 - acc: 0.9204 - val_loss: 1.2352 - val_fbeta: 0.5819 - val_acc: 0.6250
#
# Epoch 00080: saving model to Model.80-0.6250.hdf5
#
# Epoch 00080: saving model to Model.80-0.6250.hdf5
# Epoch 81/85
# 225/224 [==============================] - 6s 26ms/step - loss: 0.2517 - fbeta: 0.8938 - acc: 0.9191 - val_loss: 1.2229 - val_fbeta: 0.5905 - val_acc: 0.6401
#
# Epoch 00081: saving model to Model.81-0.6401.hdf5
#
# Epoch 00081: saving model to Model.81-0.6401.hdf5
# Epoch 82/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.2469 - fbeta: 0.8968 - acc: 0.9223 - val_loss: 1.2658 - val_fbeta: 0.5794 - val_acc: 0.6238
#
# Epoch 00082: saving model to Model.82-0.6238.hdf5
#
# Epoch 00082: saving model to Model.82-0.6238.hdf5
# Epoch 83/85
# 225/224 [==============================] - 6s 26ms/step - loss: 0.2455 - fbeta: 0.8982 - acc: 0.9220 - val_loss: 1.2106 - val_fbeta: 0.5841 - val_acc: 0.6250
#
# Epoch 00083: saving model to Model.83-0.6250.hdf5
#
# Epoch 00083: saving model to Model.83-0.6250.hdf5
# Epoch 84/85
# 225/224 [==============================] - 6s 26ms/step - loss: 0.2522 - fbeta: 0.8939 - acc: 0.9181 - val_loss: 1.2794 - val_fbeta: 0.5560 - val_acc: 0.6067
#
# Epoch 00084: saving model to Model.84-0.6067.hdf5
#
# Epoch 00084: saving model to Model.84-0.6067.hdf5
# Epoch 85/85
# 225/224 [==============================] - 6s 27ms/step - loss: 0.2514 - fbeta: 0.8945 - acc: 0.9196 - val_loss: 1.1684 - val_fbeta: 0.5970 - val_acc: 0.6562
#
# Epoch 00085: saving model to Model.85-0.6562.hdf5
#
# Epoch 00085: saving model to Model.85-0.6562.hdf5

# %%
'''
Evaluate Test Set & Print Results
'''
score = model1.evaluate(X_test, y_test, steps=int(num_test / BATCH_SIZE))
print('Model 1 Evaluation Loss: ', score[0])
print('Model 1 Evaluation Accuracy: ', score[1])

score = model2.evaluate(X_test, y_test, steps=int(num_test / BATCH_SIZE))
print('Model 2 Evaluation Loss: ', score[0])
print('Model 2 Evaluation Accuracy: ', score[1])

score = model3.evaluate(X_test, y_test, steps=int(num_test / BATCH_SIZE))
print('Model 3 Evaluation Loss: ', score[0])
print('Model 3 Evaluation Accuracy: ', score[1])

score = model4.evaluate(X_test, y_test, steps=int(num_test / BATCH_SIZE))
print('Model 4 Evaluation Loss: ', score[0])
print('Model 4 Evaluation Accuracy: ', score[1])
# Out:
# 28/28 [==============================] - 6s 206ms/step
# Model 1 Evaluation Loss:  0.9769575595855713
# Model 1 Evaluation Accuracy:  0.6408470273017883
# 28/28 [==============================] - 7s 257ms/step
# Model 2 Evaluation Loss:  0.9993553757667542
# Model 2 Evaluation Accuracy:  0.6427974104881287
# 28/28 [==============================] - 11s 394ms/step
# Model 3 Evaluation Loss:  0.9144213199615479
# Model 3 Evaluation Accuracy:  0.6132627725601196
# 28/28 [==============================] - 4s 147ms/step
# Model 4 Evaluation Loss:  1.1447107791900635
# Model 4 Evaluation Accuracy:  0.5965449810028076

# %%
# Model 1 Stats
plt.figure()
plt.plot(history1.history['acc'], color='b', label='Training')
plt.plot(history1.history['val_acc'], color='g', label='Validation')
plt.title('Model 1 Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.show()

plt.figure()
plt.plot(history1.history['loss'], color='b', label='Training')
plt.plot(history1.history['val_loss'], color='g', label='Validation')
plt.title('Model 1 Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='lower left')
plt.show()

y_pred = model1.predict_classes(X_test)
y_true = np.asarray([np.argmax(i) for i in y_test])

cm = confusion_matrix(y_true, y_pred)
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

sns.set(font_scale=1.5)
fig, ax = plt.subplots(figsize=(10,10))
ax = sns.heatmap(
    cm_norm, annot=True, linewidths=0, square=False, cmap='Greens', 
    yticklabels=emotion_labels, xticklabels=emotion_labels, 
    vmin=0, vmax=np.max(cm_norm), fmt='.2f', 
    annot_kws={'size': 20}
)
ax.set(xlabel='Predicted Label', ylabel='Actual Label')
plt.savefig(cm_file)
plt.show()


# Model 2 Stats
plt.figure()
plt.plot(history2.history['acc'], color='b', label='Training')
plt.plot(history2.history['val_acc'], color='g', label='Validation')
plt.title('Model 2 Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.show()

plt.figure()
plt.plot(history2.history['loss'], color='b', label='Training')
plt.plot(history2.history['val_loss'], color='g', label='Validation')
plt.title('Model 2 Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='lower left')
plt.show()

y_pred = model2.predict_classes(X_test)
y_true = np.asarray([np.argmax(i) for i in y_test])

cm = confusion_matrix(y_true, y_pred)
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

sns.set(font_scale=1.5)
fig, ax = plt.subplots(figsize=(10,10))
ax = sns.heatmap(
    cm_norm, annot=True, linewidths=0, square=False, cmap='Greens', 
    yticklabels=emotion_labels, xticklabels=emotion_labels, 
    vmin=0, vmax=np.max(cm_norm), fmt='.2f', 
    annot_kws={'size': 20}
)
ax.set(xlabel='Predicted Label', ylabel='Actual Label')
plt.savefig(cm_file)
plt.show()


# Model 3 Stats
plt.figure()
plt.plot(history3.history['acc'], color='b', label='Training')
plt.plot(history3.history['val_acc'], color='g', label='Validation')
plt.title('Model 3 Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.show()

plt.figure()
plt.plot(history3.history['loss'], color='b', label='Training')
plt.plot(history3.history['val_loss'], color='g', label='Validation')
plt.title('Model 3 Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='lower left')
plt.show()

y_pred = model3.predict_classes(X_test)
y_true = np.asarray([np.argmax(i) for i in y_test])

cm = confusion_matrix(y_true, y_pred)
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

sns.set(font_scale=1.5)
fig, ax = plt.subplots(figsize=(10,10))
ax = sns.heatmap(
    cm_norm, annot=True, linewidths=0, square=False, cmap='Greens', 
    yticklabels=emotion_labels, xticklabels=emotion_labels, 
    vmin=0, vmax=np.max(cm_norm), fmt='.2f', 
    annot_kws={'size': 20}
)
ax.set(xlabel='Predicted Label', ylabel='Actual Label')
plt.savefig(cm_file)
plt.show()


# Model 4 Stats
plt.figure()
plt.plot(history4.history['acc'], color='b', label='Training')
plt.plot(history4.history['val_acc'], color='g', label='Validation')
plt.title('Model 4 Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.show()

plt.figure()
plt.plot(history4.history['loss'], color='b', label='Training')
plt.plot(history4.history['val_loss'], color='g', label='Validation')
plt.title('Model 4 Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='lower left')
plt.show()

y_pred = model4.predict_classes(X_test)
y_true = np.asarray([np.argmax(i) for i in y_test])

cm = confusion_matrix(y_true, y_pred)
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

sns.set(font_scale=1.5)
fig, ax = plt.subplots(figsize=(10,10))
ax = sns.heatmap(
    cm_norm, annot=True, linewidths=0, square=False, cmap='Greens', 
    yticklabels=emotion_labels, xticklabels=emotion_labels, 
    vmin=0, vmax=np.max(cm_norm), fmt='.2f', 
    annot_kws={'size': 20}
)
ax.set(xlabel='Predicted Label', ylabel='Actual Label')
plt.savefig(cm_file)
plt.show()

# %%
# Validation Comparison
fig1 = plt.figure()
plt.plot(history1.history['val_acc'], color='#0000FF', label='Model 1')
plt.plot(history2.history['val_acc'], color='#00FF00', label='Model 2')
plt.plot(history3.history['val_acc'], color='#9932CC', label='Model 3')
plt.plot(history4.history['val_acc'], color='#FF4500', label='Model 4')
plt.title('Validation Accuracy Comparison')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.savefig(acc_file)
plt.show() 

# Loss Comparison
fig1 = plt.figure()
plt.plot(history1.history['val_loss'], color='#0000FF', label='Model 1')
plt.plot(history2.history['val_loss'], color='#00FF00', label='Model 2')
plt.plot(history3.history['val_loss'], color='#9932CC', label='Model 3')
plt.plot(history4.history['val_loss'], color='#FF4500', label='Model 4')
plt.title('Validation Loss Comparison')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.savefig(acc_file)
plt.show()
