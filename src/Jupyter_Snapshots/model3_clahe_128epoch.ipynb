# %%
'''
Libraries, etc.
'''
import os
import cv2
import time
import numpy as np # linear algebra
import scipy as sp # more w/ numpy arrays
import pandas as pd # data processing
import tensorflow as tf # machine learning
import matplotlib.pyplot as plt # graph/plot
import seaborn as sns

from keras.layers import Convolution2D, Activation, BatchNormalization, GaussianNoise, MaxPooling2D, Dropout, Dense, Flatten
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras import backend as K
from keras.utils import np_utils as npu
from sklearn.metrics import confusion_matrix

from google.colab import files
uploaded = files.upload()
# Out:
# Using TensorFlow backend.
#      <input type="file" id="files-0fd71a23-dede-4609-8681-7ce1b52f205f" name="files[]" multiple disabled />
#      <output id="result-0fd71a23-dede-4609-8681-7ce1b52f205f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving fer2013.csv to fer2013.csv

# %%
'''
Constants, Hyperparameters, etc.
'''
INPUT_FILE = 'fer2013.csv'

EMOTION_LABELS = ['Angry','Disgust','Fear','Happy','Sad','Surprise','Neutral']
NUM_LABELS = 7

BASE_SIZE = 48
BASE_DEPTH = 1

BATCH_SIZE = 128
NUM_EPOCHS = 128

# %%
'''
Load & Parse Data into Training/Test Labels & Images
'''
data = pd.read_csv(INPUT_FILE)
data.head()

train_set = data[(data.Usage == 'Training')]
validation_set = data[(data.Usage == 'PublicTest')]
test_set = data[(data.Usage == 'PrivateTest')]

X_train1 = np.array(list(map(str.split, train_set.pixels)), np.uint8)
X_validation1 = np.array(list(map(str.split, validation_set.pixels)), np.uint8)
X_test1 = np.array(list(map(str.split, test_set.pixels)), np.uint8)

NUM_TRAIN = len(X_train1)
NUM_VALIDATION = len(X_validation1)
NUM_TEST = len(X_test1)

X_train1 = X_train1.reshape(NUM_TRAIN, BASE_SIZE, BASE_SIZE)
X_validation1 = X_validation1.reshape(NUM_VALIDATION, BASE_SIZE, BASE_SIZE)
X_test1 = X_test1.reshape(NUM_TEST, BASE_SIZE, BASE_SIZE)

print('Matrix Shapes for X')
print('Training: ', X_train1.shape)
print('Validation: ', X_validation1.shape)
print('Testing: ', X_test1.shape)

y_train = train_set.emotion
y_train = npu.to_categorical(y_train, NUM_LABELS)

y_validation = validation_set.emotion
y_validation = npu.to_categorical(y_validation, NUM_LABELS)

y_test = test_set.emotion
y_test = npu.to_categorical(y_test, NUM_LABELS)

print('Matrix Shapes for Y')
print('Training: ', y_train.shape)
print('Validation: ', y_validation.shape)
print('Testing: ', y_test.shape)
# Out:
# Matrix Shapes for X
# Training:  (28709, 48, 48)
# Validation:  (3589, 48, 48)
# Testing:  (3589, 48, 48)
# Matrix Shapes for Y
# Training:  (28709, 7)
# Validation:  (3589, 7)
# Testing:  (3589, 7)

# %%
'''
Histogram Equalization, etc.
'''
clahe = cv2.createCLAHE(clipLimit=3.235, tileGridSize=(5,5))

X_train2 = X_train1.copy()
X_train3 = X_train1.copy()

X_validation2 = X_validation1.copy()
X_validation3 = X_validation1.copy()

X_test2 = X_test1.copy()
X_test3 = X_test1.copy()

i = 0
while (i < NUM_TRAIN):
  tMax = X_train1[i].max()
  tMin = X_train1[i].min()  

  if (tMax > tMin):
    tRatio = 255 / (tMax - tMin)
    X_train2[i] = np.multiply((X_train1[i] - tMin), tRatio)
    
  # Delete useless training examples
  else:
    X_train1 = np.delete(X_train1, (i), axis=0)
    X_train2 = np.delete(X_train2, (i), axis=0)
    X_train3 = np.delete(X_train3, (i), axis=0)
    y_train = np.delete(y_train, (i), axis=0)
    NUM_TRAIN -= 1
    i -= 1
    
  X_train3[i] = clahe.apply(X_train2[i])
  i += 1
  
i = 0
while (i < NUM_VALIDATION):
  tMax = X_validation1[i].max()
  tMin = X_validation1[i].min()

  # Shouldn't delete validation data... skip so we don't divide by 0
  if (tMax > tMin):
    tRatio = 255 / (tMax - tMin)
    X_validation2[i] = np.multiply((X_validation1[i] - tMin), tRatio).round()
  else:
    X_validation2[i] = X_validation1[i]

  X_validation3[i] = clahe.apply(X_validation2[i])
  i += 1

i = 0
while (i < NUM_TEST):
  tMax = X_test1[i].max()
  tMin = X_test1[i].min()

  # Shouldn't delete test data... skip so we don't divide by 0
  if (tMax > tMin):
    tRatio = 255 / (tMax - tMin)
    X_test2[i] = np.multiply((X_test1[i] - tMin), tRatio).round()
  else:
    X_test2[i] = X_test1[i]
    
  X_test3[i] = clahe.apply(X_test2[i])
  i += 1

'''
Print Samples from Input Data (to confirm transforms are correct)
'''
print('Original Images...')
for x in range(1,26):
    plt.subplot(5, 5, x)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_test1[x], cmap='gray')
    
plt.show()

print('Original w/ Linear Transform to normalize pixel values...')
for x in range(1,26):
    plt.subplot(5, 5, x)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_test2[x], cmap='gray')
    
plt.show()

print('Normalized w/ Contrast Limited Adaptive Histogram Equalization')
for x in range(1,26):
    plt.subplot(5, 5, x)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_test3[x], cmap='gray')
    
plt.show()
# Out:
# Original Images...
# Original w/ Linear Transform to normalize pixel values...
# Normalized w/ Contrast Limited Adaptive Histogram Equalization

# %%
'''
TensorFlow Model(s)
'''

def get_model1():
  model = Sequential()

  model.add(Convolution2D(64, (3, 3), padding='same', input_shape=(48,48,1)))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(128, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(256, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Flatten())

  model.add(Dense(512))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(256))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(7))
  model.add(Activation('softmax'))

  return model


def get_model2():
  model = Sequential()

  model.add(Convolution2D(64, (3, 3), padding='same', input_shape=(48,48,1)))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(128, (5, 5), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Flatten())

  model.add(Dense(256))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(512))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(7))
  model.add(Activation('softmax'))

  return model


def get_model3():
  model = Sequential()

  model.add(Convolution2D(64, (3, 3), padding='same', input_shape=(48,48,1)))
  model.add(Convolution2D(64, (3, 3), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  #model.add(GaussianNoise(2))
  model.add(Dropout(0.4))

  model.add(Convolution2D(128, (3, 3), padding='same'))
  model.add(Convolution2D(128, (3, 3), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  #model.add(GaussianNoise(2))
  model.add(Dropout(0.4))

  model.add(Convolution2D(256, (3, 3), padding='same'))
  model.add(Convolution2D(265, (3, 3), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  #model.add(GaussianNoise(2))
  model.add(Dropout(0.4))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(Convolution2D(512, (3, 3), padding='same')) 
  model.add(Convolution2D(512, (1, 1), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  #model.add(GaussianNoise(2))
  model.add(Dropout(0.4))

  model.add(Flatten())

  model.add(Dense(2048))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.4))

  model.add(Dense(512))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.4))

  model.add(Dense(7))
  model.add(Activation('softmax'))

  return model

# %%
'''
Metric(s)
'''
def fbeta(y_true, y_pred, threshold_shift=0):
  beta = 1
  
  y_pred = K.clip(y_pred, 0, 1)
  y_pred_bin = K.round(y_pred + threshold_shift)
  
  tp = K.sum(K.round(y_true * y_pred_bin), axis=1) + K.epsilon()
  fp = K.sum(K.round(K.clip(y_pred_bin - y_true, 0, 1)), axis=1)
  fn = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=1)
  
  precision = tp / (tp + fp)
  recall = tp / (tp + fn)
  
  beta_sq = beta ** 2
  return K.mean((beta_sq + 1) * (precision * recall) / (beta_sq * precision + recall + K.epsilon()))

# %%
'''
Setup Model & Data Generator
'''
# assign X_train/validation/test to the desired image set(s) from above
X_train = X_train3
X_validation = X_validation3
X_test = X_test3
NUM_TRAIN = len(X_train)

# reshape X_train/validation/test to the expected shape, and cast it back to a float32
X_train = X_train.reshape(NUM_TRAIN,BASE_SIZE,BASE_SIZE,1).astype(np.float32)
X_validation = X_validation.reshape(NUM_VALIDATION,BASE_SIZE,BASE_SIZE,1).astype(np.float32)
X_test = X_test.reshape(NUM_TEST,BASE_SIZE,BASE_SIZE,1).astype(np.float32)

# assign the desired model from above
model = get_model3()
model.summary()

# augmentation and fitting of data
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    rotation_range=0,
    width_shift_range=0.0,
    height_shift_range=0.0,
    shear_range=0,
    horizontal_flip=True,
    vertical_flip=False
)
datagen.fit(X_train)
datagen.fit(X_validation)

filepath = 'Model.{epoch:02d}-{val_acc:.4f}.hdf5'

checkpointer = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, mode='auto')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, verbose=0, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)
early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=0, verbose=0, mode='auto')

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=[fbeta, 'accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 48, 48, 64)        640
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 48, 48, 64)        36928
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 48, 48, 64)        256
# _________________________________________________________________
# activation_15 (Activation)   (None, 48, 48, 64)        0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 24, 24, 128)       73856
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 24, 24, 128)       147584
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 24, 24, 128)       512
# _________________________________________________________________
# activation_16 (Activation)   (None, 24, 24, 128)       0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 12, 12, 256)       295168
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 12, 12, 265)       610825
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 12, 12, 265)       1060
# _________________________________________________________________
# activation_17 (Activation)   (None, 12, 12, 265)       0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 265)         0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 6, 6, 265)         0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 6, 6, 512)         1221632
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 6, 6, 512)         2359808
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 6, 6, 512)         262656
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 6, 6, 512)         2048
# _________________________________________________________________
# activation_18 (Activation)   (None, 6, 6, 512)         0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 2048)              9439232
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 2048)              8192
# _________________________________________________________________
# activation_19 (Activation)   (None, 2048)              0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_20 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 7)                 3591
# _________________________________________________________________
# activation_21 (Activation)   (None, 7)                 0
# =================================================================
# Total params: 15,515,124
# Trainable params: 15,508,066
# Non-trainable params: 7,058
# _________________________________________________________________

# %%
'''
Training
'''
train_flow = datagen.flow(X_train, y_train, batch_size=BATCH_SIZE)
validation_flow = datagen.flow(X_validation, y_validation)

history = model.fit_generator(
    train_flow,
    steps_per_epoch=NUM_TRAIN / BATCH_SIZE,
    epochs=NUM_EPOCHS,
    verbose=1,
    validation_data=validation_flow,
    validation_steps=NUM_VALIDATION / BATCH_SIZE,
    callbacks=[checkpointer, reduce_lr, checkpointer]
)
# Out:
# Epoch 1/128
# 225/224 [==============================] - 50s 224ms/step - loss: 1.8650 - fbeta: 0.1276 - acc: 0.3057 - val_loss: 1.7980 - val_fbeta: 0.0280 - val_acc: 0.3082
#
# Epoch 00001: saving model to Model.01-0.3082.hdf5
#
# Epoch 00001: saving model to Model.01-0.3082.hdf5
# Epoch 2/128
# 225/224 [==============================] - 47s 209ms/step - loss: 1.4620 - fbeta: 0.2399 - acc: 0.4432 - val_loss: 1.3330 - val_fbeta: 0.3373 - val_acc: 0.4989
#
# Epoch 00002: saving model to Model.02-0.4989.hdf5
#
# Epoch 00002: saving model to Model.02-0.4989.hdf5
# Epoch 3/128
# 225/224 [==============================] - 47s 209ms/step - loss: 1.3092 - fbeta: 0.2902 - acc: 0.4987 - val_loss: 1.3200 - val_fbeta: 0.3093 - val_acc: 0.4784
#
# Epoch 00003: saving model to Model.03-0.4784.hdf5
#
# Epoch 00003: saving model to Model.03-0.4784.hdf5
# Epoch 4/128
# 225/224 [==============================] - 47s 209ms/step - loss: 1.2472 - fbeta: 0.3176 - acc: 0.5241 - val_loss: 1.4579 - val_fbeta: 0.3263 - val_acc: 0.4806
#
# Epoch 00004: saving model to Model.04-0.4806.hdf5
#
# Epoch 00004: saving model to Model.04-0.4806.hdf5
# Epoch 5/128
# 225/224 [==============================] - 47s 209ms/step - loss: 1.1984 - fbeta: 0.3497 - acc: 0.5441 - val_loss: 1.2810 - val_fbeta: 0.3524 - val_acc: 0.5032
#
# Epoch 00005: saving model to Model.05-0.5032.hdf5
#
# Epoch 00005: saving model to Model.05-0.5032.hdf5
# Epoch 6/128
# 225/224 [==============================] - 47s 209ms/step - loss: 1.1691 - fbeta: 0.3640 - acc: 0.5538 - val_loss: 1.1770 - val_fbeta: 0.3696 - val_acc: 0.5528
#
# Epoch 00006: saving model to Model.06-0.5528.hdf5
#
# Epoch 00006: saving model to Model.06-0.5528.hdf5
# Epoch 7/128
# 225/224 [==============================] - 47s 209ms/step - loss: 1.1428 - fbeta: 0.3813 - acc: 0.5655 - val_loss: 1.1479 - val_fbeta: 0.4041 - val_acc: 0.5323
#
# Epoch 00007: saving model to Model.07-0.5323.hdf5
#
# Epoch 00007: saving model to Model.07-0.5323.hdf5
# Epoch 8/128
# 225/224 [==============================] - 47s 208ms/step - loss: 1.1277 - fbeta: 0.3910 - acc: 0.5728 - val_loss: 1.2093 - val_fbeta: 0.4628 - val_acc: 0.5727
#
# Epoch 00008: saving model to Model.08-0.5727.hdf5
#
# Epoch 00008: saving model to Model.08-0.5727.hdf5
# Epoch 9/128
# 225/224 [==============================] - 47s 209ms/step - loss: 1.1075 - fbeta: 0.4035 - acc: 0.5769 - val_loss: 1.1761 - val_fbeta: 0.3793 - val_acc: 0.5560
#
# Epoch 00009: saving model to Model.09-0.5560.hdf5
#
# Epoch 00009: saving model to Model.09-0.5560.hdf5
# Epoch 10/128
# 225/224 [==============================] - 47s 209ms/step - loss: 1.0899 - fbeta: 0.4193 - acc: 0.5882 - val_loss: 1.1057 - val_fbeta: 0.4450 - val_acc: 0.5981
#
# Epoch 00010: saving model to Model.10-0.5981.hdf5
#
# Epoch 00010: saving model to Model.10-0.5981.hdf5
# Epoch 11/128
# 225/224 [==============================] - 47s 209ms/step - loss: 1.0798 - fbeta: 0.4221 - acc: 0.5873 - val_loss: 1.1505 - val_fbeta: 0.4332 - val_acc: 0.5657
#
# Epoch 00011: saving model to Model.11-0.5657.hdf5
#
# Epoch 00011: saving model to Model.11-0.5657.hdf5
# Epoch 12/128
# 225/224 [==============================] - 47s 209ms/step - loss: 1.0629 - fbeta: 0.4338 - acc: 0.5966 - val_loss: 1.0449 - val_fbeta: 0.4706 - val_acc: 0.5971
#
# Epoch 00012: saving model to Model.12-0.5971.hdf5
#
# Epoch 00012: saving model to Model.12-0.5971.hdf5
# Epoch 13/128
# 225/224 [==============================] - 48s 213ms/step - loss: 1.0536 - fbeta: 0.4370 - acc: 0.5972 - val_loss: 1.1240 - val_fbeta: 0.4817 - val_acc: 0.5754
#
# Epoch 00013: saving model to Model.13-0.5754.hdf5
#
# Epoch 00013: saving model to Model.13-0.5754.hdf5
# Epoch 14/128
# 225/224 [==============================] - 48s 213ms/step - loss: 1.0411 - fbeta: 0.4492 - acc: 0.6033 - val_loss: 1.0416 - val_fbeta: 0.5129 - val_acc: 0.6034
#
# Epoch 00014: saving model to Model.14-0.6034.hdf5
#
# Epoch 00014: saving model to Model.14-0.6034.hdf5
# Epoch 15/128
# 225/224 [==============================] - 48s 212ms/step - loss: 1.0353 - fbeta: 0.4499 - acc: 0.6080 - val_loss: 1.0746 - val_fbeta: 0.4504 - val_acc: 0.6013
#
# Epoch 00015: saving model to Model.15-0.6013.hdf5
#
# Epoch 00015: saving model to Model.15-0.6013.hdf5
# Epoch 16/128
# 225/224 [==============================] - 48s 213ms/step - loss: 1.0200 - fbeta: 0.4543 - acc: 0.6134 - val_loss: 1.0896 - val_fbeta: 0.4340 - val_acc: 0.6060
#
# Epoch 00016: saving model to Model.16-0.6060.hdf5
#
# Epoch 00016: saving model to Model.16-0.6060.hdf5
# Epoch 17/128
# 225/224 [==============================] - 48s 212ms/step - loss: 1.0135 - fbeta: 0.4692 - acc: 0.6174 - val_loss: 1.0593 - val_fbeta: 0.5129 - val_acc: 0.6110
#
# Epoch 00017: saving model to Model.17-0.6110.hdf5
#
# Epoch 00017: saving model to Model.17-0.6110.hdf5
# Epoch 18/128
# 225/224 [==============================] - 48s 213ms/step - loss: 1.0031 - fbeta: 0.4715 - acc: 0.6198 - val_loss: 1.0505 - val_fbeta: 0.4838 - val_acc: 0.5959
#
# Epoch 00018: saving model to Model.18-0.5959.hdf5
#
# Epoch 00018: saving model to Model.18-0.5959.hdf5
# Epoch 19/128
# 225/224 [==============================] - 48s 213ms/step - loss: 0.9882 - fbeta: 0.4805 - acc: 0.6205 - val_loss: 1.0484 - val_fbeta: 0.4601 - val_acc: 0.6110
#
# Epoch 00019: saving model to Model.19-0.6110.hdf5
#
# Epoch 00019: saving model to Model.19-0.6110.hdf5
# Epoch 20/128
# 225/224 [==============================] - 48s 213ms/step - loss: 0.9885 - fbeta: 0.4781 - acc: 0.6240 - val_loss: 1.0838 - val_fbeta: 0.4706 - val_acc: 0.6027
#
# Epoch 00020: saving model to Model.20-0.6027.hdf5
#
# Epoch 00020: saving model to Model.20-0.6027.hdf5
# Epoch 21/128
# 225/224 [==============================] - 48s 212ms/step - loss: 0.9778 - fbeta: 0.4884 - acc: 0.6282 - val_loss: 1.1190 - val_fbeta: 0.4569 - val_acc: 0.5841
#
# Epoch 00021: saving model to Model.21-0.5841.hdf5
#
# Epoch 00021: saving model to Model.21-0.5841.hdf5
# Epoch 22/128
# 225/224 [==============================] - 48s 212ms/step - loss: 0.9586 - fbeta: 0.4999 - acc: 0.6367 - val_loss: 1.0359 - val_fbeta: 0.5075 - val_acc: 0.6336
#
# Epoch 00022: saving model to Model.22-0.6336.hdf5
#
# Epoch 00022: saving model to Model.22-0.6336.hdf5
# Epoch 23/128
# 225/224 [==============================] - 47s 211ms/step - loss: 0.9529 - fbeta: 0.5027 - acc: 0.6365 - val_loss: 1.0403 - val_fbeta: 0.4601 - val_acc: 0.6099
#
# Epoch 00023: saving model to Model.23-0.6099.hdf5
#
# Epoch 00023: saving model to Model.23-0.6099.hdf5
# Epoch 24/128
# 225/224 [==============================] - 48s 212ms/step - loss: 0.9476 - fbeta: 0.5038 - acc: 0.6382 - val_loss: 1.0098 - val_fbeta: 0.5105 - val_acc: 0.6249
#
# Epoch 00024: saving model to Model.24-0.6249.hdf5
#
# Epoch 00024: saving model to Model.24-0.6249.hdf5
# Epoch 25/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.9405 - fbeta: 0.5081 - acc: 0.6418 - val_loss: 1.0064 - val_fbeta: 0.4688 - val_acc: 0.6218
#
# Epoch 00025: saving model to Model.25-0.6218.hdf5
#
# Epoch 00025: saving model to Model.25-0.6218.hdf5
# Epoch 26/128
# 225/224 [==============================] - 47s 208ms/step - loss: 0.9301 - fbeta: 0.5140 - acc: 0.6482 - val_loss: 1.0391 - val_fbeta: 0.4903 - val_acc: 0.6164
#
# Epoch 00026: saving model to Model.26-0.6164.hdf5
#
# Epoch 00026: saving model to Model.26-0.6164.hdf5
# Epoch 27/128
# 225/224 [==============================] - 48s 212ms/step - loss: 0.9249 - fbeta: 0.5206 - acc: 0.6503 - val_loss: 1.0036 - val_fbeta: 0.5097 - val_acc: 0.6304
#
# Epoch 00027: saving model to Model.27-0.6304.hdf5
#
# Epoch 00027: saving model to Model.27-0.6304.hdf5
# Epoch 28/128
# 225/224 [==============================] - 48s 212ms/step - loss: 0.9154 - fbeta: 0.5239 - acc: 0.6524 - val_loss: 0.9800 - val_fbeta: 0.5094 - val_acc: 0.6526
#
# Epoch 00028: saving model to Model.28-0.6526.hdf5
#
# Epoch 00028: saving model to Model.28-0.6526.hdf5
# Epoch 29/128
# 225/224 [==============================] - 48s 213ms/step - loss: 0.9127 - fbeta: 0.5263 - acc: 0.6520 - val_loss: 0.9447 - val_fbeta: 0.5216 - val_acc: 0.6509
#
# Epoch 00029: saving model to Model.29-0.6509.hdf5
#
# Epoch 00029: saving model to Model.29-0.6509.hdf5
# Epoch 30/128
# 225/224 [==============================] - 47s 211ms/step - loss: 0.8982 - fbeta: 0.5360 - acc: 0.6591 - val_loss: 1.0601 - val_fbeta: 0.5097 - val_acc: 0.6067
#
# Epoch 00030: saving model to Model.30-0.6067.hdf5
#
# Epoch 00030: saving model to Model.30-0.6067.hdf5
# Epoch 31/128
# 225/224 [==============================] - 48s 212ms/step - loss: 0.8918 - fbeta: 0.5414 - acc: 0.6608 - val_loss: 1.0082 - val_fbeta: 0.5291 - val_acc: 0.6390
#
# Epoch 00031: saving model to Model.31-0.6390.hdf5
#
# Epoch 00031: saving model to Model.31-0.6390.hdf5
# Epoch 32/128
# 225/224 [==============================] - 48s 212ms/step - loss: 0.8748 - fbeta: 0.5465 - acc: 0.6681 - val_loss: 1.0924 - val_fbeta: 0.5228 - val_acc: 0.6182
#
# Epoch 00032: saving model to Model.32-0.6182.hdf5
#
# Epoch 00032: saving model to Model.32-0.6182.hdf5
# Epoch 33/128
# 225/224 [==============================] - 47s 211ms/step - loss: 0.8788 - fbeta: 0.5494 - acc: 0.6682 - val_loss: 0.9986 - val_fbeta: 0.4860 - val_acc: 0.6196
#
# Epoch 00033: saving model to Model.33-0.6196.hdf5
#
# Epoch 00033: saving model to Model.33-0.6196.hdf5
# Epoch 34/128
# 225/224 [==============================] - 48s 213ms/step - loss: 0.8644 - fbeta: 0.5548 - acc: 0.6716 - val_loss: 0.9393 - val_fbeta: 0.5614 - val_acc: 0.6519
#
# Epoch 00034: saving model to Model.34-0.6519.hdf5
#
# Epoch 00034: saving model to Model.34-0.6519.hdf5
# Epoch 35/128
# 225/224 [==============================] - 48s 212ms/step - loss: 0.8560 - fbeta: 0.5629 - acc: 0.6765 - val_loss: 0.9729 - val_fbeta: 0.5506 - val_acc: 0.6487
#
# Epoch 00035: saving model to Model.35-0.6487.hdf5
#
# Epoch 00035: saving model to Model.35-0.6487.hdf5
# Epoch 36/128
# 225/224 [==============================] - 48s 213ms/step - loss: 0.8460 - fbeta: 0.5700 - acc: 0.6781 - val_loss: 1.1427 - val_fbeta: 0.5183 - val_acc: 0.6038
#
# Epoch 00036: saving model to Model.36-0.6038.hdf5
#
# Epoch 00036: saving model to Model.36-0.6038.hdf5
# Epoch 37/128
# 225/224 [==============================] - 47s 211ms/step - loss: 0.8425 - fbeta: 0.5703 - acc: 0.6805 - val_loss: 1.0398 - val_fbeta: 0.5657 - val_acc: 0.6379
#
# Epoch 00037: saving model to Model.37-0.6379.hdf5
#
# Epoch 00037: saving model to Model.37-0.6379.hdf5
# Epoch 38/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.8328 - fbeta: 0.5770 - acc: 0.6837 - val_loss: 1.0178 - val_fbeta: 0.5108 - val_acc: 0.6175
#
# Epoch 00038: saving model to Model.38-0.6175.hdf5
#
# Epoch 00038: saving model to Model.38-0.6175.hdf5
# Epoch 39/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.8299 - fbeta: 0.5761 - acc: 0.6844 - val_loss: 1.1333 - val_fbeta: 0.4983 - val_acc: 0.5849
#
# Epoch 00039: saving model to Model.39-0.5849.hdf5
#
# Epoch 00039: saving model to Model.39-0.5849.hdf5
# Epoch 40/128
# 225/224 [==============================] - 47s 208ms/step - loss: 0.8240 - fbeta: 0.5817 - acc: 0.6878 - val_loss: 0.9831 - val_fbeta: 0.5647 - val_acc: 0.6369
#
# Epoch 00040: saving model to Model.40-0.6369.hdf5
#
# Epoch 00040: saving model to Model.40-0.6369.hdf5
# Epoch 41/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.8068 - fbeta: 0.5909 - acc: 0.6937 - val_loss: 1.0339 - val_fbeta: 0.5151 - val_acc: 0.6164
#
# Epoch 00041: saving model to Model.41-0.6164.hdf5
#
# Epoch 00041: saving model to Model.41-0.6164.hdf5
# Epoch 42/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.7950 - fbeta: 0.5990 - acc: 0.6983 - val_loss: 0.9742 - val_fbeta: 0.5582 - val_acc: 0.6412
#
# Epoch 00042: saving model to Model.42-0.6412.hdf5
#
# Epoch 00042: saving model to Model.42-0.6412.hdf5
# Epoch 43/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.7974 - fbeta: 0.5990 - acc: 0.6993 - val_loss: 0.9549 - val_fbeta: 0.5727 - val_acc: 0.6615
#
# Epoch 00043: saving model to Model.43-0.6615.hdf5
#
# Epoch 00043: saving model to Model.43-0.6615.hdf5
# Epoch 44/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.7759 - fbeta: 0.6113 - acc: 0.7057 - val_loss: 1.1529 - val_fbeta: 0.5485 - val_acc: 0.6056
#
# Epoch 00044: saving model to Model.44-0.6056.hdf5
#
# Epoch 00044: saving model to Model.44-0.6056.hdf5
# Epoch 45/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.7310 - fbeta: 0.6270 - acc: 0.7237 - val_loss: 0.9194 - val_fbeta: 0.5862 - val_acc: 0.6789
#
# Epoch 00045: saving model to Model.45-0.6789.hdf5
#
# Epoch 00045: saving model to Model.45-0.6789.hdf5
# Epoch 46/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.7131 - fbeta: 0.6429 - acc: 0.7315 - val_loss: 0.8999 - val_fbeta: 0.5991 - val_acc: 0.6746
#
# Epoch 00046: saving model to Model.46-0.6746.hdf5
#
# Epoch 00046: saving model to Model.46-0.6746.hdf5
# Epoch 47/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.7001 - fbeta: 0.6495 - acc: 0.7365 - val_loss: 0.9303 - val_fbeta: 0.5949 - val_acc: 0.6748
#
# Epoch 00047: saving model to Model.47-0.6748.hdf5
#
# Epoch 00047: saving model to Model.47-0.6748.hdf5
# Epoch 48/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6986 - fbeta: 0.6504 - acc: 0.7333 - val_loss: 1.0005 - val_fbeta: 0.5636 - val_acc: 0.6476
#
# Epoch 00048: saving model to Model.48-0.6476.hdf5
#
# Epoch 00048: saving model to Model.48-0.6476.hdf5
# Epoch 49/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6883 - fbeta: 0.6561 - acc: 0.7399 - val_loss: 0.9248 - val_fbeta: 0.6056 - val_acc: 0.6810
#
# Epoch 00049: saving model to Model.49-0.6810.hdf5
#
# Epoch 00049: saving model to Model.49-0.6810.hdf5
# Epoch 50/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6782 - fbeta: 0.6652 - acc: 0.7446 - val_loss: 0.9141 - val_fbeta: 0.6250 - val_acc: 0.6853
#
# Epoch 00050: saving model to Model.50-0.6853.hdf5
#
# Epoch 00050: saving model to Model.50-0.6853.hdf5
# Epoch 51/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6804 - fbeta: 0.6619 - acc: 0.7435 - val_loss: 0.9668 - val_fbeta: 0.5949 - val_acc: 0.6604
#
# Epoch 00051: saving model to Model.51-0.6604.hdf5
#
# Epoch 00051: saving model to Model.51-0.6604.hdf5
# Epoch 52/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6753 - fbeta: 0.6668 - acc: 0.7444 - val_loss: 0.9382 - val_fbeta: 0.6088 - val_acc: 0.6853
#
# Epoch 00052: saving model to Model.52-0.6853.hdf5
#
# Epoch 00052: saving model to Model.52-0.6853.hdf5
# Epoch 53/128
# 225/224 [==============================] - 47s 208ms/step - loss: 0.6644 - fbeta: 0.6690 - acc: 0.7467 - val_loss: 0.9235 - val_fbeta: 0.6002 - val_acc: 0.6746
#
# Epoch 00053: saving model to Model.53-0.6746.hdf5
#
# Epoch 00053: saving model to Model.53-0.6746.hdf5
# Epoch 54/128
# 225/224 [==============================] - 47s 208ms/step - loss: 0.6625 - fbeta: 0.6743 - acc: 0.7485 - val_loss: 0.9736 - val_fbeta: 0.5894 - val_acc: 0.6616
#
# Epoch 00054: saving model to Model.54-0.6616.hdf5
#
# Epoch 00054: saving model to Model.54-0.6616.hdf5
# Epoch 55/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6642 - fbeta: 0.6745 - acc: 0.7499 - val_loss: 0.9928 - val_fbeta: 0.6093 - val_acc: 0.6704
#
# Epoch 00055: saving model to Model.55-0.6704.hdf5
#
# Epoch 00055: saving model to Model.55-0.6704.hdf5
# Epoch 56/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6582 - fbeta: 0.6758 - acc: 0.7503 - val_loss: 0.9015 - val_fbeta: 0.6239 - val_acc: 0.6800
#
# Epoch 00056: saving model to Model.56-0.6800.hdf5
#
# Epoch 00056: saving model to Model.56-0.6800.hdf5
# Epoch 57/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6448 - fbeta: 0.6822 - acc: 0.7549 - val_loss: 0.9728 - val_fbeta: 0.5905 - val_acc: 0.6455
#
# Epoch 00057: saving model to Model.57-0.6455.hdf5
#
# Epoch 00057: saving model to Model.57-0.6455.hdf5
# Epoch 58/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6516 - fbeta: 0.6800 - acc: 0.7550 - val_loss: 0.9661 - val_fbeta: 0.6067 - val_acc: 0.6756
#
# Epoch 00058: saving model to Model.58-0.6756.hdf5
#
# Epoch 00058: saving model to Model.58-0.6756.hdf5
# Epoch 59/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6490 - fbeta: 0.6805 - acc: 0.7562 - val_loss: 1.0043 - val_fbeta: 0.6127 - val_acc: 0.6615
#
# Epoch 00059: saving model to Model.59-0.6615.hdf5
#
# Epoch 00059: saving model to Model.59-0.6615.hdf5
# Epoch 60/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6440 - fbeta: 0.6856 - acc: 0.7572 - val_loss: 0.9711 - val_fbeta: 0.6013 - val_acc: 0.6681
#
# Epoch 00060: saving model to Model.60-0.6681.hdf5
#
# Epoch 00060: saving model to Model.60-0.6681.hdf5
# Epoch 61/128
# 225/224 [==============================] - 47s 208ms/step - loss: 0.6416 - fbeta: 0.6870 - acc: 0.7571 - val_loss: 0.8575 - val_fbeta: 0.6401 - val_acc: 0.7058
#
# Epoch 00061: saving model to Model.61-0.7058.hdf5
#
# Epoch 00061: saving model to Model.61-0.7058.hdf5
# Epoch 62/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6398 - fbeta: 0.6859 - acc: 0.7585 - val_loss: 0.9837 - val_fbeta: 0.5787 - val_acc: 0.6530
#
# Epoch 00062: saving model to Model.62-0.6530.hdf5
#
# Epoch 00062: saving model to Model.62-0.6530.hdf5
# Epoch 63/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6378 - fbeta: 0.6874 - acc: 0.7607 - val_loss: 0.9825 - val_fbeta: 0.6226 - val_acc: 0.6837
#
# Epoch 00063: saving model to Model.63-0.6837.hdf5
#
# Epoch 00063: saving model to Model.63-0.6837.hdf5
# Epoch 64/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6382 - fbeta: 0.6864 - acc: 0.7571 - val_loss: 0.9512 - val_fbeta: 0.6131 - val_acc: 0.6724
#
# Epoch 00064: saving model to Model.64-0.6724.hdf5
#
# Epoch 00064: saving model to Model.64-0.6724.hdf5
# Epoch 65/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6390 - fbeta: 0.6846 - acc: 0.7589 - val_loss: 0.9844 - val_fbeta: 0.5819 - val_acc: 0.6616
#
# Epoch 00065: saving model to Model.65-0.6616.hdf5
#
# Epoch 00065: saving model to Model.65-0.6616.hdf5
# Epoch 66/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6412 - fbeta: 0.6826 - acc: 0.7571 - val_loss: 0.9760 - val_fbeta: 0.6013 - val_acc: 0.6703
#
# Epoch 00066: saving model to Model.66-0.6703.hdf5
#
# Epoch 00066: saving model to Model.66-0.6703.hdf5
# Epoch 67/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6357 - fbeta: 0.6867 - acc: 0.7608 - val_loss: 0.9778 - val_fbeta: 0.6082 - val_acc: 0.6637
#
# Epoch 00067: saving model to Model.67-0.6637.hdf5
#
# Epoch 00067: saving model to Model.67-0.6637.hdf5
# Epoch 68/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6439 - fbeta: 0.6851 - acc: 0.7545 - val_loss: 1.0138 - val_fbeta: 0.6045 - val_acc: 0.6735
#
# Epoch 00068: saving model to Model.68-0.6735.hdf5
#
# Epoch 00068: saving model to Model.68-0.6735.hdf5
# Epoch 69/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6423 - fbeta: 0.6846 - acc: 0.7597 - val_loss: 0.9406 - val_fbeta: 0.6250 - val_acc: 0.6832
#
# Epoch 00069: saving model to Model.69-0.6832.hdf5
#
# Epoch 00069: saving model to Model.69-0.6832.hdf5
# Epoch 70/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6422 - fbeta: 0.6843 - acc: 0.7578 - val_loss: 0.8932 - val_fbeta: 0.6121 - val_acc: 0.6789
#
# Epoch 00070: saving model to Model.70-0.6789.hdf5
#
# Epoch 00070: saving model to Model.70-0.6789.hdf5
# Epoch 71/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6404 - fbeta: 0.6869 - acc: 0.7596 - val_loss: 0.9709 - val_fbeta: 0.6104 - val_acc: 0.6637
#
# Epoch 00071: saving model to Model.71-0.6637.hdf5
#
# Epoch 00071: saving model to Model.71-0.6637.hdf5
# Epoch 72/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6376 - fbeta: 0.6880 - acc: 0.7593 - val_loss: 0.9466 - val_fbeta: 0.6067 - val_acc: 0.6681
#
# Epoch 00072: saving model to Model.72-0.6681.hdf5
#
# Epoch 00072: saving model to Model.72-0.6681.hdf5
# Epoch 73/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6450 - fbeta: 0.6841 - acc: 0.7563 - val_loss: 0.9447 - val_fbeta: 0.5991 - val_acc: 0.6670
#
# Epoch 00073: saving model to Model.73-0.6670.hdf5
#
# Epoch 00073: saving model to Model.73-0.6670.hdf5
# Epoch 74/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6384 - fbeta: 0.6885 - acc: 0.7584 - val_loss: 0.9728 - val_fbeta: 0.6164 - val_acc: 0.6897
#
# Epoch 00074: saving model to Model.74-0.6897.hdf5
#
# Epoch 00074: saving model to Model.74-0.6897.hdf5
# Epoch 75/128
# 225/224 [==============================] - 48s 212ms/step - loss: 0.6392 - fbeta: 0.6854 - acc: 0.7561 - val_loss: 0.9295 - val_fbeta: 0.6115 - val_acc: 0.6837
#
# Epoch 00075: saving model to Model.75-0.6837.hdf5
#
# Epoch 00075: saving model to Model.75-0.6837.hdf5
# Epoch 76/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6335 - fbeta: 0.6865 - acc: 0.7605 - val_loss: 0.9496 - val_fbeta: 0.6207 - val_acc: 0.6789
#
# Epoch 00076: saving model to Model.76-0.6789.hdf5
#
# Epoch 00076: saving model to Model.76-0.6789.hdf5
# Epoch 77/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6378 - fbeta: 0.6870 - acc: 0.7575 - val_loss: 0.9214 - val_fbeta: 0.6099 - val_acc: 0.6735
#
# Epoch 00077: saving model to Model.77-0.6735.hdf5
#
# Epoch 00077: saving model to Model.77-0.6735.hdf5
# Epoch 78/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6416 - fbeta: 0.6843 - acc: 0.7543 - val_loss: 1.0263 - val_fbeta: 0.5893 - val_acc: 0.6604
#
# Epoch 00078: saving model to Model.78-0.6604.hdf5
#
# Epoch 00078: saving model to Model.78-0.6604.hdf5
# Epoch 79/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6389 - fbeta: 0.6891 - acc: 0.7601 - val_loss: 1.0074 - val_fbeta: 0.5970 - val_acc: 0.6530
#
# Epoch 00079: saving model to Model.79-0.6530.hdf5
#
# Epoch 00079: saving model to Model.79-0.6530.hdf5
# Epoch 80/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6328 - fbeta: 0.6908 - acc: 0.7633 - val_loss: 0.9952 - val_fbeta: 0.6088 - val_acc: 0.6616
#
# Epoch 00080: saving model to Model.80-0.6616.hdf5
#
# Epoch 00080: saving model to Model.80-0.6616.hdf5
# Epoch 81/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6334 - fbeta: 0.6895 - acc: 0.7608 - val_loss: 0.8937 - val_fbeta: 0.6250 - val_acc: 0.6897
#
# Epoch 00081: saving model to Model.81-0.6897.hdf5
#
# Epoch 00081: saving model to Model.81-0.6897.hdf5
# Epoch 82/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6342 - fbeta: 0.6903 - acc: 0.7625 - val_loss: 1.0005 - val_fbeta: 0.6082 - val_acc: 0.6704
#
# Epoch 00082: saving model to Model.82-0.6704.hdf5
#
# Epoch 00082: saving model to Model.82-0.6704.hdf5
# Epoch 83/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6363 - fbeta: 0.6858 - acc: 0.7582 - val_loss: 0.9256 - val_fbeta: 0.6196 - val_acc: 0.6821
#
# Epoch 00083: saving model to Model.83-0.6821.hdf5
#
# Epoch 00083: saving model to Model.83-0.6821.hdf5
# Epoch 84/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6376 - fbeta: 0.6858 - acc: 0.7609 - val_loss: 0.9677 - val_fbeta: 0.6153 - val_acc: 0.6767
#
# Epoch 00084: saving model to Model.84-0.6767.hdf5
#
# Epoch 00084: saving model to Model.84-0.6767.hdf5
# Epoch 85/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6391 - fbeta: 0.6895 - acc: 0.7595 - val_loss: 0.9670 - val_fbeta: 0.6034 - val_acc: 0.6606
#
# Epoch 00085: saving model to Model.85-0.6606.hdf5
#
# Epoch 00085: saving model to Model.85-0.6606.hdf5
# Epoch 86/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6428 - fbeta: 0.6865 - acc: 0.7569 - val_loss: 0.9677 - val_fbeta: 0.6060 - val_acc: 0.6670
#
# Epoch 00086: saving model to Model.86-0.6670.hdf5
#
# Epoch 00086: saving model to Model.86-0.6670.hdf5
# Epoch 87/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6365 - fbeta: 0.6879 - acc: 0.7586 - val_loss: 0.9304 - val_fbeta: 0.6153 - val_acc: 0.6864
#
# Epoch 00087: saving model to Model.87-0.6864.hdf5
#
# Epoch 00087: saving model to Model.87-0.6864.hdf5
# Epoch 88/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6392 - fbeta: 0.6847 - acc: 0.7571 - val_loss: 0.9797 - val_fbeta: 0.6002 - val_acc: 0.6713
#
# Epoch 00088: saving model to Model.88-0.6713.hdf5
#
# Epoch 00088: saving model to Model.88-0.6713.hdf5
# Epoch 89/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6322 - fbeta: 0.6914 - acc: 0.7623 - val_loss: 0.9818 - val_fbeta: 0.6088 - val_acc: 0.6767
#
# Epoch 00089: saving model to Model.89-0.6767.hdf5
#
# Epoch 00089: saving model to Model.89-0.6767.hdf5
# Epoch 90/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6330 - fbeta: 0.6873 - acc: 0.7582 - val_loss: 0.9596 - val_fbeta: 0.5993 - val_acc: 0.6604
#
# Epoch 00090: saving model to Model.90-0.6604.hdf5
#
# Epoch 00090: saving model to Model.90-0.6604.hdf5
# Epoch 91/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6418 - fbeta: 0.6859 - acc: 0.7578 - val_loss: 0.9531 - val_fbeta: 0.6034 - val_acc: 0.6681
#
# Epoch 00091: saving model to Model.91-0.6681.hdf5
#
# Epoch 00091: saving model to Model.91-0.6681.hdf5
# Epoch 92/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6433 - fbeta: 0.6855 - acc: 0.7570 - val_loss: 1.0015 - val_fbeta: 0.6078 - val_acc: 0.6638
#
# Epoch 00092: saving model to Model.92-0.6638.hdf5
#
# Epoch 00092: saving model to Model.92-0.6638.hdf5
# Epoch 93/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6409 - fbeta: 0.6843 - acc: 0.7573 - val_loss: 0.9180 - val_fbeta: 0.6369 - val_acc: 0.6897
#
# Epoch 00093: saving model to Model.93-0.6897.hdf5
#
# Epoch 00093: saving model to Model.93-0.6897.hdf5
# Epoch 94/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6349 - fbeta: 0.6880 - acc: 0.7597 - val_loss: 0.9795 - val_fbeta: 0.6038 - val_acc: 0.6648
#
# Epoch 00094: saving model to Model.94-0.6648.hdf5
#
# Epoch 00094: saving model to Model.94-0.6648.hdf5
# Epoch 95/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6336 - fbeta: 0.6883 - acc: 0.7588 - val_loss: 0.9356 - val_fbeta: 0.6121 - val_acc: 0.6713
#
# Epoch 00095: saving model to Model.95-0.6713.hdf5
#
# Epoch 00095: saving model to Model.95-0.6713.hdf5
# Epoch 96/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6363 - fbeta: 0.6896 - acc: 0.7576 - val_loss: 0.9808 - val_fbeta: 0.6056 - val_acc: 0.6584
#
# Epoch 00096: saving model to Model.96-0.6584.hdf5
#
# Epoch 00096: saving model to Model.96-0.6584.hdf5
# Epoch 97/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6432 - fbeta: 0.6849 - acc: 0.7580 - val_loss: 0.9696 - val_fbeta: 0.6078 - val_acc: 0.6821
#
# Epoch 00097: saving model to Model.97-0.6821.hdf5
#
# Epoch 00097: saving model to Model.97-0.6821.hdf5
# Epoch 98/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6355 - fbeta: 0.6907 - acc: 0.7615 - val_loss: 0.9958 - val_fbeta: 0.6193 - val_acc: 0.6748
#
# Epoch 00098: saving model to Model.98-0.6748.hdf5
#
# Epoch 00098: saving model to Model.98-0.6748.hdf5
# Epoch 99/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6416 - fbeta: 0.6850 - acc: 0.7568 - val_loss: 0.9745 - val_fbeta: 0.6045 - val_acc: 0.6573
#
# Epoch 00099: saving model to Model.99-0.6573.hdf5
#
# Epoch 00099: saving model to Model.99-0.6573.hdf5
# Epoch 100/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6370 - fbeta: 0.6871 - acc: 0.7603 - val_loss: 0.9873 - val_fbeta: 0.6056 - val_acc: 0.6562
#
# Epoch 00100: saving model to Model.100-0.6562.hdf5
#
# Epoch 00100: saving model to Model.100-0.6562.hdf5
# Epoch 101/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6478 - fbeta: 0.6823 - acc: 0.7526 - val_loss: 0.8928 - val_fbeta: 0.6315 - val_acc: 0.7015
#
# Epoch 00101: saving model to Model.101-0.7015.hdf5
#
# Epoch 00101: saving model to Model.101-0.7015.hdf5
# Epoch 102/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6412 - fbeta: 0.6882 - acc: 0.7596 - val_loss: 0.8580 - val_fbeta: 0.6393 - val_acc: 0.6959
#
# Epoch 00102: saving model to Model.102-0.6959.hdf5
#
# Epoch 00102: saving model to Model.102-0.6959.hdf5
# Epoch 103/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6377 - fbeta: 0.6860 - acc: 0.7594 - val_loss: 0.9462 - val_fbeta: 0.6142 - val_acc: 0.6800
#
# Epoch 00103: saving model to Model.103-0.6800.hdf5
#
# Epoch 00103: saving model to Model.103-0.6800.hdf5
# Epoch 104/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6373 - fbeta: 0.6897 - acc: 0.7616 - val_loss: 0.9576 - val_fbeta: 0.6185 - val_acc: 0.6713
#
# Epoch 00104: saving model to Model.104-0.6713.hdf5
#
# Epoch 00104: saving model to Model.104-0.6713.hdf5
# Epoch 105/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6397 - fbeta: 0.6853 - acc: 0.7563 - val_loss: 1.0111 - val_fbeta: 0.5776 - val_acc: 0.6519
#
# Epoch 00105: saving model to Model.105-0.6519.hdf5
#
# Epoch 00105: saving model to Model.105-0.6519.hdf5
# Epoch 106/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6405 - fbeta: 0.6850 - acc: 0.7591 - val_loss: 0.9885 - val_fbeta: 0.5827 - val_acc: 0.6504
#
# Epoch 00106: saving model to Model.106-0.6504.hdf5
#
# Epoch 00106: saving model to Model.106-0.6504.hdf5
# Epoch 107/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6386 - fbeta: 0.6840 - acc: 0.7574 - val_loss: 0.9254 - val_fbeta: 0.6164 - val_acc: 0.6843
#
# Epoch 00107: saving model to Model.107-0.6843.hdf5
#
# Epoch 00107: saving model to Model.107-0.6843.hdf5
# Epoch 108/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6349 - fbeta: 0.6884 - acc: 0.7621 - val_loss: 1.0118 - val_fbeta: 0.6153 - val_acc: 0.6584
#
# Epoch 00108: saving model to Model.108-0.6584.hdf5
#
# Epoch 00108: saving model to Model.108-0.6584.hdf5
# Epoch 109/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6374 - fbeta: 0.6886 - acc: 0.7584 - val_loss: 0.9254 - val_fbeta: 0.6196 - val_acc: 0.6886
#
# Epoch 00109: saving model to Model.109-0.6886.hdf5
#
# Epoch 00109: saving model to Model.109-0.6886.hdf5
# Epoch 110/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6381 - fbeta: 0.6859 - acc: 0.7583 - val_loss: 1.0279 - val_fbeta: 0.5916 - val_acc: 0.6626
#
# Epoch 00110: saving model to Model.110-0.6626.hdf5
#
# Epoch 00110: saving model to Model.110-0.6626.hdf5
# Epoch 111/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6370 - fbeta: 0.6890 - acc: 0.7581 - val_loss: 0.9361 - val_fbeta: 0.6379 - val_acc: 0.6918
#
# Epoch 00111: saving model to Model.111-0.6918.hdf5
#
# Epoch 00111: saving model to Model.111-0.6918.hdf5
# Epoch 112/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6409 - fbeta: 0.6876 - acc: 0.7598 - val_loss: 0.9118 - val_fbeta: 0.5970 - val_acc: 0.6735
#
# Epoch 00112: saving model to Model.112-0.6735.hdf5
#
# Epoch 00112: saving model to Model.112-0.6735.hdf5
# Epoch 113/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6352 - fbeta: 0.6909 - acc: 0.7620 - val_loss: 0.9577 - val_fbeta: 0.6115 - val_acc: 0.6792
#
# Epoch 00113: saving model to Model.113-0.6792.hdf5
#
# Epoch 00113: saving model to Model.113-0.6792.hdf5
# Epoch 114/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6443 - fbeta: 0.6841 - acc: 0.7579 - val_loss: 0.9529 - val_fbeta: 0.6218 - val_acc: 0.6670
#
# Epoch 00114: saving model to Model.114-0.6670.hdf5
#
# Epoch 00114: saving model to Model.114-0.6670.hdf5
# Epoch 115/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6377 - fbeta: 0.6856 - acc: 0.7591 - val_loss: 0.9563 - val_fbeta: 0.6110 - val_acc: 0.6713
#
# Epoch 00115: saving model to Model.115-0.6713.hdf5
#
# Epoch 00115: saving model to Model.115-0.6713.hdf5
# Epoch 116/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6361 - fbeta: 0.6864 - acc: 0.7584 - val_loss: 0.9735 - val_fbeta: 0.5927 - val_acc: 0.6519
#
# Epoch 00116: saving model to Model.116-0.6519.hdf5
#
# Epoch 00116: saving model to Model.116-0.6519.hdf5
# Epoch 117/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6344 - fbeta: 0.6869 - acc: 0.7570 - val_loss: 0.9401 - val_fbeta: 0.6160 - val_acc: 0.6748
#
# Epoch 00117: saving model to Model.117-0.6748.hdf5
#
# Epoch 00117: saving model to Model.117-0.6748.hdf5
# Epoch 118/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6346 - fbeta: 0.6862 - acc: 0.7589 - val_loss: 0.9456 - val_fbeta: 0.6088 - val_acc: 0.6649
#
# Epoch 00118: saving model to Model.118-0.6649.hdf5
#
# Epoch 00118: saving model to Model.118-0.6649.hdf5
# Epoch 119/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6383 - fbeta: 0.6886 - acc: 0.7603 - val_loss: 0.9686 - val_fbeta: 0.6099 - val_acc: 0.6735
#
# Epoch 00119: saving model to Model.119-0.6735.hdf5
#
# Epoch 00119: saving model to Model.119-0.6735.hdf5
# Epoch 120/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6381 - fbeta: 0.6877 - acc: 0.7597 - val_loss: 1.0001 - val_fbeta: 0.5905 - val_acc: 0.6638
#
# Epoch 00120: saving model to Model.120-0.6638.hdf5
#
# Epoch 00120: saving model to Model.120-0.6638.hdf5
# Epoch 121/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6326 - fbeta: 0.6893 - acc: 0.7612 - val_loss: 0.9183 - val_fbeta: 0.6149 - val_acc: 0.6881
#
# Epoch 00121: saving model to Model.121-0.6881.hdf5
#
# Epoch 00121: saving model to Model.121-0.6881.hdf5
# Epoch 122/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6390 - fbeta: 0.6858 - acc: 0.7556 - val_loss: 0.8658 - val_fbeta: 0.6304 - val_acc: 0.7004
#
# Epoch 00122: saving model to Model.122-0.7004.hdf5
#
# Epoch 00122: saving model to Model.122-0.7004.hdf5
# Epoch 123/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6467 - fbeta: 0.6840 - acc: 0.7567 - val_loss: 0.9755 - val_fbeta: 0.6088 - val_acc: 0.6627
#
# Epoch 00123: saving model to Model.123-0.6627.hdf5
#
# Epoch 00123: saving model to Model.123-0.6627.hdf5
# Epoch 124/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6419 - fbeta: 0.6891 - acc: 0.7589 - val_loss: 1.0034 - val_fbeta: 0.5959 - val_acc: 0.6638
#
# Epoch 00124: saving model to Model.124-0.6638.hdf5
#
# Epoch 00124: saving model to Model.124-0.6638.hdf5
# Epoch 125/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6370 - fbeta: 0.6870 - acc: 0.7582 - val_loss: 1.0115 - val_fbeta: 0.6160 - val_acc: 0.6726
#
# Epoch 00125: saving model to Model.125-0.6726.hdf5
#
# Epoch 00125: saving model to Model.125-0.6726.hdf5
# Epoch 126/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6363 - fbeta: 0.6893 - acc: 0.7617 - val_loss: 0.8670 - val_fbeta: 0.6325 - val_acc: 0.7058
#
# Epoch 00126: saving model to Model.126-0.7058.hdf5
#
# Epoch 00126: saving model to Model.126-0.7058.hdf5
# Epoch 127/128
# 225/224 [==============================] - 47s 209ms/step - loss: 0.6368 - fbeta: 0.6869 - acc: 0.7576 - val_loss: 1.0114 - val_fbeta: 0.5970 - val_acc: 0.6638
#
# Epoch 00127: saving model to Model.127-0.6638.hdf5
#
# Epoch 00127: saving model to Model.127-0.6638.hdf5
# Epoch 128/128
# 225/224 [==============================] - 47s 210ms/step - loss: 0.6373 - fbeta: 0.6881 - acc: 0.7596 - val_loss: 0.9839 - val_fbeta: 0.5884 - val_acc: 0.6476
#
# Epoch 00128: saving model to Model.128-0.6476.hdf5
#
# Epoch 00128: saving model to Model.128-0.6476.hdf5

# %%
'''
Evaluation
'''
score = model.evaluate(X_test, y_test, steps=int(NUM_TEST / BATCH_SIZE))
print('Evaluation Loss: ', score[0])
print('Evaluation Accuracy: ', score[1])

# History of Accuracy
hist_acc = 'accuracy.png'
fig1 = plt.figure()
plt.plot(history.history['acc'], color='b', label='Training')
plt.plot(history.history['val_acc'], color='g', label='Validation')
plt.title('History for Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
fig1.savefig(hist_acc)
plt.show() 

# History of Loss
loss_acc = 'loss.png'
fig2 = plt.figure()
plt.plot(history.history['loss'], color='b', label='Training')
plt.plot(history.history['val_loss'], color='g', label='Validation')
plt.title('History for Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='lower left')
fig1.savefig(loss_acc)
plt.show()

# Confusion Matrix
y_pred = model.predict_classes(X_test)
y_true = np.asarray([np.argmax(i) for i in y_test])

cm = confusion_matrix(y_true, y_pred)
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
sns.set(font_scale=1.5)
fig, ax = plt.subplots(figsize=(10,10))
ax = sns.heatmap(cm_norm, annot=True, linewidths=0, square=False, cmap='Greens', yticklabels=EMOTION_LABELS, xticklabels=EMOTION_LABELS, vmin=0, vmax=np.max(cm_norm), fmt='.2f', annot_kws={'size': 20})
ax.set(xlabel='Predicted Labels', ylabel='Actual Labels')

plt.show()
# Out:
# 28/28 [==============================] - 42s 2s/step
# Evaluation Loss:  0.9121073484420776
# Evaluation Accuracy:  0.6174421906471252
