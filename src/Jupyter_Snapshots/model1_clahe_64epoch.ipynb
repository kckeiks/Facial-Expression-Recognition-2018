# %%
'''
Libraries, etc.
'''
import os
import cv2
import time
import numpy as np # linear algebra
import scipy as sp # more w/ numpy arrays
import pandas as pd # data processing
import tensorflow as tf # machine learning
import matplotlib.pyplot as plt # graph/plot
import seaborn as sns

from keras.layers import Convolution2D, Activation, BatchNormalization, GaussianNoise, MaxPooling2D, Dropout, Dense, Flatten
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras import backend as K
from keras.utils import np_utils as npu
from sklearn.metrics import confusion_matrix

from google.colab import files
uploaded = files.upload()
# Out:
# Using TensorFlow backend.
#      <input type="file" id="files-0fd71a23-dede-4609-8681-7ce1b52f205f" name="files[]" multiple disabled />
#      <output id="result-0fd71a23-dede-4609-8681-7ce1b52f205f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving fer2013.csv to fer2013.csv

# %%
'''
Constants, Hyperparameters, etc.
'''
INPUT_FILE = 'fer2013.csv'

EMOTION_LABELS = ['Angry','Disgust','Fear','Happy','Sad','Surprise','Neutral']
NUM_LABELS = 7

BASE_SIZE = 48
BASE_DEPTH = 1

BATCH_SIZE = 128
NUM_EPOCHS = 64

# %%
'''
Load & Parse Data into Training/Test Labels & Images
'''
data = pd.read_csv(INPUT_FILE)
data.head()

train_set = data[(data.Usage == 'Training')]
validation_set = data[(data.Usage == 'PublicTest')]
test_set = data[(data.Usage == 'PrivateTest')]

X_train1 = np.array(list(map(str.split, train_set.pixels)), np.uint8)
X_validation1 = np.array(list(map(str.split, validation_set.pixels)), np.uint8)
X_test1 = np.array(list(map(str.split, test_set.pixels)), np.uint8)

NUM_TRAIN = len(X_train1)
NUM_VALIDATION = len(X_validation1)
NUM_TEST = len(X_test1)

X_train1 = X_train1.reshape(NUM_TRAIN, BASE_SIZE, BASE_SIZE)
X_validation1 = X_validation1.reshape(NUM_VALIDATION, BASE_SIZE, BASE_SIZE)
X_test1 = X_test1.reshape(NUM_TEST, BASE_SIZE, BASE_SIZE)

print('Matrix Shapes for X')
print('Training: ', X_train1.shape)
print('Validation: ', X_validation1.shape)
print('Testing: ', X_test1.shape)

y_train = train_set.emotion
y_train = npu.to_categorical(y_train, NUM_LABELS)

y_validation = validation_set.emotion
y_validation = npu.to_categorical(y_validation, NUM_LABELS)

y_test = test_set.emotion
y_test = npu.to_categorical(y_test, NUM_LABELS)

print('Matrix Shapes for Y')
print('Training: ', y_train.shape)
print('Validation: ', y_validation.shape)
print('Testing: ', y_test.shape)
# Out:
# Matrix Shapes for X
# Training:  (28709, 48, 48)
# Validation:  (3589, 48, 48)
# Testing:  (3589, 48, 48)
# Matrix Shapes for Y
# Training:  (28709, 7)
# Validation:  (3589, 7)
# Testing:  (3589, 7)

# %%
'''
Histogram Equalization, etc.
'''
clahe = cv2.createCLAHE(clipLimit=3.235, tileGridSize=(5,5))

X_train2 = X_train1.copy()
X_train3 = X_train1.copy()

X_validation2 = X_validation1.copy()
X_validation3 = X_validation1.copy()

X_test2 = X_test1.copy()
X_test3 = X_test1.copy()

i = 0
while (i < NUM_TRAIN):
  tMax = X_train1[i].max()
  tMin = X_train1[i].min()  

  if (tMax > tMin):
    tRatio = 255 / (tMax - tMin)
    X_train2[i] = np.multiply((X_train1[i] - tMin), tRatio)
    
  # Delete useless training examples
  else:
    X_train1 = np.delete(X_train1, (i), axis=0)
    X_train2 = np.delete(X_train2, (i), axis=0)
    X_train3 = np.delete(X_train3, (i), axis=0)
    y_train = np.delete(y_train, (i), axis=0)
    NUM_TRAIN -= 1
    i -= 1
    
  X_train3[i] = clahe.apply(X_train2[i])
  i += 1
  
i = 0
while (i < NUM_VALIDATION):
  tMax = X_validation1[i].max()
  tMin = X_validation1[i].min()

  # Shouldn't delete validation data... skip so we don't divide by 0
  if (tMax > tMin):
    tRatio = 255 / (tMax - tMin)
    X_validation2[i] = np.multiply((X_validation1[i] - tMin), tRatio).round()
  else:
    X_validation2[i] = X_validation1[i]

  X_validation3[i] = clahe.apply(X_validation2[i])
  i += 1

i = 0
while (i < NUM_TEST):
  tMax = X_test1[i].max()
  tMin = X_test1[i].min()

  # Shouldn't delete test data... skip so we don't divide by 0
  if (tMax > tMin):
    tRatio = 255 / (tMax - tMin)
    X_test2[i] = np.multiply((X_test1[i] - tMin), tRatio).round()
  else:
    X_test2[i] = X_test1[i]
    
  X_test3[i] = clahe.apply(X_test2[i])
  i += 1

'''
Print Samples from Input Data (to confirm transforms are correct)
'''
print('Original Images...')
for x in range(1,26):
    plt.subplot(5, 5, x)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_test1[x], cmap='gray')
    
plt.show()

print('Original w/ Linear Transform to normalize pixel values...')
for x in range(1,26):
    plt.subplot(5, 5, x)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_test2[x], cmap='gray')
    
plt.show()

print('Normalized w/ Contrast Limited Adaptive Histogram Equalization')
for x in range(1,26):
    plt.subplot(5, 5, x)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_test3[x], cmap='gray')
    
plt.show()
# Out:
# Original Images...
# Original w/ Linear Transform to normalize pixel values...
# Normalized w/ Contrast Limited Adaptive Histogram Equalization

# %%
'''
TensorFlow Model(s)
'''

def get_model1():
  model = Sequential()

  model.add(Convolution2D(64, (3, 3), padding='same', input_shape=(48,48,1)))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(128, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(256, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Flatten())

  model.add(Dense(512))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(256))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(7))
  model.add(Activation('softmax'))

  return model


def get_model2():
  model = Sequential()

  model.add(Convolution2D(64, (3, 3), padding='same', input_shape=(48,48,1)))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(128, (5, 5), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Flatten())

  model.add(Dense(256))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(512))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(7))
  model.add(Activation('softmax'))

  return model


def get_model3():
  model = Sequential()

  model.add(Convolution2D(64, (3, 3), padding='same', input_shape=(48,48,1)))
  model.add(Convolution2D(64, (3, 3), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(GaussianNoise(2))
  model.add(Dropout(0.4))

  model.add(Convolution2D(128, (3, 3), padding='same'))
  model.add(Convolution2D(128, (3, 3), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(GaussianNoise(2))
  model.add(Dropout(0.4))

  model.add(Convolution2D(256, (3, 3), padding='same'))
  model.add(Convolution2D(265, (3, 3), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(GaussianNoise(2))
  model.add(Dropout(0.4))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(Convolution2D(512, (3, 3), padding='same')) 
  model.add(Convolution2D(512, (1, 1), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(GaussianNoise(2))
  model.add(Dropout(0.4))

  model.add(Flatten())

  model.add(Dense(2048))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.4))

  model.add(Dense(512))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.4))

  model.add(Dense(7))
  model.add(Activation('softmax'))

  return model

# %%
'''
Metric(s)
'''
def fbeta(y_true, y_pred, threshold_shift=0):
  beta = 1
  
  y_pred = K.clip(y_pred, 0, 1)
  y_pred_bin = K.round(y_pred + threshold_shift)
  
  tp = K.sum(K.round(y_true * y_pred_bin), axis=1) + K.epsilon()
  fp = K.sum(K.round(K.clip(y_pred_bin - y_true, 0, 1)), axis=1)
  fn = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=1)
  
  precision = tp / (tp + fp)
  recall = tp / (tp + fn)
  
  beta_sq = beta ** 2
  return K.mean((beta_sq + 1) * (precision * recall) / (beta_sq * precision + recall + K.epsilon()))

# %%
'''
Setup Model & Data Generator
'''
# assign X_train/validation/test to the desired image set(s) from above
X_train = X_train3
X_validation = X_validation3
X_test = X_test3
NUM_TRAIN = len(X_train)

# reshape X_train/validation/test to the expected shape, and cast it back to a float32
X_train = X_train.reshape(NUM_TRAIN,BASE_SIZE,BASE_SIZE,1).astype(np.float32)
X_validation = X_validation.reshape(NUM_VALIDATION,BASE_SIZE,BASE_SIZE,1).astype(np.float32)
X_test = X_test.reshape(NUM_TEST,BASE_SIZE,BASE_SIZE,1).astype(np.float32)

# assign the desired model from above
model = get_model1()
model.summary()

# augmentation and fitting of data
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    rotation_range=0,
    width_shift_range=0.0,
    height_shift_range=0.0,
    shear_range=0,
    horizontal_flip=True,
    vertical_flip=False
)
datagen.fit(X_train)
datagen.fit(X_validation)

filepath = 'Model.{epoch:02d}-{val_acc:.4f}.hdf5'

checkpointer = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, mode='auto')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, verbose=0, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)
early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=0, verbose=0, mode='auto')

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=[fbeta, 'accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 48, 48, 64)        640
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 48, 48, 64)        256
# _________________________________________________________________
# activation_1 (Activation)    (None, 48, 48, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 24, 24, 128)       512
# _________________________________________________________________
# activation_2 (Activation)    (None, 24, 24, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 12, 12, 256)       295168
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 12, 12, 256)       1024
# _________________________________________________________________
# activation_3 (Activation)    (None, 12, 12, 256)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 256)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 6, 6, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 6, 6, 512)         1180160
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 6, 6, 512)         2048
# _________________________________________________________________
# activation_4 (Activation)    (None, 6, 6, 512)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               2359808
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_6 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 1799
# _________________________________________________________________
# activation_7 (Activation)    (None, 7)                 0
# =================================================================
# Total params: 4,049,671
# Trainable params: 4,046,215
# Non-trainable params: 3,456
# _________________________________________________________________

# %%
'''
Training
'''
train_flow = datagen.flow(X_train, y_train, batch_size=BATCH_SIZE)
validation_flow = datagen.flow(X_validation, y_validation)

history = model.fit_generator(
    train_flow,
    steps_per_epoch=NUM_TRAIN / BATCH_SIZE,
    epochs=NUM_EPOCHS,
    verbose=1,
    validation_data=validation_flow,
    validation_steps=NUM_VALIDATION / BATCH_SIZE,
    callbacks=[checkpointer, reduce_lr, checkpointer]
)
# Out:
# Epoch 1/64
# 225/224 [==============================] - 28s 122ms/step - loss: 1.6920 - fbeta: 0.1635 - acc: 0.3603 - val_loss: 1.4968 - val_fbeta: 0.2101 - val_acc: 0.4030
#
# Epoch 00001: saving model to Model.01-0.4030.hdf5
#
# Epoch 00001: saving model to Model.01-0.4030.hdf5
# Epoch 2/64
# 225/224 [==============================] - 23s 101ms/step - loss: 1.3775 - fbeta: 0.2680 - acc: 0.4740 - val_loss: 1.4200 - val_fbeta: 0.2985 - val_acc: 0.4450
#
# Epoch 00002: saving model to Model.02-0.4450.hdf5
#
# Epoch 00002: saving model to Model.02-0.4450.hdf5
# Epoch 3/64
# 225/224 [==============================] - 23s 101ms/step - loss: 1.2610 - fbeta: 0.3146 - acc: 0.5164 - val_loss: 1.2859 - val_fbeta: 0.2974 - val_acc: 0.4903
#
# Epoch 00003: saving model to Model.03-0.4903.hdf5
#
# Epoch 00003: saving model to Model.03-0.4903.hdf5
# Epoch 4/64
# 225/224 [==============================] - 23s 101ms/step - loss: 1.1900 - fbeta: 0.3476 - acc: 0.5456 - val_loss: 1.1536 - val_fbeta: 0.4029 - val_acc: 0.5627
#
# Epoch 00004: saving model to Model.04-0.5627.hdf5
#
# Epoch 00004: saving model to Model.04-0.5627.hdf5
# Epoch 5/64
# 225/224 [==============================] - 23s 102ms/step - loss: 1.1402 - fbeta: 0.3817 - acc: 0.5698 - val_loss: 1.1684 - val_fbeta: 0.4321 - val_acc: 0.5733
#
# Epoch 00005: saving model to Model.05-0.5733.hdf5
#
# Epoch 00005: saving model to Model.05-0.5733.hdf5
# Epoch 6/64
# 225/224 [==============================] - 23s 101ms/step - loss: 1.1097 - fbeta: 0.3982 - acc: 0.5767 - val_loss: 1.1992 - val_fbeta: 0.3858 - val_acc: 0.5485
#
# Epoch 00006: saving model to Model.06-0.5485.hdf5
#
# Epoch 00006: saving model to Model.06-0.5485.hdf5
# Epoch 7/64
# 225/224 [==============================] - 23s 101ms/step - loss: 1.0731 - fbeta: 0.4225 - acc: 0.5939 - val_loss: 1.1676 - val_fbeta: 0.3987 - val_acc: 0.5733
#
# Epoch 00007: saving model to Model.07-0.5733.hdf5
#
# Epoch 00007: saving model to Model.07-0.5733.hdf5
# Epoch 8/64
# 225/224 [==============================] - 23s 101ms/step - loss: 1.0482 - fbeta: 0.4396 - acc: 0.6034 - val_loss: 1.1673 - val_fbeta: 0.4251 - val_acc: 0.5583
#
# Epoch 00008: saving model to Model.08-0.5583.hdf5
#
# Epoch 00008: saving model to Model.08-0.5583.hdf5
# Epoch 9/64
# 225/224 [==============================] - 23s 101ms/step - loss: 1.0268 - fbeta: 0.4551 - acc: 0.6104 - val_loss: 1.1671 - val_fbeta: 0.4547 - val_acc: 0.5636
#
# Epoch 00009: saving model to Model.09-0.5636.hdf5
#
# Epoch 00009: saving model to Model.09-0.5636.hdf5
# Epoch 10/64
# 225/224 [==============================] - 23s 101ms/step - loss: 1.0020 - fbeta: 0.4691 - acc: 0.6196 - val_loss: 1.0956 - val_fbeta: 0.4494 - val_acc: 0.5722
#
# Epoch 00010: saving model to Model.10-0.5722.hdf5
#
# Epoch 00010: saving model to Model.10-0.5722.hdf5
# Epoch 11/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.9760 - fbeta: 0.4854 - acc: 0.6299 - val_loss: 1.0683 - val_fbeta: 0.4720 - val_acc: 0.6110
#
# Epoch 00011: saving model to Model.11-0.6110.hdf5
#
# Epoch 00011: saving model to Model.11-0.6110.hdf5
# Epoch 12/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.9627 - fbeta: 0.4970 - acc: 0.6353 - val_loss: 1.1362 - val_fbeta: 0.4395 - val_acc: 0.5649
#
# Epoch 00012: saving model to Model.12-0.5649.hdf5
#
# Epoch 00012: saving model to Model.12-0.5649.hdf5
# Epoch 13/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.9376 - fbeta: 0.5091 - acc: 0.6460 - val_loss: 1.1045 - val_fbeta: 0.4709 - val_acc: 0.5905
#
# Epoch 00013: saving model to Model.13-0.5905.hdf5
#
# Epoch 00013: saving model to Model.13-0.5905.hdf5
# Epoch 14/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.9169 - fbeta: 0.5268 - acc: 0.6550 - val_loss: 1.0100 - val_fbeta: 0.4709 - val_acc: 0.6185
#
# Epoch 00014: saving model to Model.14-0.6185.hdf5
#
# Epoch 00014: saving model to Model.14-0.6185.hdf5
# Epoch 15/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.8902 - fbeta: 0.5410 - acc: 0.6641 - val_loss: 1.0745 - val_fbeta: 0.5011 - val_acc: 0.6088
#
# Epoch 00015: saving model to Model.15-0.6088.hdf5
#
# Epoch 00015: saving model to Model.15-0.6088.hdf5
# Epoch 16/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.8719 - fbeta: 0.5543 - acc: 0.6718 - val_loss: 1.0860 - val_fbeta: 0.4850 - val_acc: 0.6016
#
# Epoch 00016: saving model to Model.16-0.6016.hdf5
#
# Epoch 00016: saving model to Model.16-0.6016.hdf5
# Epoch 17/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.8519 - fbeta: 0.5673 - acc: 0.6804 - val_loss: 1.0524 - val_fbeta: 0.5151 - val_acc: 0.6099
#
# Epoch 00017: saving model to Model.17-0.6099.hdf5
#
# Epoch 00017: saving model to Model.17-0.6099.hdf5
# Epoch 18/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.8401 - fbeta: 0.5775 - acc: 0.6859 - val_loss: 1.0208 - val_fbeta: 0.5259 - val_acc: 0.6164
#
# Epoch 00018: saving model to Model.18-0.6164.hdf5
#
# Epoch 00018: saving model to Model.18-0.6164.hdf5
# Epoch 19/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.8159 - fbeta: 0.5902 - acc: 0.6928 - val_loss: 1.0952 - val_fbeta: 0.5172 - val_acc: 0.6088
#
# Epoch 00019: saving model to Model.19-0.6088.hdf5
#
# Epoch 00019: saving model to Model.19-0.6088.hdf5
# Epoch 20/64
# 225/224 [==============================] - 23s 101ms/step - loss: 0.7937 - fbeta: 0.6047 - acc: 0.7045 - val_loss: 1.0408 - val_fbeta: 0.5139 - val_acc: 0.6215
#
# Epoch 00020: saving model to Model.20-0.6215.hdf5
#
# Epoch 00020: saving model to Model.20-0.6215.hdf5
# Epoch 21/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.7740 - fbeta: 0.6152 - acc: 0.7108 - val_loss: 1.0769 - val_fbeta: 0.5280 - val_acc: 0.6142
#
# Epoch 00021: saving model to Model.21-0.6142.hdf5
#
# Epoch 00021: saving model to Model.21-0.6142.hdf5
# Epoch 22/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.7605 - fbeta: 0.6276 - acc: 0.7154 - val_loss: 1.0030 - val_fbeta: 0.5463 - val_acc: 0.6455
#
# Epoch 00022: saving model to Model.22-0.6455.hdf5
#
# Epoch 00022: saving model to Model.22-0.6455.hdf5
# Epoch 23/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.7370 - fbeta: 0.6384 - acc: 0.7235 - val_loss: 1.1871 - val_fbeta: 0.5259 - val_acc: 0.5894
#
# Epoch 00023: saving model to Model.23-0.5894.hdf5
#
# Epoch 00023: saving model to Model.23-0.5894.hdf5
# Epoch 24/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.7195 - fbeta: 0.6514 - acc: 0.7334 - val_loss: 1.1230 - val_fbeta: 0.5350 - val_acc: 0.5949
#
# Epoch 00024: saving model to Model.24-0.5949.hdf5
#
# Epoch 00024: saving model to Model.24-0.5949.hdf5
# Epoch 25/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.6966 - fbeta: 0.6648 - acc: 0.7416 - val_loss: 1.1477 - val_fbeta: 0.5280 - val_acc: 0.6034
#
# Epoch 00025: saving model to Model.25-0.6034.hdf5
#
# Epoch 00025: saving model to Model.25-0.6034.hdf5
# Epoch 26/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.6783 - fbeta: 0.6725 - acc: 0.7442 - val_loss: 1.2181 - val_fbeta: 0.5205 - val_acc: 0.5873
#
# Epoch 00026: saving model to Model.26-0.5873.hdf5
#
# Epoch 00026: saving model to Model.26-0.5873.hdf5
# Epoch 27/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.6560 - fbeta: 0.6888 - acc: 0.7571 - val_loss: 1.0924 - val_fbeta: 0.5463 - val_acc: 0.6131
#
# Epoch 00027: saving model to Model.27-0.6131.hdf5
#
# Epoch 00027: saving model to Model.27-0.6131.hdf5
# Epoch 28/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.6424 - fbeta: 0.6964 - acc: 0.7590 - val_loss: 1.0650 - val_fbeta: 0.5616 - val_acc: 0.6315
#
# Epoch 00028: saving model to Model.28-0.6315.hdf5
#
# Epoch 00028: saving model to Model.28-0.6315.hdf5
# Epoch 29/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.6172 - fbeta: 0.7085 - acc: 0.7711 - val_loss: 1.0808 - val_fbeta: 0.5808 - val_acc: 0.6218
#
# Epoch 00029: saving model to Model.29-0.6218.hdf5
#
# Epoch 00029: saving model to Model.29-0.6218.hdf5
# Epoch 30/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.5944 - fbeta: 0.7202 - acc: 0.7775 - val_loss: 1.1045 - val_fbeta: 0.5862 - val_acc: 0.6401
#
# Epoch 00030: saving model to Model.30-0.6401.hdf5
#
# Epoch 00030: saving model to Model.30-0.6401.hdf5
# Epoch 31/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.5783 - fbeta: 0.7318 - acc: 0.7868 - val_loss: 1.4209 - val_fbeta: 0.5119 - val_acc: 0.5571
#
# Epoch 00031: saving model to Model.31-0.5571.hdf5
#
# Epoch 00031: saving model to Model.31-0.5571.hdf5
# Epoch 32/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.5613 - fbeta: 0.7474 - acc: 0.7940 - val_loss: 1.1332 - val_fbeta: 0.5816 - val_acc: 0.6226
#
# Epoch 00032: saving model to Model.32-0.6226.hdf5
#
# Epoch 00032: saving model to Model.32-0.6226.hdf5
# Epoch 33/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.5003 - fbeta: 0.7661 - acc: 0.8151 - val_loss: 0.9712 - val_fbeta: 0.6175 - val_acc: 0.6746
#
# Epoch 00033: saving model to Model.33-0.6746.hdf5
#
# Epoch 00033: saving model to Model.33-0.6746.hdf5
# Epoch 34/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.4817 - fbeta: 0.7754 - acc: 0.8219 - val_loss: 1.1235 - val_fbeta: 0.6034 - val_acc: 0.6379
#
# Epoch 00034: saving model to Model.34-0.6379.hdf5
#
# Epoch 00034: saving model to Model.34-0.6379.hdf5
# Epoch 35/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.4645 - fbeta: 0.7888 - acc: 0.8314 - val_loss: 1.0875 - val_fbeta: 0.6185 - val_acc: 0.6659
#
# Epoch 00035: saving model to Model.35-0.6659.hdf5
#
# Epoch 00035: saving model to Model.35-0.6659.hdf5
# Epoch 36/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.4504 - fbeta: 0.7930 - acc: 0.8353 - val_loss: 1.0297 - val_fbeta: 0.6260 - val_acc: 0.6681
#
# Epoch 00036: saving model to Model.36-0.6681.hdf5
#
# Epoch 00036: saving model to Model.36-0.6681.hdf5
# Epoch 37/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.4465 - fbeta: 0.8017 - acc: 0.8404 - val_loss: 1.1367 - val_fbeta: 0.6218 - val_acc: 0.6595
#
# Epoch 00037: saving model to Model.37-0.6595.hdf5
#
# Epoch 00037: saving model to Model.37-0.6595.hdf5
# Epoch 38/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.4433 - fbeta: 0.7988 - acc: 0.8368 - val_loss: 1.1180 - val_fbeta: 0.6088 - val_acc: 0.6509
#
# Epoch 00038: saving model to Model.38-0.6509.hdf5
#
# Epoch 00038: saving model to Model.38-0.6509.hdf5
# Epoch 39/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.4317 - fbeta: 0.8062 - acc: 0.8417 - val_loss: 0.9801 - val_fbeta: 0.6437 - val_acc: 0.6759
#
# Epoch 00039: saving model to Model.39-0.6759.hdf5
#
# Epoch 00039: saving model to Model.39-0.6759.hdf5
# Epoch 40/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.4261 - fbeta: 0.8081 - acc: 0.8431 - val_loss: 1.0775 - val_fbeta: 0.6175 - val_acc: 0.6541
#
# Epoch 00040: saving model to Model.40-0.6541.hdf5
#
# Epoch 00040: saving model to Model.40-0.6541.hdf5
# Epoch 41/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.4166 - fbeta: 0.8145 - acc: 0.8483 - val_loss: 1.1932 - val_fbeta: 0.6207 - val_acc: 0.6498
#
# Epoch 00041: saving model to Model.41-0.6498.hdf5
#
# Epoch 00041: saving model to Model.41-0.6498.hdf5
# Epoch 42/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.4034 - fbeta: 0.8180 - acc: 0.8511 - val_loss: 1.0194 - val_fbeta: 0.6487 - val_acc: 0.6800
#
# Epoch 00042: saving model to Model.42-0.6800.hdf5
#
# Epoch 00042: saving model to Model.42-0.6800.hdf5
# Epoch 43/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.4090 - fbeta: 0.8187 - acc: 0.8498 - val_loss: 1.1162 - val_fbeta: 0.6437 - val_acc: 0.6637
#
# Epoch 00043: saving model to Model.43-0.6637.hdf5
#
# Epoch 00043: saving model to Model.43-0.6637.hdf5
# Epoch 44/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.3917 - fbeta: 0.8250 - acc: 0.8558 - val_loss: 1.1360 - val_fbeta: 0.6218 - val_acc: 0.6519
#
# Epoch 00044: saving model to Model.44-0.6519.hdf5
#
# Epoch 00044: saving model to Model.44-0.6519.hdf5
# Epoch 45/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.3893 - fbeta: 0.8294 - acc: 0.8577 - val_loss: 1.1455 - val_fbeta: 0.6315 - val_acc: 0.6649
#
# Epoch 00045: saving model to Model.45-0.6649.hdf5
#
# Epoch 00045: saving model to Model.45-0.6649.hdf5
# Epoch 46/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.3928 - fbeta: 0.8248 - acc: 0.8544 - val_loss: 1.0376 - val_fbeta: 0.6476 - val_acc: 0.6810
#
# Epoch 00046: saving model to Model.46-0.6810.hdf5
#
# Epoch 00046: saving model to Model.46-0.6810.hdf5
# Epoch 47/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.3891 - fbeta: 0.8259 - acc: 0.8568 - val_loss: 1.0310 - val_fbeta: 0.6459 - val_acc: 0.6737
#
# Epoch 00047: saving model to Model.47-0.6737.hdf5
#
# Epoch 00047: saving model to Model.47-0.6737.hdf5
# Epoch 48/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.3970 - fbeta: 0.8269 - acc: 0.8565 - val_loss: 1.1703 - val_fbeta: 0.6336 - val_acc: 0.6638
#
# Epoch 00048: saving model to Model.48-0.6638.hdf5
#
# Epoch 00048: saving model to Model.48-0.6638.hdf5
# Epoch 49/64
# 225/224 [==============================] - 23s 101ms/step - loss: 0.3889 - fbeta: 0.8262 - acc: 0.8587 - val_loss: 1.0342 - val_fbeta: 0.6250 - val_acc: 0.6692
#
# Epoch 00049: saving model to Model.49-0.6692.hdf5
#
# Epoch 00049: saving model to Model.49-0.6692.hdf5
# Epoch 50/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.3937 - fbeta: 0.8268 - acc: 0.8562 - val_loss: 1.1421 - val_fbeta: 0.6315 - val_acc: 0.6649
#
# Epoch 00050: saving model to Model.50-0.6649.hdf5
#
# Epoch 00050: saving model to Model.50-0.6649.hdf5
# Epoch 51/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.3999 - fbeta: 0.8196 - acc: 0.8522 - val_loss: 1.0762 - val_fbeta: 0.6493 - val_acc: 0.6792
#
# Epoch 00051: saving model to Model.51-0.6792.hdf5
#
# Epoch 00051: saving model to Model.51-0.6792.hdf5
# Epoch 52/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.3902 - fbeta: 0.8280 - acc: 0.8592 - val_loss: 1.1298 - val_fbeta: 0.6282 - val_acc: 0.6573
#
# Epoch 00052: saving model to Model.52-0.6573.hdf5
#
# Epoch 00052: saving model to Model.52-0.6573.hdf5
# Epoch 53/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.3827 - fbeta: 0.8301 - acc: 0.8607 - val_loss: 1.0946 - val_fbeta: 0.6412 - val_acc: 0.6724
#
# Epoch 00053: saving model to Model.53-0.6724.hdf5
#
# Epoch 00053: saving model to Model.53-0.6724.hdf5
# Epoch 54/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.3874 - fbeta: 0.8270 - acc: 0.8571 - val_loss: 1.1367 - val_fbeta: 0.6024 - val_acc: 0.6455
#
# Epoch 00054: saving model to Model.54-0.6455.hdf5
#
# Epoch 00054: saving model to Model.54-0.6455.hdf5
# Epoch 55/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.3874 - fbeta: 0.8300 - acc: 0.8598 - val_loss: 1.1075 - val_fbeta: 0.6504 - val_acc: 0.6926
#
# Epoch 00055: saving model to Model.55-0.6926.hdf5
#
# Epoch 00055: saving model to Model.55-0.6926.hdf5
# Epoch 56/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.3845 - fbeta: 0.8277 - acc: 0.8576 - val_loss: 1.1164 - val_fbeta: 0.6606 - val_acc: 0.6940
#
# Epoch 00056: saving model to Model.56-0.6940.hdf5
#
# Epoch 00056: saving model to Model.56-0.6940.hdf5
# Epoch 57/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.3879 - fbeta: 0.8287 - acc: 0.8585 - val_loss: 1.0995 - val_fbeta: 0.6272 - val_acc: 0.6713
#
# Epoch 00057: saving model to Model.57-0.6713.hdf5
#
# Epoch 00057: saving model to Model.57-0.6713.hdf5
# Epoch 58/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.3912 - fbeta: 0.8260 - acc: 0.8551 - val_loss: 1.0630 - val_fbeta: 0.6455 - val_acc: 0.6800
#
# Epoch 00058: saving model to Model.58-0.6800.hdf5
#
# Epoch 00058: saving model to Model.58-0.6800.hdf5
# Epoch 59/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.3872 - fbeta: 0.8280 - acc: 0.8568 - val_loss: 1.1733 - val_fbeta: 0.6193 - val_acc: 0.6437
#
# Epoch 00059: saving model to Model.59-0.6437.hdf5
#
# Epoch 00059: saving model to Model.59-0.6437.hdf5
# Epoch 60/64
# 225/224 [==============================] - 23s 101ms/step - loss: 0.3885 - fbeta: 0.8266 - acc: 0.8560 - val_loss: 1.1089 - val_fbeta: 0.6272 - val_acc: 0.6692
#
# Epoch 00060: saving model to Model.60-0.6692.hdf5
#
# Epoch 00060: saving model to Model.60-0.6692.hdf5
# Epoch 61/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.3888 - fbeta: 0.8269 - acc: 0.8587 - val_loss: 1.1321 - val_fbeta: 0.6455 - val_acc: 0.6767
#
# Epoch 00061: saving model to Model.61-0.6767.hdf5
#
# Epoch 00061: saving model to Model.61-0.6767.hdf5
# Epoch 62/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.3879 - fbeta: 0.8268 - acc: 0.8574 - val_loss: 1.0532 - val_fbeta: 0.6519 - val_acc: 0.6853
#
# Epoch 00062: saving model to Model.62-0.6853.hdf5
#
# Epoch 00062: saving model to Model.62-0.6853.hdf5
# Epoch 63/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.3850 - fbeta: 0.8289 - acc: 0.8601 - val_loss: 1.1231 - val_fbeta: 0.6204 - val_acc: 0.6615
#
# Epoch 00063: saving model to Model.63-0.6615.hdf5
#
# Epoch 00063: saving model to Model.63-0.6615.hdf5
# Epoch 64/64
# 225/224 [==============================] - 23s 102ms/step - loss: 0.3842 - fbeta: 0.8313 - acc: 0.8610 - val_loss: 1.0997 - val_fbeta: 0.6369 - val_acc: 0.6670
#
# Epoch 00064: saving model to Model.64-0.6670.hdf5
#
# Epoch 00064: saving model to Model.64-0.6670.hdf5

# %%
'''
Evaluation
'''
score = model.evaluate(X_test, y_test, steps=int(NUM_TEST / BATCH_SIZE))
print('Evaluation Loss: ', score[0])
print('Evaluation Accuracy: ', score[1])

# History of Accuracy
hist_acc = 'accuracy.png'
fig1 = plt.figure()
plt.plot(history.history['acc'], color='b', label='Training')
plt.plot(history.history['val_acc'], color='g', label='Validation')
plt.title('History for Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
fig1.savefig(hist_acc)
plt.show() 

# History of Loss
loss_acc = 'loss.png'
fig2 = plt.figure()
plt.plot(history.history['loss'], color='b', label='Training')
plt.plot(history.history['val_loss'], color='g', label='Validation')
plt.title('History for Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='lower left')
fig1.savefig(loss_acc)
plt.show()

# Confusion Matrix
y_pred = model.predict_classes(X_test)
y_true = np.asarray([np.argmax(i) for i in y_test])

cm = confusion_matrix(y_true, y_pred)
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
sns.set(font_scale=1.5)
fig, ax = plt.subplots(figsize=(10,10))
ax = sns.heatmap(cm_norm, annot=True, linewidths=0, square=False, cmap='Greens', yticklabels=EMOTION_LABELS, xticklabels=EMOTION_LABELS, vmin=0, vmax=np.max(cm_norm), fmt='.2f', annot_kws={'size': 20})
ax.set(xlabel='Predicted Labels', ylabel='Actual Labels')

plt.show()
# Out:
# 28/28 [==============================] - 21s 737ms/step
# Evaluation Loss:  1.0340418815612793
# Evaluation Accuracy:  0.645862340927124
