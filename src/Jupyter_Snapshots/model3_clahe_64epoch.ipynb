# %%
'''
Libraries, etc.
'''
import os
import cv2
import time
import numpy as np # linear algebra
import scipy as sp # more w/ numpy arrays
import pandas as pd # data processing
import tensorflow as tf # machine learning
import matplotlib.pyplot as plt # graph/plot
import seaborn as sns

from keras.layers import Convolution2D, Activation, BatchNormalization, GaussianNoise, MaxPooling2D, Dropout, Dense, Flatten
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras import backend as K
from keras.utils import np_utils as npu
from sklearn.metrics import confusion_matrix

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-510ed3cb-4cae-44f8-bebd-9c4bf09204b3" name="files[]" multiple disabled />
#      <output id="result-510ed3cb-4cae-44f8-bebd-9c4bf09204b3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
'''
Constants, Hyperparameters, etc.
'''
INPUT_FILE = 'fer2013.csv'

EMOTION_LABELS = ['Angry','Disgust','Fear','Happy','Sad','Surprise','Neutral']
NUM_LABELS = 7

BASE_SIZE = 48
BASE_DEPTH = 1

BATCH_SIZE = 128
NUM_EPOCHS = 64

# %%
'''
Load & Parse Data into Training/Test Labels & Images
'''
data = pd.read_csv(INPUT_FILE)
data.head()

train_set = data[(data.Usage == 'Training')]
validation_set = data[(data.Usage == 'PublicTest')]
test_set = data[(data.Usage == 'PrivateTest')]

X_train1 = np.array(list(map(str.split, train_set.pixels)), np.uint8)
X_validation1 = np.array(list(map(str.split, validation_set.pixels)), np.uint8)
X_test1 = np.array(list(map(str.split, test_set.pixels)), np.uint8)

NUM_TRAIN = len(X_train1)
NUM_VALIDATION = len(X_validation1)
NUM_TEST = len(X_test1)

X_train1 = X_train1.reshape(NUM_TRAIN, BASE_SIZE, BASE_SIZE)
X_validation1 = X_validation1.reshape(NUM_VALIDATION, BASE_SIZE, BASE_SIZE)
X_test1 = X_test1.reshape(NUM_TEST, BASE_SIZE, BASE_SIZE)

print('Matrix Shapes for X')
print('Training: ', X_train1.shape)
print('Validation: ', X_validation1.shape)
print('Testing: ', X_test1.shape)

y_train = train_set.emotion
y_train = npu.to_categorical(y_train, NUM_LABELS)

y_validation = validation_set.emotion
y_validation = npu.to_categorical(y_validation, NUM_LABELS)

y_test = test_set.emotion
y_test = npu.to_categorical(y_test, NUM_LABELS)

print('Matrix Shapes for Y')
print('Training: ', y_train.shape)
print('Validation: ', y_validation.shape)
print('Testing: ', y_test.shape)
# Out:
# Training Shape:  (28709, 48, 48)
# Validation Shape:  (3589, 48, 48)
# Testing Shape:  (3589, 48, 48)

# %%
'''
Histogram Equalization, etc.
'''
clahe = cv2.createCLAHE(clipLimit=3.235, tileGridSize=(5,5))

X_train2 = X_train1.copy()
X_train3 = X_train1.copy()

X_validation2 = X_validation1.copy()
X_validation3 = X_validation1.copy()

X_test2 = X_test1.copy()
X_test3 = X_test1.copy()

i = 0
while (i < NUM_TRAIN):
  tMax = X_train1[i].max()
  tMin = X_train1[i].min()  

  if (tMax > tMin):
    tRatio = 255 / (tMax - tMin)
    X_train2[i] = np.multiply((X_train1[i] - tMin), tRatio)
    
  # Delete useless training examples
  else:
    X_train1 = np.delete(X_train1, (i), axis=0)
    X_train2 = np.delete(X_train2, (i), axis=0)
    X_train3 = np.delete(X_train3, (i), axis=0)
    y_train = np.delete(y_train, (i), axis=0)
    NUM_TRAIN -= 1
    i -= 1
    
  X_train3[i] = clahe.apply(X_train2[i])
  i += 1
  
i = 0
while (i < NUM_VALIDATION):
  tMax = X_validation1[i].max()
  tMin = X_validation1[i].min()

  # Shouldn't delete validation data... skip so we don't divide by 0
  if (tMax > tMin):
    tRatio = 255 / (tMax - tMin)
    X_validation2[i] = np.multiply((X_validation1[i] - tMin), tRatio).round()
  else:
    X_validation2[i] = X_validation1[i]

  X_validation3[i] = clahe.apply(X_validation2[i])
  i += 1

i = 0
while (i < NUM_TEST):
  tMax = X_test1[i].max()
  tMin = X_test1[i].min()

  # Shouldn't delete test data... skip so we don't divide by 0
  if (tMax > tMin):
    tRatio = 255 / (tMax - tMin)
    X_test2[i] = np.multiply((X_test1[i] - tMin), tRatio).round()
  else:
    X_test2[i] = X_test1[i]
    
  X_test3[i] = clahe.apply(X_test2[i])
  i += 1

'''
Print Samples from Input Data (to confirm transforms are correct)
'''
print('Original Images...')
for x in range(0,25):
    plt.subplot(5, 5, x)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_test1[x], cmap='gray')
    
plt.show()

print('Original w/ Linear Transform to normalize pixel values...')
for x in range(0,25):
    plt.subplot(5, 5, x)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_test2[x], cmap='gray')
    
plt.show()

print('Normalized w/ Contrast Limited Adaptive Histogram Equalization')
for x in range(0,25):
    plt.subplot(5, 5, x)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_test3[x], cmap='gray')
    
plt.show()
# Out:
# Original Images...
# Original w/ Linear Transform to normalize pixel values...
# Normalized w/ Contrast Limited Adaptive Histogram Equalization

# %%
'''
TensorFlow Model(s)
'''

def get_model1():
  model = Sequential()

  model.add(Convolution2D(64, (3, 3), padding='same', input_shape=(48,48,1)))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(128, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(256, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Flatten())

  model.add(Dense(512))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(256))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(7))
  model.add(Activation('softmax'))

  return model


def get_model2():
  model = Sequential()

  model.add(Convolution2D(64, (3, 3), padding='same', input_shape=(48,48,1)))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(128, (5, 5), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(Dropout(0.25))

  model.add(Flatten())

  model.add(Dense(256))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(512))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.25))

  model.add(Dense(7))
  model.add(Activation('softmax'))

  return model


def get_model3():
  model = Sequential()

  model.add(Convolution2D(64, (3, 3), padding='same', input_shape=(48,48,1)))
  model.add(Convolution2D(64, (3, 3), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(GaussianNoise(0.3))
  model.add(Dropout(0.4))

  model.add(Convolution2D(128, (3, 3), padding='same'))
  model.add(Convolution2D(128, (3, 3), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(GaussianNoise(0.3))
  model.add(Dropout(0.4))

  model.add(Convolution2D(256, (3, 3), padding='same'))
  model.add(Convolution2D(265, (3, 3), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(GaussianNoise(0.3))
  model.add(Dropout(0.4))

  model.add(Convolution2D(512, (3, 3), padding='same'))
  model.add(Convolution2D(512, (3, 3), padding='same')) 
  model.add(Convolution2D(512, (1, 1), padding='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
  model.add(GaussianNoise(0.3))
  model.add(Dropout(0.4))

  model.add(Flatten())

  model.add(Dense(2048))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.4))

  model.add(Dense(512))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.4))

  model.add(Dense(7))
  model.add(Activation('softmax'))

  return model

# %%
'''
Metric(s)
'''
def fbeta(y_true, y_pred, threshold_shift=0):
  beta = 1
  
  y_pred = K.clip(y_pred, 0, 1)
  y_pred_bin = K.round(y_pred + threshold_shift)
  
  tp = K.sum(K.round(y_true * y_pred_bin), axis=1) + K.epsilon()
  fp = K.sum(K.round(K.clip(y_pred_bin - y_true, 0, 1)), axis=1)
  fn = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=1)
  
  precision = tp / (tp + fp)
  recall = tp / (tp + fn)
  
  beta_sq = beta ** 2
  return K.mean((beta_sq + 1) * (precision * recall) / (beta_sq * precision + recall + K.epsilon()))

# %%
'''
Setup Model & Data Generator
'''
# assign X_train/validation/test to the desired image set(s) from above
X_train = X_train3#np.concatenate( (np.concatenate( (X_train1, X_train2), axis=0), X_train3), axis=0)
X_validation = X_validation3
X_test = X_test3
#y_train = np.concatenate( (np.concatenate( (y_train, y_train), axis=0), y_train), axis=0)
NUM_TRAIN = len(X_train)

# reshape X_train/validation/test to the expected shape, and cast it back to a float32
X_train = X_train.reshape(NUM_TRAIN,BASE_SIZE,BASE_SIZE,1).astype(np.float32)
X_validation = X_validation.reshape(NUM_VALIDATION,BASE_SIZE,BASE_SIZE,1).astype(np.float32)
X_test = X_test.reshape(NUM_TEST,BASE_SIZE,BASE_SIZE,1).astype(np.float32)

# assign the desired model from above
model = get_model3()
model.summary()

# augmentation and fitting of data
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    rotation_range=0,
    width_shift_range=0.0,
    height_shift_range=0.0,
    shear_range=0,
    horizontal_flip=True,
    vertical_flip=False
)
datagen.fit(X_train)
datagen.fit(X_validation)

filepath = 'Model.{epoch:02d}-{val_acc:.4f}.hdf5'

checkpointer = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, mode='auto')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, verbose=0, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)
early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=0, verbose=0, mode='auto')

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=[fbeta, 'accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_111 (Conv2D)          (None, 48, 48, 64)        640
# _________________________________________________________________
# conv2d_112 (Conv2D)          (None, 48, 48, 64)        36928
# _________________________________________________________________
# batch_normalization_138 (Bat (None, 48, 48, 64)        256
# _________________________________________________________________
# activation_151 (Activation)  (None, 48, 48, 64)        0
# _________________________________________________________________
# max_pooling2d_87 (MaxPooling (None, 24, 24, 64)        0
# _________________________________________________________________
# gaussian_noise_19 (GaussianN (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_130 (Dropout)        (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_113 (Conv2D)          (None, 24, 24, 128)       73856
# _________________________________________________________________
# conv2d_114 (Conv2D)          (None, 24, 24, 128)       147584
# _________________________________________________________________
# batch_normalization_139 (Bat (None, 24, 24, 128)       512
# _________________________________________________________________
# activation_152 (Activation)  (None, 24, 24, 128)       0
# _________________________________________________________________
# max_pooling2d_88 (MaxPooling (None, 12, 12, 128)       0
# _________________________________________________________________
# gaussian_noise_20 (GaussianN (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_131 (Dropout)        (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_115 (Conv2D)          (None, 12, 12, 256)       295168
# _________________________________________________________________
# conv2d_116 (Conv2D)          (None, 12, 12, 265)       610825
# _________________________________________________________________
# batch_normalization_140 (Bat (None, 12, 12, 265)       1060
# _________________________________________________________________
# activation_153 (Activation)  (None, 12, 12, 265)       0
# _________________________________________________________________
# max_pooling2d_89 (MaxPooling (None, 6, 6, 265)         0
# _________________________________________________________________
# gaussian_noise_21 (GaussianN (None, 6, 6, 265)         0
# _________________________________________________________________
# dropout_132 (Dropout)        (None, 6, 6, 265)         0
# _________________________________________________________________
# conv2d_117 (Conv2D)          (None, 6, 6, 512)         1221632
# _________________________________________________________________
# conv2d_118 (Conv2D)          (None, 6, 6, 512)         2359808
# _________________________________________________________________
# conv2d_119 (Conv2D)          (None, 6, 6, 512)         262656
# _________________________________________________________________
# batch_normalization_141 (Bat (None, 6, 6, 512)         2048
# _________________________________________________________________
# activation_154 (Activation)  (None, 6, 6, 512)         0
# _________________________________________________________________
# max_pooling2d_90 (MaxPooling (None, 3, 3, 512)         0
# _________________________________________________________________
# gaussian_noise_22 (GaussianN (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_133 (Dropout)        (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten_22 (Flatten)         (None, 4608)              0
# _________________________________________________________________
# dense_65 (Dense)             (None, 2048)              9439232
# _________________________________________________________________
# batch_normalization_142 (Bat (None, 2048)              8192
# _________________________________________________________________
# activation_155 (Activation)  (None, 2048)              0
# _________________________________________________________________
# dropout_134 (Dropout)        (None, 2048)              0
# _________________________________________________________________
# dense_66 (Dense)             (None, 512)               1049088
# _________________________________________________________________
# batch_normalization_143 (Bat (None, 512)               2048
# _________________________________________________________________
# activation_156 (Activation)  (None, 512)               0
# _________________________________________________________________
# dropout_135 (Dropout)        (None, 512)               0
# _________________________________________________________________
# dense_67 (Dense)             (None, 7)                 3591
# _________________________________________________________________
# activation_157 (Activation)  (None, 7)                 0
# =================================================================
# Total params: 15,515,124
# Trainable params: 15,508,066
# Non-trainable params: 7,058
# _________________________________________________________________

# %%
'''
Training
'''
train_flow = datagen.flow(X_train, y_train, batch_size=BATCH_SIZE)
validation_flow = datagen.flow(X_validation, y_validation)

history = model.fit_generator(
    train_flow,
    steps_per_epoch=NUM_TRAIN / BATCH_SIZE,
    epochs=NUM_EPOCHS,
    verbose=1,
    validation_data=validation_flow,
    validation_steps=NUM_VALIDATION / BATCH_SIZE,
    callbacks=[checkpointer, reduce_lr, checkpointer]
)
# Out:
# Epoch 1/64
# 225/224 [==============================] - 61s 269ms/step - loss: 1.9755 - fbeta: 0.0533 - acc: 0.2406 - val_loss: 1.9079 - val_fbeta: 0.1336 - val_acc: 0.2586
#
# Epoch 00001: saving model to Model.01-0.2586.hdf5
#
# Epoch 00001: saving model to Model.01-0.2586.hdf5
# Epoch 2/64
# 225/224 [==============================] - 49s 218ms/step - loss: 1.5263 - fbeta: 0.2013 - acc: 0.4165 - val_loss: 1.7235 - val_fbeta: 0.2500 - val_acc: 0.4170
#
# Epoch 00002: saving model to Model.02-0.4170.hdf5
#
# Epoch 00002: saving model to Model.02-0.4170.hdf5
# Epoch 3/64
# 225/224 [==============================] - 49s 219ms/step - loss: 1.3442 - fbeta: 0.2750 - acc: 0.4859 - val_loss: 1.2379 - val_fbeta: 0.3459 - val_acc: 0.5162
#
# Epoch 00003: saving model to Model.03-0.5162.hdf5
#
# Epoch 00003: saving model to Model.03-0.5162.hdf5
# Epoch 4/64
# 225/224 [==============================] - 49s 219ms/step - loss: 1.2708 - fbeta: 0.3061 - acc: 0.5117 - val_loss: 1.4152 - val_fbeta: 0.2209 - val_acc: 0.4406
#
# Epoch 00004: saving model to Model.04-0.4406.hdf5
#
# Epoch 00004: saving model to Model.04-0.4406.hdf5
# Epoch 5/64
# 225/224 [==============================] - 49s 219ms/step - loss: 1.2327 - fbeta: 0.3230 - acc: 0.5305 - val_loss: 1.3255 - val_fbeta: 0.4073 - val_acc: 0.5226
#
# Epoch 00005: saving model to Model.05-0.5226.hdf5
#
# Epoch 00005: saving model to Model.05-0.5226.hdf5
# Epoch 6/64
# 225/224 [==============================] - 49s 219ms/step - loss: 1.1984 - fbeta: 0.3466 - acc: 0.5464 - val_loss: 1.2238 - val_fbeta: 0.3362 - val_acc: 0.5345
#
# Epoch 00006: saving model to Model.06-0.5345.hdf5
#
# Epoch 00006: saving model to Model.06-0.5345.hdf5
# Epoch 7/64
# 225/224 [==============================] - 49s 219ms/step - loss: 1.1722 - fbeta: 0.3609 - acc: 0.5513 - val_loss: 1.1792 - val_fbeta: 0.4289 - val_acc: 0.5431
#
# Epoch 00007: saving model to Model.07-0.5431.hdf5
#
# Epoch 00007: saving model to Model.07-0.5431.hdf5
# Epoch 8/64
# 225/224 [==============================] - 49s 220ms/step - loss: 1.1571 - fbeta: 0.3665 - acc: 0.5612 - val_loss: 1.1369 - val_fbeta: 0.4151 - val_acc: 0.5749
#
# Epoch 00008: saving model to Model.08-0.5749.hdf5
#
# Epoch 00008: saving model to Model.08-0.5749.hdf5
# Epoch 9/64
# 225/224 [==============================] - 49s 219ms/step - loss: 1.1388 - fbeta: 0.3814 - acc: 0.5662 - val_loss: 1.1348 - val_fbeta: 0.4170 - val_acc: 0.5733
#
# Epoch 00009: saving model to Model.09-0.5733.hdf5
#
# Epoch 00009: saving model to Model.09-0.5733.hdf5
# Epoch 10/64
# 225/224 [==============================] - 49s 218ms/step - loss: 1.1252 - fbeta: 0.3899 - acc: 0.5715 - val_loss: 1.0437 - val_fbeta: 0.4429 - val_acc: 0.6067
#
# Epoch 00010: saving model to Model.10-0.6067.hdf5
#
# Epoch 00010: saving model to Model.10-0.6067.hdf5
# Epoch 11/64
# 225/224 [==============================] - 49s 219ms/step - loss: 1.1096 - fbeta: 0.3994 - acc: 0.5775 - val_loss: 1.1062 - val_fbeta: 0.4601 - val_acc: 0.5744
#
# Epoch 00011: saving model to Model.11-0.5744.hdf5
#
# Epoch 00011: saving model to Model.11-0.5744.hdf5
# Epoch 12/64
# 225/224 [==============================] - 49s 219ms/step - loss: 1.0988 - fbeta: 0.4121 - acc: 0.5826 - val_loss: 1.0927 - val_fbeta: 0.4251 - val_acc: 0.5738
#
# Epoch 00012: saving model to Model.12-0.5738.hdf5
#
# Epoch 00012: saving model to Model.12-0.5738.hdf5
# Epoch 13/64
# 225/224 [==============================] - 49s 218ms/step - loss: 1.0883 - fbeta: 0.4163 - acc: 0.5857 - val_loss: 1.1029 - val_fbeta: 0.4504 - val_acc: 0.5830
#
# Epoch 00013: saving model to Model.13-0.5830.hdf5
#
# Epoch 00013: saving model to Model.13-0.5830.hdf5
# Epoch 14/64
# 225/224 [==============================] - 49s 219ms/step - loss: 1.0768 - fbeta: 0.4276 - acc: 0.5938 - val_loss: 1.0934 - val_fbeta: 0.4310 - val_acc: 0.5700
#
# Epoch 00014: saving model to Model.14-0.5700.hdf5
#
# Epoch 00014: saving model to Model.14-0.5700.hdf5
# Epoch 15/64
# 225/224 [==============================] - 49s 218ms/step - loss: 1.0640 - fbeta: 0.4297 - acc: 0.5956 - val_loss: 1.0855 - val_fbeta: 0.4774 - val_acc: 0.6088
#
# Epoch 00015: saving model to Model.15-0.6088.hdf5
#
# Epoch 00015: saving model to Model.15-0.6088.hdf5
# Epoch 16/64
# 225/224 [==============================] - 49s 218ms/step - loss: 1.0562 - fbeta: 0.4343 - acc: 0.5992 - val_loss: 1.0008 - val_fbeta: 0.4750 - val_acc: 0.6226
#
# Epoch 00016: saving model to Model.16-0.6226.hdf5
#
# Epoch 00016: saving model to Model.16-0.6226.hdf5
# Epoch 17/64
# 225/224 [==============================] - 49s 219ms/step - loss: 1.0473 - fbeta: 0.4427 - acc: 0.6044 - val_loss: 1.3243 - val_fbeta: 0.3319 - val_acc: 0.4860
#
# Epoch 00017: saving model to Model.17-0.4860.hdf5
#
# Epoch 00017: saving model to Model.17-0.4860.hdf5
# Epoch 18/64
# 225/224 [==============================] - 49s 218ms/step - loss: 1.0452 - fbeta: 0.4457 - acc: 0.6004 - val_loss: 1.0319 - val_fbeta: 0.4709 - val_acc: 0.6099
#
# Epoch 00018: saving model to Model.18-0.6099.hdf5
#
# Epoch 00018: saving model to Model.18-0.6099.hdf5
# Epoch 19/64
# 225/224 [==============================] - 49s 219ms/step - loss: 1.0330 - fbeta: 0.4465 - acc: 0.6076 - val_loss: 1.1396 - val_fbeta: 0.4892 - val_acc: 0.5905
#
# Epoch 00019: saving model to Model.19-0.5905.hdf5
#
# Epoch 00019: saving model to Model.19-0.5905.hdf5
# Epoch 20/64
# 225/224 [==============================] - 49s 219ms/step - loss: 1.0256 - fbeta: 0.4581 - acc: 0.6103 - val_loss: 1.0954 - val_fbeta: 0.4650 - val_acc: 0.6027
#
# Epoch 00020: saving model to Model.20-0.6027.hdf5
#
# Epoch 00020: saving model to Model.20-0.6027.hdf5
# Epoch 21/64
# 225/224 [==============================] - 49s 218ms/step - loss: 1.0170 - fbeta: 0.4598 - acc: 0.6166 - val_loss: 1.0469 - val_fbeta: 0.4914 - val_acc: 0.5991
#
# Epoch 00021: saving model to Model.21-0.5991.hdf5
#
# Epoch 00021: saving model to Model.21-0.5991.hdf5
# Epoch 22/64
# 225/224 [==============================] - 49s 218ms/step - loss: 1.0088 - fbeta: 0.4647 - acc: 0.6177 - val_loss: 1.0617 - val_fbeta: 0.4731 - val_acc: 0.6067
#
# Epoch 00022: saving model to Model.22-0.6067.hdf5
#
# Epoch 00022: saving model to Model.22-0.6067.hdf5
# Epoch 23/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.9960 - fbeta: 0.4740 - acc: 0.6229 - val_loss: 1.0868 - val_fbeta: 0.4343 - val_acc: 0.5733
#
# Epoch 00023: saving model to Model.23-0.5733.hdf5
#
# Epoch 00023: saving model to Model.23-0.5733.hdf5
# Epoch 24/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.9938 - fbeta: 0.4766 - acc: 0.6231 - val_loss: 1.1205 - val_fbeta: 0.4617 - val_acc: 0.5849
#
# Epoch 00024: saving model to Model.24-0.5849.hdf5
#
# Epoch 00024: saving model to Model.24-0.5849.hdf5
# Epoch 25/64
# 225/224 [==============================] - 49s 219ms/step - loss: 0.9817 - fbeta: 0.4810 - acc: 0.6273 - val_loss: 1.0050 - val_fbeta: 0.5216 - val_acc: 0.6358
#
# Epoch 00025: saving model to Model.25-0.6358.hdf5
#
# Epoch 00025: saving model to Model.25-0.6358.hdf5
# Epoch 26/64
# 225/224 [==============================] - 49s 219ms/step - loss: 0.9865 - fbeta: 0.4823 - acc: 0.6250 - val_loss: 1.0815 - val_fbeta: 0.4892 - val_acc: 0.6045
#
# Epoch 00026: saving model to Model.26-0.6045.hdf5
#
# Epoch 00026: saving model to Model.26-0.6045.hdf5
# Epoch 27/64
# 225/224 [==============================] - 49s 219ms/step - loss: 0.9373 - fbeta: 0.4983 - acc: 0.6453 - val_loss: 0.9316 - val_fbeta: 0.5313 - val_acc: 0.6369
#
# Epoch 00027: saving model to Model.27-0.6369.hdf5
#
# Epoch 00027: saving model to Model.27-0.6369.hdf5
# Epoch 28/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.9204 - fbeta: 0.5111 - acc: 0.6486 - val_loss: 0.9995 - val_fbeta: 0.5239 - val_acc: 0.6482
#
# Epoch 00028: saving model to Model.28-0.6482.hdf5
#
# Epoch 00028: saving model to Model.28-0.6482.hdf5
# Epoch 29/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.9130 - fbeta: 0.5212 - acc: 0.6531 - val_loss: 0.9395 - val_fbeta: 0.5194 - val_acc: 0.6347
#
# Epoch 00029: saving model to Model.29-0.6347.hdf5
#
# Epoch 00029: saving model to Model.29-0.6347.hdf5
# Epoch 30/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.9075 - fbeta: 0.5234 - acc: 0.6563 - val_loss: 0.9787 - val_fbeta: 0.5162 - val_acc: 0.6228
#
# Epoch 00030: saving model to Model.30-0.6228.hdf5
#
# Epoch 00030: saving model to Model.30-0.6228.hdf5
# Epoch 31/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.9016 - fbeta: 0.5298 - acc: 0.6599 - val_loss: 0.9287 - val_fbeta: 0.5205 - val_acc: 0.6552
#
# Epoch 00031: saving model to Model.31-0.6552.hdf5
#
# Epoch 00031: saving model to Model.31-0.6552.hdf5
# Epoch 32/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8979 - fbeta: 0.5305 - acc: 0.6571 - val_loss: 0.9452 - val_fbeta: 0.5416 - val_acc: 0.6593
#
# Epoch 00032: saving model to Model.32-0.6593.hdf5
#
# Epoch 00032: saving model to Model.32-0.6593.hdf5
# Epoch 33/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8944 - fbeta: 0.5343 - acc: 0.6603 - val_loss: 0.9699 - val_fbeta: 0.5183 - val_acc: 0.6304
#
# Epoch 00033: saving model to Model.33-0.6304.hdf5
#
# Epoch 00033: saving model to Model.33-0.6304.hdf5
# Epoch 34/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8973 - fbeta: 0.5337 - acc: 0.6597 - val_loss: 0.9652 - val_fbeta: 0.5377 - val_acc: 0.6422
#
# Epoch 00034: saving model to Model.34-0.6422.hdf5
#
# Epoch 00034: saving model to Model.34-0.6422.hdf5
# Epoch 35/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8897 - fbeta: 0.5350 - acc: 0.6621 - val_loss: 0.9361 - val_fbeta: 0.5302 - val_acc: 0.6347
#
# Epoch 00035: saving model to Model.35-0.6347.hdf5
#
# Epoch 00035: saving model to Model.35-0.6347.hdf5
# Epoch 36/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8847 - fbeta: 0.5400 - acc: 0.6674 - val_loss: 0.9283 - val_fbeta: 0.5560 - val_acc: 0.6626
#
# Epoch 00036: saving model to Model.36-0.6626.hdf5
#
# Epoch 00036: saving model to Model.36-0.6626.hdf5
# Epoch 37/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8834 - fbeta: 0.5423 - acc: 0.6621 - val_loss: 0.9331 - val_fbeta: 0.5183 - val_acc: 0.6466
#
# Epoch 00037: saving model to Model.37-0.6466.hdf5
#
# Epoch 00037: saving model to Model.37-0.6466.hdf5
# Epoch 38/64
# 225/224 [==============================] - 49s 219ms/step - loss: 0.8785 - fbeta: 0.5459 - acc: 0.6663 - val_loss: 0.8960 - val_fbeta: 0.5571 - val_acc: 0.6573
#
# Epoch 00038: saving model to Model.38-0.6573.hdf5
#
# Epoch 00038: saving model to Model.38-0.6573.hdf5
# Epoch 39/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8748 - fbeta: 0.5440 - acc: 0.6686 - val_loss: 1.0197 - val_fbeta: 0.5383 - val_acc: 0.6326
#
# Epoch 00039: saving model to Model.39-0.6326.hdf5
#
# Epoch 00039: saving model to Model.39-0.6326.hdf5
# Epoch 40/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8730 - fbeta: 0.5445 - acc: 0.6701 - val_loss: 0.9773 - val_fbeta: 0.5399 - val_acc: 0.6412
#
# Epoch 00040: saving model to Model.40-0.6412.hdf5
#
# Epoch 00040: saving model to Model.40-0.6412.hdf5
# Epoch 41/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8686 - fbeta: 0.5480 - acc: 0.6703 - val_loss: 0.8963 - val_fbeta: 0.5582 - val_acc: 0.6735
#
# Epoch 00041: saving model to Model.41-0.6735.hdf5
#
# Epoch 00041: saving model to Model.41-0.6735.hdf5
# Epoch 42/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8638 - fbeta: 0.5541 - acc: 0.6707 - val_loss: 0.9615 - val_fbeta: 0.5420 - val_acc: 0.6444
#
# Epoch 00042: saving model to Model.42-0.6444.hdf5
#
# Epoch 00042: saving model to Model.42-0.6444.hdf5
# Epoch 43/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8655 - fbeta: 0.5517 - acc: 0.6730 - val_loss: 1.0008 - val_fbeta: 0.5516 - val_acc: 0.6471
#
# Epoch 00043: saving model to Model.43-0.6471.hdf5
#
# Epoch 00043: saving model to Model.43-0.6471.hdf5
# Epoch 44/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8610 - fbeta: 0.5548 - acc: 0.6710 - val_loss: 0.9433 - val_fbeta: 0.5517 - val_acc: 0.6649
#
# Epoch 00044: saving model to Model.44-0.6649.hdf5
#
# Epoch 00044: saving model to Model.44-0.6649.hdf5
# Epoch 45/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8531 - fbeta: 0.5560 - acc: 0.6766 - val_loss: 0.9199 - val_fbeta: 0.5614 - val_acc: 0.6552
#
# Epoch 00045: saving model to Model.45-0.6552.hdf5
#
# Epoch 00045: saving model to Model.45-0.6552.hdf5
# Epoch 46/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8533 - fbeta: 0.5588 - acc: 0.6773 - val_loss: 0.9350 - val_fbeta: 0.5409 - val_acc: 0.6412
#
# Epoch 00046: saving model to Model.46-0.6412.hdf5
#
# Epoch 00046: saving model to Model.46-0.6412.hdf5
# Epoch 47/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8552 - fbeta: 0.5603 - acc: 0.6752 - val_loss: 0.9678 - val_fbeta: 0.5505 - val_acc: 0.6382
#
# Epoch 00047: saving model to Model.47-0.6382.hdf5
#
# Epoch 00047: saving model to Model.47-0.6382.hdf5
# Epoch 48/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8533 - fbeta: 0.5592 - acc: 0.6785 - val_loss: 0.8687 - val_fbeta: 0.5647 - val_acc: 0.6821
#
# Epoch 00048: saving model to Model.48-0.6821.hdf5
#
# Epoch 00048: saving model to Model.48-0.6821.hdf5
# Epoch 49/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8494 - fbeta: 0.5616 - acc: 0.6788 - val_loss: 0.9803 - val_fbeta: 0.5409 - val_acc: 0.6412
#
# Epoch 00049: saving model to Model.49-0.6412.hdf5
#
# Epoch 00049: saving model to Model.49-0.6412.hdf5
# Epoch 50/64
# 225/224 [==============================] - 49s 217ms/step - loss: 0.8496 - fbeta: 0.5615 - acc: 0.6782 - val_loss: 0.9493 - val_fbeta: 0.5657 - val_acc: 0.6562
#
# Epoch 00050: saving model to Model.50-0.6562.hdf5
#
# Epoch 00050: saving model to Model.50-0.6562.hdf5
# Epoch 51/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8424 - fbeta: 0.5652 - acc: 0.6808 - val_loss: 0.9559 - val_fbeta: 0.5216 - val_acc: 0.6382
#
# Epoch 00051: saving model to Model.51-0.6382.hdf5
#
# Epoch 00051: saving model to Model.51-0.6382.hdf5
# Epoch 52/64
# 225/224 [==============================] - 49s 217ms/step - loss: 0.8405 - fbeta: 0.5709 - acc: 0.6816 - val_loss: 0.8751 - val_fbeta: 0.5560 - val_acc: 0.6627
#
# Epoch 00052: saving model to Model.52-0.6627.hdf5
#
# Epoch 00052: saving model to Model.52-0.6627.hdf5
# Epoch 53/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8407 - fbeta: 0.5667 - acc: 0.6823 - val_loss: 1.0126 - val_fbeta: 0.5280 - val_acc: 0.6239
#
# Epoch 00053: saving model to Model.53-0.6239.hdf5
#
# Epoch 00053: saving model to Model.53-0.6239.hdf5
# Epoch 54/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8381 - fbeta: 0.5694 - acc: 0.6812 - val_loss: 0.9517 - val_fbeta: 0.5571 - val_acc: 0.6530
#
# Epoch 00054: saving model to Model.54-0.6530.hdf5
#
# Epoch 00054: saving model to Model.54-0.6530.hdf5
# Epoch 55/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8354 - fbeta: 0.5713 - acc: 0.6843 - val_loss: 0.9330 - val_fbeta: 0.5760 - val_acc: 0.6615
#
# Epoch 00055: saving model to Model.55-0.6615.hdf5
#
# Epoch 00055: saving model to Model.55-0.6615.hdf5
# Epoch 56/64
# 225/224 [==============================] - 49s 217ms/step - loss: 0.8304 - fbeta: 0.5737 - acc: 0.6861 - val_loss: 0.9191 - val_fbeta: 0.5377 - val_acc: 0.6412
#
# Epoch 00056: saving model to Model.56-0.6412.hdf5
#
# Epoch 00056: saving model to Model.56-0.6412.hdf5
# Epoch 57/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8291 - fbeta: 0.5733 - acc: 0.6853 - val_loss: 0.9417 - val_fbeta: 0.5657 - val_acc: 0.6552
#
# Epoch 00057: saving model to Model.57-0.6552.hdf5
#
# Epoch 00057: saving model to Model.57-0.6552.hdf5
# Epoch 58/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8276 - fbeta: 0.5739 - acc: 0.6854 - val_loss: 0.9476 - val_fbeta: 0.5700 - val_acc: 0.6606
#
# Epoch 00058: saving model to Model.58-0.6606.hdf5
#
# Epoch 00058: saving model to Model.58-0.6606.hdf5
# Epoch 59/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8154 - fbeta: 0.5776 - acc: 0.6853 - val_loss: 0.9484 - val_fbeta: 0.5549 - val_acc: 0.6482
#
# Epoch 00059: saving model to Model.59-0.6482.hdf5
#
# Epoch 00059: saving model to Model.59-0.6482.hdf5
# Epoch 60/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8169 - fbeta: 0.5806 - acc: 0.6895 - val_loss: 0.9628 - val_fbeta: 0.5313 - val_acc: 0.6347
#
# Epoch 00060: saving model to Model.60-0.6347.hdf5
#
# Epoch 00060: saving model to Model.60-0.6347.hdf5
# Epoch 61/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8168 - fbeta: 0.5823 - acc: 0.6923 - val_loss: 0.9731 - val_fbeta: 0.5496 - val_acc: 0.6562
#
# Epoch 00061: saving model to Model.61-0.6562.hdf5
#
# Epoch 00061: saving model to Model.61-0.6562.hdf5
# Epoch 62/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8221 - fbeta: 0.5765 - acc: 0.6861 - val_loss: 0.8857 - val_fbeta: 0.5851 - val_acc: 0.6713
#
# Epoch 00062: saving model to Model.62-0.6713.hdf5
#
# Epoch 00062: saving model to Model.62-0.6713.hdf5
# Epoch 63/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8120 - fbeta: 0.5790 - acc: 0.6882 - val_loss: 0.9306 - val_fbeta: 0.5760 - val_acc: 0.6693
#
# Epoch 00063: saving model to Model.63-0.6693.hdf5
#
# Epoch 00063: saving model to Model.63-0.6693.hdf5
# Epoch 64/64
# 225/224 [==============================] - 49s 218ms/step - loss: 0.8185 - fbeta: 0.5808 - acc: 0.6938 - val_loss: 0.9209 - val_fbeta: 0.5582 - val_acc: 0.6573
#
# Epoch 00064: saving model to Model.64-0.6573.hdf5
#
# Epoch 00064: saving model to Model.64-0.6573.hdf5

# %%
'''
Evaluation
'''
score = model.evaluate(X_test, y_test, steps=int(NUM_TEST / BATCH_SIZE))
print('Evaluation Loss: ', score[0])
print('Evaluation Accuracy: ', score[1])

# History of Accuracy
hist_acc = 'accuracy.png'
fig1 = plt.figure()
plt.plot(history.history['acc'], color='b', label='Training')
plt.plot(history.history['val_acc'], color='g', label='Validation')
plt.title('History for Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
fig1.savefig(hist_acc)
plt.show() 

# History of Loss
loss_acc = 'loss.png'
fig2 = plt.figure()
plt.plot(history.history['loss'], color='b', label='Training')
plt.plot(history.history['val_loss'], color='g', label='Validation')
plt.title('History for Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='lower left')
fig1.savefig(loss_acc)
plt.show()

# Confusion Matrix
y_pred = model.predict_classes(X_test)
y_true = np.asarray([np.argmax(i) for i in y_test])

cm = confusion_matrix(y_true, y_pred)
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
sns.set(font_scale=1.5)
fig, ax = plt.subplots(figsize=(10,10))
ax = sns.heatmap(cm_norm, annot=True, linewidths=0, square=False, cmap='Greens', yticklabels=EMOTION_LABELS, xticklabels=EMOTION_LABELS, vmin=0, vmax=np.max(cm_norm), fmt='.2f', annot_kws={'size': 20})
ax.set(xlabel='Predicted Labels', ylabel='Actual Labels')

plt.show()
# Out:
# 28/28 [==============================] - 49s 2s/step
# Evaluation Loss:  0.9011732935905457
# Evaluation Accuracy:  0.5711897611618042
